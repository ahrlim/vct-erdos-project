# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
plt_kwargs = {'figsize': (10, 4)}

# %%
eco_rounds = pd.read_csv("../../data/vct_2022/matches/eco_rounds.csv")
#maps_scores = pd.read_csv("../../data/vct_2022/matches/maps_scores.csv")
#eco_stats = pd.read_csv("../../data/vct_2022/matches/eco_stats.csv")

# %%
eco_rounds = eco_rounds.loc[ (eco_rounds["Map"]=="Fracture")]
eco_rounds["Outcome"] = eco_rounds["Outcome"].apply(lambda x: 1 if x == "Win" else 0)
eco_rounds["Loadout Value"] = eco_rounds["Loadout Value"].apply(lambda x: int(x.replace(".","").replace("k","00")))
eco_rounds["Remaining Credits"] = eco_rounds["Remaining Credits"].apply(lambda x: int(x.replace(".","").replace("k","00")))

eco_rounds
# Out:
#                                        Tournament             Stage  \
# 260                       Valorant Champions 2022       Group Stage
# 261                       Valorant Champions 2022       Group Stage
# 262                       Valorant Champions 2022       Group Stage
# 263                       Valorant Champions 2022       Group Stage
# 264                       Valorant Champions 2022       Group Stage
# ...                                           ...               ...
# 358393  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 358394  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 358395  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 358396  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 358397  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
#
#            Match Type                 Match Name       Map  Round Number  \
# 260       Opening (B)      ZETA DIVISION vs LOUD  Fracture             1
# 261       Opening (B)      ZETA DIVISION vs LOUD  Fracture             1
# 262       Opening (B)      ZETA DIVISION vs LOUD  Fracture             2
# 263       Opening (B)      ZETA DIVISION vs LOUD  Fracture             2
# 264       Opening (B)      ZETA DIVISION vs LOUD  Fracture             3
# ...               ...                        ...       ...           ...
# 358393  Lower Round 3  5MOKES vs FunPlus Phoenix  Fracture            18
# 358394  Lower Round 3  5MOKES vs FunPlus Phoenix  Fracture            19
# 358395  Lower Round 3  5MOKES vs FunPlus Phoenix  Fracture            19
# 358396  Lower Round 3  5MOKES vs FunPlus Phoenix  Fracture            20
# 358397  Lower Round 3  5MOKES vs FunPlus Phoenix  Fracture            20
#
#                    Team  Loadout Value  Remaining Credits              Type  \
# 260       ZETA DIVISION           3700                200         Eco: 0-5k
# 261                LOUD           3700                300         Eco: 0-5k
# 262       ZETA DIVISION          16200               1400  Semi-buy: 10-20k
# 263                LOUD           4100               7500         Eco: 0-5k
# 264       ZETA DIVISION          13600              13700  Semi-buy: 10-20k
# ...                 ...            ...                ...               ...
# 358393  FunPlus Phoenix          22500              12000    Full buy: 20k+
# 358394           5MOKES          19000               1500  Semi-buy: 10-20k
# 358395  FunPlus Phoenix          22100              20800    Full buy: 20k+
# 358396           5MOKES          19500               3400  Semi-buy: 10-20k
# 358397  FunPlus Phoenix          21500               9800    Full buy: 20k+
#
#         Outcome
# 260           1
# 261           0
# 262           1
# 263           0
# 264           0
# ...         ...
# 358393        1
# 358394        1
# 358395        0
# 358396        0
# 358397        1
#
# [24670 rows x 11 columns]

# %%
maps_scores = pd.read_csv("../../data/vct_2022/matches/maps_scores.csv")
maps_scores.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2022  Group Stage  Opening (A)
# 1  Valorant Champions 2022  Group Stage  Opening (A)
# 2  Valorant Champions 2022  Group Stage  Opening (A)
# 3  Valorant Champions 2022  Group Stage  Opening (A)
# 4  Valorant Champions 2022  Group Stage  Opening (A)
#
#                    Match Name     Map     Team A  Team A Score  \
# 0  Paper Rex vs EDward Gaming   Pearl  Paper Rex            13
# 1  Paper Rex vs EDward Gaming  Icebox  Paper Rex             5
# 2  Paper Rex vs EDward Gaming   Haven  Paper Rex            13
# 3     Leviatán vs Team Liquid   Haven   Leviatán            13
# 4     Leviatán vs Team Liquid  Ascent   Leviatán            13
#
#    Team A Attacker Score  Team A Defender Score  Team A Overtime Score  \
# 0                      6                      7                    NaN
# 1                      2                      3                    NaN
# 2                      7                      6                    NaN
# 3                      8                      5                    NaN
# 4                      6                      7                    NaN
#
#           Team B  Team B Score  Team B Attacker Score  Team B Defender Score  \
# 0  EDward Gaming            11                      5                      6
# 1  EDward Gaming            13                      3                     10
# 2  EDward Gaming             8                      3                      5
# 3    Team Liquid            10                      6                      4
# 4    Team Liquid            10                      4                      6
#
#    Team B Overtime Score Duration
# 0                    NaN  1:16:34
# 1                    NaN    40:51
# 2                    NaN      NaN
# 3                    NaN  1:04:37
# 4                    NaN  1:05:07

# %%
team_ab_2022 = maps_scores[["Tournament", "Stage", "Match Type", "Match Name", "Map", "Team A", "Team B"]]

team_ab_2022
# Out:
#                                      Tournament             Stage  \
# 0                       Valorant Champions 2022       Group Stage
# 1                       Valorant Champions 2022       Group Stage
# 2                       Valorant Champions 2022       Group Stage
# 3                       Valorant Champions 2022       Group Stage
# 4                       Valorant Champions 2022       Group Stage
# ...                                         ...               ...
# 8879  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 8880  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 8881  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 8882  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 8883  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
#
#        Match Type                        Match Name     Map         Team A  \
# 0     Opening (A)        Paper Rex vs EDward Gaming   Pearl      Paper Rex
# 1     Opening (A)        Paper Rex vs EDward Gaming  Icebox      Paper Rex
# 2     Opening (A)        Paper Rex vs EDward Gaming   Haven      Paper Rex
# 3     Opening (A)           Leviatán vs Team Liquid   Haven       Leviatán
# 4     Opening (A)           Leviatán vs Team Liquid  Ascent       Leviatán
# ...           ...                               ...     ...            ...
# 8879  Grand Final  Natus Vincere vs FunPlus Phoenix    Bind  Natus Vincere
# 8880  Grand Final  Natus Vincere vs FunPlus Phoenix  Icebox  Natus Vincere
# 8881  Grand Final  Natus Vincere vs FunPlus Phoenix  Breeze  Natus Vincere
# 8882  Grand Final  Natus Vincere vs FunPlus Phoenix   Haven  Natus Vincere
# 8883  Grand Final  Natus Vincere vs FunPlus Phoenix   Split  Natus Vincere
#
#                Team B
# 0       EDward Gaming
# 1       EDward Gaming
# 2       EDward Gaming
# 3         Team Liquid
# 4         Team Liquid
# ...               ...
# 8879  FunPlus Phoenix
# 8880  FunPlus Phoenix
# 8881  FunPlus Phoenix
# 8882  FunPlus Phoenix
# 8883  FunPlus Phoenix
#
# [8884 rows x 7 columns]

# %%
keys = ['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map','Team']

Eco_rounds_ab_2022=\
pd.merge(
    team_ab_2022.rename(columns={"Team A":"Team"})\
    ,eco_rounds\
    ,on=keys
)\
.rename(columns={"Loadout Value":"Loadout_A", "Remaining Credits":"Remaining_credit_A", "Type":"Eco_type_A", "Outcome":"Outcome_A"})\
.rename(columns={"Team":"Team A", "Team B":"Team"})\
.set_index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map','Team', 'Round Number'])\
.join(eco_rounds\
      .set_index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map','Team', 'Round Number'])\
)\
.reset_index()\
.rename(columns={"Loadout Value":"Loadout_B", "Remaining Credits":"Remaining_credit_B", "Type":"Eco_type_B", "Outcome":"Outcome_B"})\
.rename(columns={"Team":"Team B"})

Eco_rounds_ab_2022.head()
# Out:
#                 Tournament        Stage   Match Type             Match Name  \
# 0  Valorant Champions 2022  Group Stage  Opening (B)  ZETA DIVISION vs LOUD
# 1  Valorant Champions 2022  Group Stage  Opening (B)  ZETA DIVISION vs LOUD
# 2  Valorant Champions 2022  Group Stage  Opening (B)  ZETA DIVISION vs LOUD
# 3  Valorant Champions 2022  Group Stage  Opening (B)  ZETA DIVISION vs LOUD
# 4  Valorant Champions 2022  Group Stage  Opening (B)  ZETA DIVISION vs LOUD
#
#         Map Team B  Round Number         Team A  Loadout_A  \
# 0  Fracture   LOUD             1  ZETA DIVISION       3700
# 1  Fracture   LOUD             2  ZETA DIVISION      16200
# 2  Fracture   LOUD             3  ZETA DIVISION      13600
# 3  Fracture   LOUD             4  ZETA DIVISION      24200
# 4  Fracture   LOUD             5  ZETA DIVISION      23200
#
#    Remaining_credit_A        Eco_type_A  Outcome_A  Loadout_B  \
# 0                 200         Eco: 0-5k          1       3700
# 1                1400  Semi-buy: 10-20k          1       4100
# 2               13700  Semi-buy: 10-20k          0      20300
# 3                1400    Full buy: 20k+          1      20800
# 4                6700    Full buy: 20k+          1       6500
#
#    Remaining_credit_B       Eco_type_B  Outcome_B
# 0                 300        Eco: 0-5k          0
# 1                7500        Eco: 0-5k          0
# 2                 900   Full buy: 20k+          1
# 3                3900   Full buy: 20k+          0
# 4                8000  Semi-eco: 5-10k          0

# %%
Eco_rounds_ab_2022[[ "Eco_type_A", "Eco_type_B", "Outcome_A", "Round Number"]].groupby([ "Eco_type_A", "Eco_type_B", "Outcome_A"]).count()
# Out:
#                                              Round Number
# Eco_type_A       Eco_type_B       Outcome_A
# Eco: 0-5k        Eco: 0-5k        0                   558
#                                   1                   671
#                  Full buy: 20k+   0                    39
#                                   1                     6
#                  Semi-buy: 10-20k 0                   453
#                                   1                    41
# Full buy: 20k+   Eco: 0-5k        0                     6
#                                   1                    42
#                  Full buy: 20k+   0                  2118
#                                   1                  2396
#                  Semi-buy: 10-20k 0                   599
#                                   1                  1135
#                  Semi-eco: 5-10k  0                   185
#                                   1                   681
# Semi-buy: 10-20k Eco: 0-5k        0                    38
#                                   1                   540
#                  Full buy: 20k+   0                   942
#                                   1                   607
#                  Semi-buy: 10-20k 0                   196
#                                   1                   227
#                  Semi-eco: 5-10k  0                    21
#                                   1                    73
# Semi-eco: 5-10k  Full buy: 20k+   0                   534
#                                   1                   151
#                  Semi-buy: 10-20k 0                    54
#                                   1                    22

# %%
def RoundRating(LoadOutA, LoadoutB,  OutcomeA):
    LoadoutB = max(LoadoutB, 100)
    LoadOutA = max(LoadOutA, 100)
    if OutcomeA == 1:
        return LoadoutB/LoadOutA
    if OutcomeA == 0:
        return 0
    
def RoundRating2(x, y):
    return 5

# %%
Eco_rounds_ab_2022["Rating_A"]=Eco_rounds_ab_2022[["Loadout_A", "Loadout_B", "Outcome_A"]]\
    .apply(lambda row: RoundRating(row["Loadout_A"], row["Loadout_B"], row["Outcome_A"]), axis=1)

Eco_rounds_ab_2022["Rating_B"]=Eco_rounds_ab_2022[["Loadout_A", "Loadout_B", "Outcome_B"]]\
    .apply(lambda row: RoundRating(row["Loadout_B"], row["Loadout_A"], row["Outcome_B"]), axis=1)


Eco_rounds_ab_2022.head(10)
# Out:
#                 Tournament        Stage   Match Type             Match Name  \
# 0  Valorant Champions 2022  Group Stage  Opening (B)  ZETA DIVISION vs LOUD
# 1  Valorant Champions 2022  Group Stage  Opening (B)  ZETA DIVISION vs LOUD
# 2  Valorant Champions 2022  Group Stage  Opening (B)  ZETA DIVISION vs LOUD
# 3  Valorant Champions 2022  Group Stage  Opening (B)  ZETA DIVISION vs LOUD
# 4  Valorant Champions 2022  Group Stage  Opening (B)  ZETA DIVISION vs LOUD
# 5  Valorant Champions 2022  Group Stage  Opening (B)  ZETA DIVISION vs LOUD
# 6  Valorant Champions 2022  Group Stage  Opening (B)  ZETA DIVISION vs LOUD
# 7  Valorant Champions 2022  Group Stage  Opening (B)  ZETA DIVISION vs LOUD
# 8  Valorant Champions 2022  Group Stage  Opening (B)  ZETA DIVISION vs LOUD
# 9  Valorant Champions 2022  Group Stage  Opening (B)  ZETA DIVISION vs LOUD
#
#         Map Team B  Round Number         Team A  Loadout_A  \
# 0  Fracture   LOUD             1  ZETA DIVISION       3700
# 1  Fracture   LOUD             2  ZETA DIVISION      16200
# 2  Fracture   LOUD             3  ZETA DIVISION      13600
# 3  Fracture   LOUD             4  ZETA DIVISION      24200
# 4  Fracture   LOUD             5  ZETA DIVISION      23200
# 5  Fracture   LOUD             6  ZETA DIVISION      27100
# 6  Fracture   LOUD             7  ZETA DIVISION      20000
# 7  Fracture   LOUD             8  ZETA DIVISION      25300
# 8  Fracture   LOUD             9  ZETA DIVISION      24300
# 9  Fracture   LOUD            10  ZETA DIVISION      25500
#
#    Remaining_credit_A        Eco_type_A  Outcome_A  Loadout_B  \
# 0                 200         Eco: 0-5k          1       3700
# 1                1400  Semi-buy: 10-20k          1       4100
# 2               13700  Semi-buy: 10-20k          0      20300
# 3                1400    Full buy: 20k+          1      20800
# 4                6700    Full buy: 20k+          1       6500
# 5               13200    Full buy: 20k+          0      21000
# 6                5100    Full buy: 20k+          1      20800
# 7                8900    Full buy: 20k+          1      19400
# 8               13100    Full buy: 20k+          1       8800
# 9               11100    Full buy: 20k+          0      23600
#
#    Remaining_credit_B        Eco_type_B  Outcome_B  Rating_A  Rating_B
# 0                 300         Eco: 0-5k          0  1.000000  0.000000
# 1                7500         Eco: 0-5k          0  0.253086  0.000000
# 2                 900    Full buy: 20k+          1  0.000000  0.669951
# 3                3900    Full buy: 20k+          0  0.859504  0.000000
# 4                8000   Semi-eco: 5-10k          0  0.280172  0.000000
# 5                1000    Full buy: 20k+          1  0.000000  1.290476
# 6                6400    Full buy: 20k+          0  1.040000  0.000000
# 7                1800  Semi-buy: 10-20k          0  0.766798  0.000000
# 8                8100   Semi-eco: 5-10k          0  0.362140  0.000000
# 9                3100    Full buy: 20k+          1  0.000000  1.080508

# %%
keys = ['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map','Team A', 'Team B']
grouped5 = Eco_rounds_ab_2022.groupby(keys)
Eco_rounds_ab_2022["Match Rating A"]=grouped5["Rating_A"].transform(lambda x: x.mean())
Eco_rounds_ab_2022["Match Rating B"]=grouped5["Rating_B"].transform(lambda x: x.mean())

Eco_rounds_ab_2022.head(5)
# Out:
#                 Tournament        Stage   Match Type             Match Name  \
# 0  Valorant Champions 2022  Group Stage  Opening (B)  ZETA DIVISION vs LOUD
# 1  Valorant Champions 2022  Group Stage  Opening (B)  ZETA DIVISION vs LOUD
# 2  Valorant Champions 2022  Group Stage  Opening (B)  ZETA DIVISION vs LOUD
# 3  Valorant Champions 2022  Group Stage  Opening (B)  ZETA DIVISION vs LOUD
# 4  Valorant Champions 2022  Group Stage  Opening (B)  ZETA DIVISION vs LOUD
#
#         Map Team B  Round Number         Team A  Loadout_A  \
# 0  Fracture   LOUD             1  ZETA DIVISION       3700
# 1  Fracture   LOUD             2  ZETA DIVISION      16200
# 2  Fracture   LOUD             3  ZETA DIVISION      13600
# 3  Fracture   LOUD             4  ZETA DIVISION      24200
# 4  Fracture   LOUD             5  ZETA DIVISION      23200
#
#    Remaining_credit_A        Eco_type_A  Outcome_A  Loadout_B  \
# 0                 200         Eco: 0-5k          1       3700
# 1                1400  Semi-buy: 10-20k          1       4100
# 2               13700  Semi-buy: 10-20k          0      20300
# 3                1400    Full buy: 20k+          1      20800
# 4                6700    Full buy: 20k+          1       6500
#
#    Remaining_credit_B       Eco_type_B  Outcome_B  Rating_A  Rating_B  \
# 0                 300        Eco: 0-5k          0  1.000000  0.000000
# 1                7500        Eco: 0-5k          0  0.253086  0.000000
# 2                 900   Full buy: 20k+          1  0.000000  0.669951
# 3                3900   Full buy: 20k+          0  0.859504  0.000000
# 4                8000  Semi-eco: 5-10k          0  0.280172  0.000000
#
#    Match Rating A  Match Rating B
# 0        0.342734        0.515243
# 1        0.342734        0.515243
# 2        0.342734        0.515243
# 3        0.342734        0.515243
# 4        0.342734        0.515243

# %%
#keys = ['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map','Team A', 'Team B']
grouped6 = Eco_rounds_ab_2022.groupby(["Team A"])
Eco_rounds_ab_2022["Team Rating A"]=grouped6["Rating_A"].transform(lambda x: x.mean())
grouped6 = Eco_rounds_ab_2022.groupby(["Team B"])
Eco_rounds_ab_2022["Team Rating B"]=grouped6["Rating_B"].transform(lambda x: x.mean())

Eco_rounds_ab_2022
# Out:
#                                       Tournament             Stage  \
# 0                        Valorant Champions 2022       Group Stage
# 1                        Valorant Champions 2022       Group Stage
# 2                        Valorant Champions 2022       Group Stage
# 3                        Valorant Champions 2022       Group Stage
# 4                        Valorant Champions 2022       Group Stage
# ...                                          ...               ...
# 12330  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 12331  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 12332  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 12333  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 12334  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
#
#           Match Type                 Match Name       Map           Team B  \
# 0        Opening (B)      ZETA DIVISION vs LOUD  Fracture             LOUD
# 1        Opening (B)      ZETA DIVISION vs LOUD  Fracture             LOUD
# 2        Opening (B)      ZETA DIVISION vs LOUD  Fracture             LOUD
# 3        Opening (B)      ZETA DIVISION vs LOUD  Fracture             LOUD
# 4        Opening (B)      ZETA DIVISION vs LOUD  Fracture             LOUD
# ...              ...                        ...       ...              ...
# 12330  Lower Round 3  5MOKES vs FunPlus Phoenix  Fracture  FunPlus Phoenix
# 12331  Lower Round 3  5MOKES vs FunPlus Phoenix  Fracture  FunPlus Phoenix
# 12332  Lower Round 3  5MOKES vs FunPlus Phoenix  Fracture  FunPlus Phoenix
# 12333  Lower Round 3  5MOKES vs FunPlus Phoenix  Fracture  FunPlus Phoenix
# 12334  Lower Round 3  5MOKES vs FunPlus Phoenix  Fracture  FunPlus Phoenix
#
#        Round Number         Team A  Loadout_A  Remaining_credit_A  ...  \
# 0                 1  ZETA DIVISION       3700                 200  ...
# 1                 2  ZETA DIVISION      16200                1400  ...
# 2                 3  ZETA DIVISION      13600               13700  ...
# 3                 4  ZETA DIVISION      24200                1400  ...
# 4                 5  ZETA DIVISION      23200                6700  ...
# ...             ...            ...        ...                 ...  ...
# 12330            16         5MOKES      22400                8400  ...
# 12331            17         5MOKES       8800               10300  ...
# 12332            18         5MOKES      21100                4300  ...
# 12333            19         5MOKES      19000                1500  ...
# 12334            20         5MOKES      19500                3400  ...
#
#       Loadout_B  Remaining_credit_B       Eco_type_B  Outcome_B  Rating_A  \
# 0          3700                 300        Eco: 0-5k          0  1.000000
# 1          4100                7500        Eco: 0-5k          0  0.253086
# 2         20300                 900   Full buy: 20k+          1  0.000000
# 3         20800                3900   Full buy: 20k+          0  0.859504
# 4          6500                8000  Semi-eco: 5-10k          0  0.280172
# ...         ...                 ...              ...        ...       ...
# 12330     21700                1200   Full buy: 20k+          1  0.000000
# 12331     20300                4500   Full buy: 20k+          1  0.000000
# 12332     22500               12000   Full buy: 20k+          1  0.000000
# 12333     22100               20800   Full buy: 20k+          0  1.163158
# 12334     21500                9800   Full buy: 20k+          1  0.000000
#
#        Rating_B  Match Rating A  Match Rating B  Team Rating A  Team Rating B
# 0      0.000000        0.342734        0.515243       0.449277       0.541830
# 1      0.000000        0.342734        0.515243       0.449277       0.541830
# 2      0.669951        0.342734        0.515243       0.449277       0.541830
# 3      0.000000        0.342734        0.515243       0.449277       0.541830
# 4      0.000000        0.342734        0.515243       0.449277       0.541830
# ...         ...             ...             ...            ...            ...
# 12330  1.032258        0.381667        0.604586       0.279142       0.526345
# 12331  0.433498        0.381667        0.604586       0.279142       0.526345
# 12332  0.937778        0.381667        0.604586       0.279142       0.526345
# 12333  0.000000        0.381667        0.604586       0.279142       0.526345
# 12334  0.906977        0.381667        0.604586       0.279142       0.526345
#
# [12335 rows x 22 columns]

# %%
Eco_rounds_ab_2022[['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map','Team A', 'Team B', 'Team Rating A', 'Team Rating B']]
# Out:
#                                       Tournament             Stage  \
# 0                        Valorant Champions 2022       Group Stage
# 1                        Valorant Champions 2022       Group Stage
# 2                        Valorant Champions 2022       Group Stage
# 3                        Valorant Champions 2022       Group Stage
# 4                        Valorant Champions 2022       Group Stage
# ...                                          ...               ...
# 12330  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 12331  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 12332  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 12333  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 12334  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
#
#           Match Type                 Match Name       Map         Team A  \
# 0        Opening (B)      ZETA DIVISION vs LOUD  Fracture  ZETA DIVISION
# 1        Opening (B)      ZETA DIVISION vs LOUD  Fracture  ZETA DIVISION
# 2        Opening (B)      ZETA DIVISION vs LOUD  Fracture  ZETA DIVISION
# 3        Opening (B)      ZETA DIVISION vs LOUD  Fracture  ZETA DIVISION
# 4        Opening (B)      ZETA DIVISION vs LOUD  Fracture  ZETA DIVISION
# ...              ...                        ...       ...            ...
# 12330  Lower Round 3  5MOKES vs FunPlus Phoenix  Fracture         5MOKES
# 12331  Lower Round 3  5MOKES vs FunPlus Phoenix  Fracture         5MOKES
# 12332  Lower Round 3  5MOKES vs FunPlus Phoenix  Fracture         5MOKES
# 12333  Lower Round 3  5MOKES vs FunPlus Phoenix  Fracture         5MOKES
# 12334  Lower Round 3  5MOKES vs FunPlus Phoenix  Fracture         5MOKES
#
#                 Team B  Team Rating A  Team Rating B
# 0                 LOUD       0.449277       0.541830
# 1                 LOUD       0.449277       0.541830
# 2                 LOUD       0.449277       0.541830
# 3                 LOUD       0.449277       0.541830
# 4                 LOUD       0.449277       0.541830
# ...                ...            ...            ...
# 12330  FunPlus Phoenix       0.279142       0.526345
# 12331  FunPlus Phoenix       0.279142       0.526345
# 12332  FunPlus Phoenix       0.279142       0.526345
# 12333  FunPlus Phoenix       0.279142       0.526345
# 12334  FunPlus Phoenix       0.279142       0.526345
#
# [12335 rows x 9 columns]

# %%
Eco_rounds_ab_2022.sort_values(by=["Team Rating A"], ascending=False).head()
# Out:
#                                              Tournament  \
# 5341  Champions Tour Malaysia & Singapore Stage 2: C...
# 5350  Champions Tour Malaysia & Singapore Stage 2: C...
# 5343  Champions Tour Malaysia & Singapore Stage 2: C...
# 5342  Champions Tour Malaysia & Singapore Stage 2: C...
# 5346  Champions Tour Malaysia & Singapore Stage 2: C...
#
#                              Stage         Match Type            Match Name  \
# 5341  Open Qualifier (Elimination)  Upper Round of 32  Dei Macha vs Seekers
# 5350  Open Qualifier (Elimination)  Upper Round of 32  Dei Macha vs Seekers
# 5343  Open Qualifier (Elimination)  Upper Round of 32  Dei Macha vs Seekers
# 5342  Open Qualifier (Elimination)  Upper Round of 32  Dei Macha vs Seekers
# 5346  Open Qualifier (Elimination)  Upper Round of 32  Dei Macha vs Seekers
#
#            Map   Team B  Round Number     Team A  Loadout_A  \
# 5341  Fracture  Seekers             5  Dei Macha      23700
# 5350  Fracture  Seekers            14  Dei Macha       1000
# 5343  Fracture  Seekers             7  Dei Macha      23300
# 5342  Fracture  Seekers             6  Dei Macha      20800
# 5346  Fracture  Seekers            10  Dei Macha      23300
#
#       Remaining_credit_A  ... Loadout_B  Remaining_credit_B        Eco_type_B  \
# 5341               21100  ...     14500                7100  Semi-buy: 10-20k
# 5350                9800  ...     16700                2200  Semi-buy: 10-20k
# 5343               26900  ...     10800                7100  Semi-buy: 10-20k
# 5342               29100  ...     21300                2000    Full buy: 20k+
# 5346               14800  ...     23700               12700    Full buy: 20k+
#
#       Outcome_B   Rating_A  Rating_B  Match Rating A  Match Rating B  \
# 5341          0   0.611814       0.0        1.728564        0.206846
# 5350          0  16.700000       0.0        1.728564        0.206846
# 5343          0   0.463519       0.0        1.728564        0.206846
# 5342          0   1.024038       0.0        1.728564        0.206846
# 5346          0   1.017167       0.0        1.728564        0.206846
#
#       Team Rating A  Team Rating B
# 5341       1.728564       0.473555
# 5350       1.728564       0.473555
# 5343       1.728564       0.473555
# 5342       1.728564       0.473555
# 5346       1.728564       0.473555
#
# [5 rows x 22 columns]

# %%
grouped_rating_df_A = Eco_rounds_ab_2022.groupby(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Team A'])["Rating_A"].agg("mean").reset_index()
grouped_rating_df_B = Eco_rounds_ab_2022.groupby(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Team B'])["Rating_B"].agg("mean").reset_index()
#print(grouped_rating_df_A.head())
print(grouped_rating_df_B.head())
# Out:
#                                           Tournament        Stage  \
# 0  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 1  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 2  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 3  Champions Tour Asia-Pacific Stage 1: Challenge...    Knockouts
# 4  Champions Tour Asia-Pacific Stage 1: Challenge...    Knockouts
#
#                     Match Type                        Match Name       Map  \
# 0                  Decider (B)        Persija Esports vs Bonkers  Fracture
# 1                 Winner's (A)  BOOM Esports vs Made in Thailand  Fracture
# 2                 Winner's (B)      Paper Rex vs Persija Esports  Fracture
# 3                 Grand Finals       Paper Rex vs XERXIA Esports  Fracture
# 4  Upper Bracket Quarterfinals    BOOM Esports vs XERXIA Esports  Fracture
#
#              Team B  Rating_B
# 0           Bonkers  0.375520
# 1  Made in Thailand  0.387117
# 2   Persija Esports  0.370516
# 3    XERXIA Esports  0.188576
# 4    XERXIA Esports  0.456355

# %%
maps_scores["Team_A_win"] = maps_scores["Team A Score"] > maps_scores["Team B Score"]
maps_scores["Team_B_win"] = maps_scores["Team B Score"] > maps_scores["Team A Score"]

maps_scores.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2022  Group Stage  Opening (A)
# 1  Valorant Champions 2022  Group Stage  Opening (A)
# 2  Valorant Champions 2022  Group Stage  Opening (A)
# 3  Valorant Champions 2022  Group Stage  Opening (A)
# 4  Valorant Champions 2022  Group Stage  Opening (A)
#
#                    Match Name     Map     Team A  Team A Score  \
# 0  Paper Rex vs EDward Gaming   Pearl  Paper Rex            13
# 1  Paper Rex vs EDward Gaming  Icebox  Paper Rex             5
# 2  Paper Rex vs EDward Gaming   Haven  Paper Rex            13
# 3     Leviatán vs Team Liquid   Haven   Leviatán            13
# 4     Leviatán vs Team Liquid  Ascent   Leviatán            13
#
#    Team A Attacker Score  Team A Defender Score  Team A Overtime Score  \
# 0                      6                      7                    NaN
# 1                      2                      3                    NaN
# 2                      7                      6                    NaN
# 3                      8                      5                    NaN
# 4                      6                      7                    NaN
#
#           Team B  Team B Score  Team B Attacker Score  Team B Defender Score  \
# 0  EDward Gaming            11                      5                      6
# 1  EDward Gaming            13                      3                     10
# 2  EDward Gaming             8                      3                      5
# 3    Team Liquid            10                      6                      4
# 4    Team Liquid            10                      4                      6
#
#    Team B Overtime Score Duration  Team_A_win  Team_B_win
# 0                    NaN  1:16:34        True       False
# 1                    NaN    40:51       False        True
# 2                    NaN      NaN        True       False
# 3                    NaN  1:04:37        True       False
# 4                    NaN  1:05:07        True       False

# %%
maps_scores = maps_scores[["Tournament", "Stage", "Match Type", "Match Name", "Map", "Team A", "Team A Score", "Team_A_win", "Team B", "Team B Score", "Team_B_win"]]

# %%
maps_scores = maps_scores.loc[ (maps_scores["Map"]=="Fracture")]
maps_scores.head()
# Out:
#                  Tournament        Stage    Match Type  \
# 6   Valorant Champions 2022  Group Stage   Opening (B)
# 9   Valorant Champions 2022  Group Stage   Opening (B)
# 18  Valorant Champions 2022  Group Stage  Winner's (B)
# 20  Valorant Champions 2022  Group Stage   Opening (C)
# 25  Valorant Champions 2022  Group Stage  Winner's (D)
#
#                       Match Name       Map         Team A  Team A Score  \
# 6          ZETA DIVISION vs LOUD  Fracture  ZETA DIVISION             9
# 9   OpTic Gaming vs BOOM Esports  Fracture   OpTic Gaming            13
# 18          OpTic Gaming vs LOUD  Fracture   OpTic Gaming            13
# 20        XSET vs XERXIA Esports  Fracture           XSET            13
# 25            DRX vs 100 Thieves  Fracture            DRX            13
#
#     Team_A_win          Team B  Team B Score  Team_B_win
# 6        False            LOUD            13        True
# 9         True    BOOM Esports             3       False
# 18        True            LOUD            10       False
# 20        True  XERXIA Esports            11       False
# 25        True     100 Thieves             9       False

# %%
maps_scores.keys()
# Out:
# Index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Team A',
#        'Team A Score', 'Team_A_win', 'Team B', 'Team B Score', 'Team_B_win'],
#       dtype='object')

# %%
final_rating_df =\
      maps_scores.set_index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Team A'])\
                  .join(grouped_rating_df_A\
                        .rename(columns={"Rating_A":"Team_A_rating"})\
                        .set_index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Team A'])\
                  )\
                  .reset_index()\
                  .set_index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Team B'])\
                  .join(grouped_rating_df_B\
                        .rename(columns={"Rating_B":"Team_B_rating"})\
                        .set_index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Team B'])\
                  )\
                  .reset_index()

# %%
final_rating_df
# Out:
#                                     Tournament             Stage  \
# 0                      Valorant Champions 2022       Group Stage
# 1                      Valorant Champions 2022       Group Stage
# 2                      Valorant Champions 2022       Group Stage
# 3                      Valorant Champions 2022       Group Stage
# 4                      Valorant Champions 2022       Group Stage
# ..                                         ...               ...
# 594  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 595  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 596  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 597  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 598  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
#
#               Match Type                            Match Name       Map  \
# 0            Opening (B)                 ZETA DIVISION vs LOUD  Fracture
# 1            Opening (B)          OpTic Gaming vs BOOM Esports  Fracture
# 2           Winner's (B)                  OpTic Gaming vs LOUD  Fracture
# 3            Opening (C)                XSET vs XERXIA Esports  Fracture
# 4           Winner's (D)                    DRX vs 100 Thieves  Fracture
# ..                   ...                                   ...       ...
# 594  Upper Quarterfinals       One Breath Gaming vs B8 Esports  Fracture
# 595     Upper Semifinals                  5MOKES vs KPI Gaming  Fracture
# 596        Lower Round 1        B8 Esports vs SMARACIS eSports  Fracture
# 597        Lower Round 2  One Breath Gaming vs FunPlus Phoenix  Fracture
# 598        Lower Round 3             5MOKES vs FunPlus Phoenix  Fracture
#
#                Team B             Team A  Team A Score  Team_A_win  \
# 0                LOUD      ZETA DIVISION             9       False
# 1        BOOM Esports       OpTic Gaming            13        True
# 2                LOUD       OpTic Gaming            13        True
# 3      XERXIA Esports               XSET            13        True
# 4         100 Thieves                DRX            13        True
# ..                ...                ...           ...         ...
# 594        B8 Esports  One Breath Gaming             9       False
# 595        KPI Gaming             5MOKES             3       False
# 596  SMARACIS eSports         B8 Esports            10       False
# 597   FunPlus Phoenix  One Breath Gaming             1       False
# 598   FunPlus Phoenix             5MOKES             7       False
#
#      Team B Score  Team_B_win  Team_A_rating  Team_B_rating
# 0              13        True       0.342734       0.515243
# 1               3       False       0.646165       0.135679
# 2              10       False       0.570627       0.332273
# 3              11       False       0.440186       0.438816
# 4               9       False       0.835589       0.400342
# ..            ...         ...            ...            ...
# 594            13        True       0.247066       0.551339
# 595            13        True       0.150987       0.728024
# 596            13        True       0.405914       0.509498
# 597            13        True       0.078704       0.695581
# 598            13        True       0.381667       0.604586
#
# [599 rows x 13 columns]

# %%
len(final_rating_df)
# Out:
# 599

# %%
final_rating_df.Team_A_rating.isna().sum()
# Out:
# 3

# %%
final_rating_df=final_rating_df.dropna()

# %%
final_rating_df.Team_A_rating.isna().sum()
# Out:
# 0

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %%
final_rating_df.keys()
# Out:
# Index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Team B',
#        'Team A', 'Team A Score', 'Team_A_win', 'Team B Score', 'Team_B_win',
#        'Team_A_rating', 'Team_B_rating'],
#       dtype='object')

# %%
scaler = StandardScaler()
scaler_A = StandardScaler()
scaler_B = StandardScaler()

scaler.fit(pd.concat([final_rating_df.Team_A_rating, final_rating_df.Team_B_rating]).to_numpy().reshape(-1,1))
scaler_A.fit(final_rating_df.Team_A_rating.to_numpy().reshape(-1,1))
scaler_B.fit(final_rating_df.Team_B_rating.to_numpy().reshape(-1,1))
# Out:
# StandardScaler()

# %%
print("mean of ratings:", scaler.mean_)
print("variance of ratings:", scaler.var_)

print("mean of team A ratings:", scaler_A.mean_)
print("variance of team B ratings:", scaler_A.var_)

print("mean of team B ratings:", scaler_B.mean_)
print("variance of team B ratings:", scaler_B.var_)
# Out:
# mean of ratings: [0.47004915]
# variance of ratings: [0.04085538]
# mean of team A ratings: [0.49947378]
# variance of team B ratings: [0.04964091]
# mean of team B ratings: [0.44062452]
# variance of team B ratings: [0.03033823]

# %%
alpha = 0.3  # Opacity of scatter plot

# %%
plt.figure(figsize=(14,6))
#plt.subplot(1, 2, 1)  # row 1, column 2, count 1

plt.scatter(
    final_rating_df[final_rating_df.Team_A_win == True].Team_A_rating,
    final_rating_df[final_rating_df.Team_A_win == True].Team_B_rating,
    c="blue",
    alpha=alpha,
    label = "A win"
)

plt.scatter(
    final_rating_df[final_rating_df.Team_A_win == False].Team_A_rating,
    final_rating_df[final_rating_df.Team_A_win == False].Team_B_rating,
    c="red",
    alpha=alpha,
    label= "B win"
)
plt.plot(range(0,2), range(0,2), linestyle="dotted", color="grey", label="A rating = B rating")
plt.xlabel("Team A rating")
plt.ylabel("Team B rating")

# using subplot function and creating plot two
# row 1, column 2, count 2
# plt.subplot(1, 2, 2)
 
# plt.scatter(
#     scaler.transform(final_rating_df[final_rating_df.Team_A_win == True].Team_A_rating.to_numpy().reshape(-1,1)),
#     scaler.transform(final_rating_df[final_rating_df.Team_A_win == True].Team_B_rating.to_numpy().reshape(-1,1)),
#     c="blue",
#     alpha=alpha,
#     label="A win"
# )

# plt.scatter(
#     scaler.transform(final_rating_df[final_rating_df.Team_A_win == False].Team_A_rating.to_numpy().reshape(-1,1)),
#     scaler.transform(final_rating_df[final_rating_df.Team_A_win == False].Team_B_rating.to_numpy().reshape(-1,1)),
#     c="red",
#     alpha=alpha,
#     label ="B win"
# )

# plt.plot(range(-4,5), range(-4,5), linestyle="dotted", color="grey", label="A rating = B rating")
# plt.legend(loc="upper center", bbox_to_anchor=(1.2, 1))

# plt.xlabel("Team A rating scaled")
# plt.ylabel("Team B rating scaled")
 
plt.show()

# %%
print("mean of team A win:", np.mean(final_rating_df.Team_A_win))
print("mean of team B win:", np.mean(final_rating_df.Team_B_win))
# Out:
# mean of team A win: 0.6023489932885906
# mean of team B win: 0.3976510067114094

# %%
lr = LogisticRegression()
X = final_rating_df[["Team_A_rating", "Team_B_rating"]]
y = final_rating_df.Team_A_win.to_numpy().reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, stratify=y)

# %%
lr.fit(X_train, y_train)
pred = lr.predict(X_test)
acc = accuracy_score(y_test, pred)
print("mean of true value:", np.mean(y_test))
print("mean of prediction:", np.mean(pred))
print("Accuracy:", acc)
# Out:
# mean of true value: 0.6040268456375839
# mean of prediction: 0.697986577181208
# Accuracy: 0.8791946308724832
# c:\Users\parab\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
cm = confusion_matrix(y_test, pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()

# %% [markdown]
# Before chams 2022

# %%
chams_2022_team_rating = final_rating_df.loc[final_rating_df["Tournament"]=="Valorant Champions 2022"]

# %%
chams_2022_team_rating
# Out:
#                 Tournament        Stage           Match Type  \
# 0  Valorant Champions 2022  Group Stage          Opening (B)
# 1  Valorant Champions 2022  Group Stage          Opening (B)
# 2  Valorant Champions 2022  Group Stage         Winner's (B)
# 3  Valorant Champions 2022  Group Stage          Opening (C)
# 4  Valorant Champions 2022  Group Stage         Winner's (D)
# 5  Valorant Champions 2022  Group Stage      Elimination (B)
# 6  Valorant Champions 2022  Group Stage         Winner's (C)
# 7  Valorant Champions 2022     Playoffs  Upper Quarterfinals
# 8  Valorant Champions 2022     Playoffs        Lower Round 2
# 9  Valorant Champions 2022     Playoffs          Lower Final
#
#                       Match Name       Map          Team B           Team A  \
# 0          ZETA DIVISION vs LOUD  Fracture            LOUD    ZETA DIVISION
# 1   OpTic Gaming vs BOOM Esports  Fracture    BOOM Esports     OpTic Gaming
# 2           OpTic Gaming vs LOUD  Fracture            LOUD     OpTic Gaming
# 3         XSET vs XERXIA Esports  Fracture  XERXIA Esports             XSET
# 4             DRX vs 100 Thieves  Fracture     100 Thieves              DRX
# 5  BOOM Esports vs ZETA DIVISION  Fracture   ZETA DIVISION     BOOM Esports
# 6        FunPlus Phoenix vs XSET  Fracture            XSET  FunPlus Phoenix
# 7                 XSET vs FNATIC  Fracture          FNATIC             XSET
# 8                  DRX vs FNATIC  Fracture          FNATIC              DRX
# 9            OpTic Gaming vs DRX  Fracture             DRX     OpTic Gaming
#
#    Team A Score  Team_A_win  Team B Score  Team_B_win  Team_A_rating  \
# 0             9       False            13        True       0.342734
# 1            13        True             3       False       0.646165
# 2            13        True            10       False       0.570627
# 3            13        True            11       False       0.440186
# 4            13        True             9       False       0.835589
# 5             2       False            13        True       0.088758
# 6            13        True             4       False       0.569178
# 7            13        True            11       False       0.510875
# 8            13        True             9       False       0.434135
# 9             8       False            13        True       0.496675
#
#    Team_B_rating
# 0       0.515243
# 1       0.135679
# 2       0.332273
# 3       0.438816
# 4       0.400342
# 5       0.617300
# 6       0.242689
# 7       0.468498
# 8       0.442067
# 9       0.496811

# %%
lr2 = LogisticRegression()
W_train = final_rating_df[final_rating_df["Tournament"] != "Valorant Champions 2022"][["Team_A_rating", "Team_B_rating"]]
z_train = final_rating_df[final_rating_df["Tournament"] != "Valorant Champions 2022"].Team_A_win.to_numpy().reshape(-1,1)

W_test = chams_2022_team_rating[["Team_A_rating", "Team_B_rating"]]
z_test = chams_2022_team_rating.Team_A_win.to_numpy().reshape(-1,1)

# %%
print(len(W_train), len(W_test))
# Out:
# 586 10

# %%
lr2.fit(W_train, z_train)
pred2 = lr2.predict(W_test)
acc2 = accuracy_score(z_test, pred2)
print("mean of true values:", np.mean(z_test))
print("mean of prediction:", np.mean(pred2))
print("Accuracy:", acc2)
# Out:
# mean of true values: 0.7
# mean of prediction: 0.8
# Accuracy: 0.9
# c:\Users\parab\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
cm2 = confusion_matrix(z_test, pred2, labels=lr2.classes_)
disp2 = ConfusionMatrixDisplay(confusion_matrix=cm2,
                              display_labels=lr2.classes_)
disp2.plot()
plt.show()
