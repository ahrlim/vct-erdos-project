# %% [markdown]
# #### In this notebook, I will do logistic regression on ratings of each role of teams.
#
# Ratings are from players_stats.csv files.  Player's rating of each match is recorded in this file.
#
# <u> Previously... </u>
#
# As an expriment, I did team rating analysis before: I computed a team rating by adding 5 players' individual rating.
# The predictors/features that I used here were "team A rating" and "team B rating" and the target was "team A win", if team A win, it's True, False otherwise.
# LinearRegression did quite well on both traing and test set, but it's expected because there is a data leakage in somesense: if your team players perform well, then they will get higher rating and most likely to win.
#
# To prevent this kind of data leakage, I decided to use earlier tournaments of the year to compute team rating.
# Goal: predict game results in "Valorant Champions 2023" tournament by using teams' ratings from earlier tournaments.
#     There were total 746 games(train set) before "Valorant Champions 2023" and total 84 games(test set) in "Valorant Champions 2023"
# I did the following steps.
# - Step 1:  Compute team rating by taking average of team's previous ratings by map.
# - Step 2:  Train a LogisticRegression model on earlier tournaments (746 games).
# - Step 3:  Predict game results for 84 games in "Valorant Champions 2023" with team rating input computed in step 1.
#
# Unfortunately, the accuracy score and confusion matrix don't look great in this experiment.  You can find this analysis in "vct_2023_team_rating.ipynb".
#
#
# <u> In this notebook... </u>
#
# Instead of simply summing 5 players ratings, I will compute each team's duelist, controller, initiator, sentinel rating.
#
# For example, let's say team "Fruits" had a game and in this game,
#
# - "apple" and "pineapple" played a duelist and their ratings were 1.5 and 1.22, respectively,
# - "orange" played a controller and its rating was 1.7,
# - "grapefruit" played an initiator and its rating was 1.5 and
# - "banana" played a sentinel and its rating was 1.65.
#
# Then team "Fruits"'s <u>*role ratings*</u> data for this game is:
# - duelist rating: 2.72 (which is the sum of 1.5 and 1.22)
# - controller rating: 1.7
# - initiator rating: 1.5
# - sentinel rating: 1.65
#
#
# In this notebook, I worked around with players_stats, overview, maps_scores files and got a dataframe with the processed <u>*role ratings*</u> I just explained above.
#
# I first did LogisticRegression and took a look into coefficients of the model.  Coefficients were all quite different which would imply some roles are more important than others.
# Naturally, I got more curious about how these coefficients vary depend on a map.  I did a polynomial logistic regression and it showed that coefficients change when a map changes.
# In this polynomial regression, I used each <u>*role ratings*</u> together with <u>*interation terms between role ratings and maps*</u>.

# %%
import pandas as pd
import numpy as np
from IPython.display import HTML

# %%
def side_by_side(*dfs):
    html = '<div style="display:flex">'
    for df in dfs:
        html += '<div style="margin-right: 2em">'
        html += df.to_html()
        html += '</div>'
    html += '</div>'
    display(HTML(html))

# %%
roles = {"duelist": {"jett", "phoenix", "reyna", "raze", "yoru", "neon", "iso"},
             "initiator": {"sova", "breach", "skye", "kayo", "fade", "gekko"},
             "controller": {"brimstone", "omen", "viper", "astra", "harbor"},
             "sentinel": {"cypher", "sage", "killjoy", "chamber", "deadlock"}}
allagents = set()
for role, l in roles.items():
    allagents = allagents.union(set(l))

duelists = roles["duelist"]
initiators = roles["initiator"]
controllers = roles["controller"]
sentinels = roles["sentinel"]

# %%
players_stats = pd.read_csv("../../vct-erdos-project/data/vct_2023/players_stats/players_stats.csv")
overview = pd.read_csv("../../vct-erdos-project/data/vct_2023/matches/overview.csv")
maps_scores = pd.read_csv("../../vct-erdos-project/data/vct_2023/matches/maps_scores.csv")

# %%
players_stats = players_stats[['Tournament', 'Stage', 'Match Type', 'Player', 'Team', 'Agents', 'Rating']]

players_stats["Agents"] = players_stats["Agents"].apply(lambda x: x.replace(" ", ""))

players_stats = players_stats[players_stats.Agents.isin(allagents)]
players_stats
# Out:
#                                               Tournament       Stage  \
# 0      Champions Tour 2023: Americas Last Chance Qual...  Main Event
# 1      Champions Tour 2023: Americas Last Chance Qual...  Main Event
# 3      Champions Tour 2023: Americas Last Chance Qual...  Main Event
# 4      Champions Tour 2023: Americas Last Chance Qual...  Main Event
# 5      Champions Tour 2023: Americas Last Chance Qual...  Main Event
# ...                                                  ...         ...
# 10509     Champions Tour 2023: Champions China Qualifier  All Stages
# 10510     Champions Tour 2023: Champions China Qualifier  All Stages
# 10511     Champions Tour 2023: Champions China Qualifier  All Stages
# 10513     Champions Tour 2023: Champions China Qualifier  All Stages
# 10514     Champions Tour 2023: Champions China Qualifier  All Stages
#
#             Match Type   Player             Team     Agents  Rating
# 0        Upper Round 1   Melser      KRÜ Esports  brimstone    1.14
# 1        Upper Round 1   Melser      KRÜ Esports       omen    1.12
# 3        Upper Round 1  DaveeyS      KRÜ Esports    killjoy    1.29
# 4        Upper Round 1   keznit      KRÜ Esports       raze    1.24
# 5        Upper Round 1    Klaus      KRÜ Esports       skye    1.25
# ...                ...      ...              ...        ...     ...
# 10509  All Match Types    Biank  Bilibili Gaming     harbor     NaN
# 10510  All Match Types    Biank  Bilibili Gaming       skye     NaN
# 10511  All Match Types    Biank  Bilibili Gaming       sova     NaN
# 10513  All Match Types     whzy  Bilibili Gaming       jett     NaN
# 10514  All Match Types     whzy  Bilibili Gaming       raze     NaN
#
# [7767 rows x 7 columns]

# %%
players_stats["Rating"].isna().sum()
# Out:
# 449

# %%
players_stats.loc[:,"Rating"] = players_stats.groupby(["Player", "Team", "Agents"])["Rating"]\
                                .transform(lambda x: x.fillna(x.mean()))\

players_stats.Rating.isna().sum()
# Out:
# 111

# %%
players_stats["Rating"] = players_stats.groupby(["Player", "Team"])["Rating"]\
                            .transform(lambda x: x.fillna(x.mean()))\
                            
                            
players_stats.Rating.isna().sum()
# Out:
# 34

# %%
players_stats["Rating"] = players_stats.groupby(["Team"])["Rating"]\
                            .transform(lambda x: x.fillna(x.mean()))\
                            
                            
players_stats.Rating.isna().sum()
# Out:
# 0

# %%
players_stats.sort_values(by=["Rating"], ascending=False).head(10)
# Out:
#                                              Tournament              Stage  \
# 3264                   Champions Tour 2023: EMEA League     Regular Season
# 3180                   Champions Tour 2023: EMEA League     Regular Season
# 7707                Champions Tour 2023: Pacific League        League Play
# 531   Champions Tour 2023: Pacific Last Chance Quali...         Main Event
# 3314                   Champions Tour 2023: EMEA League     Regular Season
# 9355     Champions Tour 2023: Champions China Qualifier  Preliminary Stage
# 6704               Champions Tour 2023: Americas League     Regular Season
# 141   Champions Tour 2023: Americas Last Chance Qual...         Main Event
# 6126               Champions Tour 2023: Americas League     Regular Season
# 7238                Champions Tour 2023: Pacific League           Playoffs
#
#             Match Type   Player            Team   Agents  Rating
# 3264            Week 2   Jamppi     Team Liquid     skye    2.29
# 3180            Week 1     Sayf     Team Liquid     raze    2.25
# 7707            Week 3   xffero  Rex Regum Qeon     sova    2.10
# 531        Lower Final     invy     Team Secret     kayo    2.08
# 3314            Week 3     Shao   Natus Vincere     fade    2.04
# 9355           Round 1  Septem7   Shenzhen NTER  killjoy    1.98
# 6704            Week 7   Victor     NRG Esports     raze    1.97
# 141        Upper Final     NagZ     KRÜ Esports    viper    1.96
# 6126            Week 2      s0m     NRG Esports    viper    1.96
# 7238  Upper Semifinals     BuZz             DRX     raze    1.95

# %%
ind1 = overview["Side"] == "both"
ind2 = overview["Map"] != "All Maps"
ind = ind1 & ind2

overview = overview[ind]
overview = overview[['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Player',
       'Team', 'Agents']]
overview
# Out:
#                                    Tournament        Stage   Match Type  \
# 0                     Valorant Champions 2023  Group Stage  Opening (D)
# 3                     Valorant Champions 2023  Group Stage  Opening (D)
# 6                     Valorant Champions 2023  Group Stage  Opening (D)
# 9                     Valorant Champions 2023  Group Stage  Opening (D)
# 12                    Valorant Champions 2023  Group Stage  Opening (D)
# ...                                       ...          ...          ...
# 34929  Champions Tour 2023: Lock-In Sao Paulo     Playoffs  Grand Final
# 34932  Champions Tour 2023: Lock-In Sao Paulo     Playoffs  Grand Final
# 34935  Champions Tour 2023: Lock-In Sao Paulo     Playoffs  Grand Final
# 34938  Champions Tour 2023: Lock-In Sao Paulo     Playoffs  Grand Final
# 34941  Champions Tour 2023: Lock-In Sao Paulo     Playoffs  Grand Final
#
#                          Match Name       Map     Player         Team   Agents
# 0      Team Liquid vs Natus Vincere  Fracture       nAts  Team Liquid    viper
# 3      Team Liquid vs Natus Vincere  Fracture       Sayf  Team Liquid   breach
# 6      Team Liquid vs Natus Vincere  Fracture    soulcas  Team Liquid    astra
# 9      Team Liquid vs Natus Vincere  Fracture     Jamppi  Team Liquid     neon
# 12     Team Liquid vs Natus Vincere  Fracture     Redgar  Team Liquid     sova
# ...                             ...       ...        ...          ...      ...
# 34929                LOUD vs FNATIC    Icebox      Derke       FNATIC     jett
# 34932                LOUD vs FNATIC    Icebox    Boaster       FNATIC    viper
# 34935                LOUD vs FNATIC    Icebox    Alfajer       FNATIC  killjoy
# 34938                LOUD vs FNATIC    Icebox        Leo       FNATIC     sova
# 34941                LOUD vs FNATIC    Icebox  Chronicle       FNATIC     sage
#
# [8300 rows x 8 columns]

# %%
rating_df = overview.merge(players_stats, on=['Tournament', 'Stage', 'Match Type', 'Player', "Agents", "Team"], how="left")

rating_df["Rating"] = rating_df.groupby(['Tournament', 'Stage', "Player"])["Rating"]\
                        .transform(lambda x: x.fillna(x.mean()))

rating_df.isna().sum()
# Out:
# Tournament    0
# Stage         0
# Match Type    0
# Match Name    0
# Map           0
# Player        0
# Team          0
# Agents        0
# Rating        3
# dtype: int64

# %%
rating_df["Rating"] = rating_df.groupby(['Tournament', 'Stage', 'Match Type', "Team"])["Rating"]\
                        .transform(lambda x: x.fillna(x.mean()))\

rating_df.isna().sum()
# Out:
# Tournament    0
# Stage         0
# Match Type    0
# Match Name    0
# Map           0
# Player        0
# Team          0
# Agents        0
# Rating        0
# dtype: int64

# %%
rating_df
# Out:
#                                   Tournament        Stage   Match Type  \
# 0                    Valorant Champions 2023  Group Stage  Opening (D)
# 1                    Valorant Champions 2023  Group Stage  Opening (D)
# 2                    Valorant Champions 2023  Group Stage  Opening (D)
# 3                    Valorant Champions 2023  Group Stage  Opening (D)
# 4                    Valorant Champions 2023  Group Stage  Opening (D)
# ...                                      ...          ...          ...
# 8295  Champions Tour 2023: Lock-In Sao Paulo     Playoffs  Grand Final
# 8296  Champions Tour 2023: Lock-In Sao Paulo     Playoffs  Grand Final
# 8297  Champions Tour 2023: Lock-In Sao Paulo     Playoffs  Grand Final
# 8298  Champions Tour 2023: Lock-In Sao Paulo     Playoffs  Grand Final
# 8299  Champions Tour 2023: Lock-In Sao Paulo     Playoffs  Grand Final
#
#                         Match Name       Map     Player         Team   Agents  \
# 0     Team Liquid vs Natus Vincere  Fracture       nAts  Team Liquid    viper
# 1     Team Liquid vs Natus Vincere  Fracture       Sayf  Team Liquid   breach
# 2     Team Liquid vs Natus Vincere  Fracture    soulcas  Team Liquid    astra
# 3     Team Liquid vs Natus Vincere  Fracture     Jamppi  Team Liquid     neon
# 4     Team Liquid vs Natus Vincere  Fracture     Redgar  Team Liquid     sova
# ...                            ...       ...        ...          ...      ...
# 8295                LOUD vs FNATIC    Icebox      Derke       FNATIC     jett
# 8296                LOUD vs FNATIC    Icebox    Boaster       FNATIC    viper
# 8297                LOUD vs FNATIC    Icebox    Alfajer       FNATIC  killjoy
# 8298                LOUD vs FNATIC    Icebox        Leo       FNATIC     sova
# 8299                LOUD vs FNATIC    Icebox  Chronicle       FNATIC     sage
#
#       Rating
# 0      1.260
# 1      0.960
# 2      0.950
# 3      0.890
# 4      0.690
# ...      ...
# 8295   1.100
# 8296   0.950
# 8297   0.960
# 8298   1.195
# 8299   0.840
#
# [8300 rows x 9 columns]

# %%
duelist_r = [row[1].Rating if row[1].Agents in duelists else 0 for row in rating_df[["Agents", "Rating"]].iterrows()]
controller_r = [row[1].Rating if row[1].Agents in controllers else 0 for row in rating_df[["Agents", "Rating"]].iterrows()]
initiator_r = [row[1].Rating if row[1].Agents in initiators else 0 for row in rating_df[["Agents", "Rating"]].iterrows()]
sentinel_r = [row[1].Rating if row[1].Agents in sentinels else 0 for row in rating_df[["Agents", "Rating"]].iterrows()]

# %%
role_rating = {"duelist_r":duelist_r\
                ,"controller_r": controller_r\
                ,"initiator_r":initiator_r\
                ,"sentinel_r":sentinel_r}

for role, rating_list in role_rating.items():
    rating_df[role] = rating_list

rating_df
# Out:
#                                   Tournament        Stage   Match Type  \
# 0                    Valorant Champions 2023  Group Stage  Opening (D)
# 1                    Valorant Champions 2023  Group Stage  Opening (D)
# 2                    Valorant Champions 2023  Group Stage  Opening (D)
# 3                    Valorant Champions 2023  Group Stage  Opening (D)
# 4                    Valorant Champions 2023  Group Stage  Opening (D)
# ...                                      ...          ...          ...
# 8295  Champions Tour 2023: Lock-In Sao Paulo     Playoffs  Grand Final
# 8296  Champions Tour 2023: Lock-In Sao Paulo     Playoffs  Grand Final
# 8297  Champions Tour 2023: Lock-In Sao Paulo     Playoffs  Grand Final
# 8298  Champions Tour 2023: Lock-In Sao Paulo     Playoffs  Grand Final
# 8299  Champions Tour 2023: Lock-In Sao Paulo     Playoffs  Grand Final
#
#                         Match Name       Map     Player         Team   Agents  \
# 0     Team Liquid vs Natus Vincere  Fracture       nAts  Team Liquid    viper
# 1     Team Liquid vs Natus Vincere  Fracture       Sayf  Team Liquid   breach
# 2     Team Liquid vs Natus Vincere  Fracture    soulcas  Team Liquid    astra
# 3     Team Liquid vs Natus Vincere  Fracture     Jamppi  Team Liquid     neon
# 4     Team Liquid vs Natus Vincere  Fracture     Redgar  Team Liquid     sova
# ...                            ...       ...        ...          ...      ...
# 8295                LOUD vs FNATIC    Icebox      Derke       FNATIC     jett
# 8296                LOUD vs FNATIC    Icebox    Boaster       FNATIC    viper
# 8297                LOUD vs FNATIC    Icebox    Alfajer       FNATIC  killjoy
# 8298                LOUD vs FNATIC    Icebox        Leo       FNATIC     sova
# 8299                LOUD vs FNATIC    Icebox  Chronicle       FNATIC     sage
#
#       Rating  duelist_r  controller_r  initiator_r  sentinel_r
# 0      1.260       0.00          1.26        0.000        0.00
# 1      0.960       0.00          0.00        0.960        0.00
# 2      0.950       0.00          0.95        0.000        0.00
# 3      0.890       0.89          0.00        0.000        0.00
# 4      0.690       0.00          0.00        0.690        0.00
# ...      ...        ...           ...          ...         ...
# 8295   1.100       1.10          0.00        0.000        0.00
# 8296   0.950       0.00          0.95        0.000        0.00
# 8297   0.960       0.00          0.00        0.000        0.96
# 8298   1.195       0.00          0.00        1.195        0.00
# 8299   0.840       0.00          0.00        0.000        0.84
#
# [8300 rows x 13 columns]

# %%
rating_df.isna().sum()
# Out:
# Tournament      0
# Stage           0
# Match Type      0
# Match Name      0
# Map             0
# Player          0
# Team            0
# Agents          0
# Rating          0
# duelist_r       0
# controller_r    0
# initiator_r     0
# sentinel_r      0
# dtype: int64

# %%
rating_df_by_roles_temp =\
    rating_df.groupby(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Team'])\
        [["Rating", "duelist_r", "controller_r", "initiator_r", "sentinel_r"]]\
        .agg("sum").reset_index()

# %%
maps_scores["Team_A_win"] = maps_scores["Team A Score"] > maps_scores["Team B Score"]
maps_scores["Team_B_win"] = maps_scores["Team B Score"] > maps_scores["Team A Score"]

maps_scores.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2023  Group Stage  Opening (D)
# 1  Valorant Champions 2023  Group Stage  Opening (D)
# 2  Valorant Champions 2023  Group Stage  Opening (D)
# 3  Valorant Champions 2023  Group Stage  Opening (D)
# 4  Valorant Champions 2023  Group Stage  Opening (D)
#
#                      Match Name       Map       Team A  Team A Score  \
# 0  Team Liquid vs Natus Vincere  Fracture  Team Liquid            11
# 1  Team Liquid vs Natus Vincere      Bind  Team Liquid            15
# 2                   DRX vs LOUD     Lotus          DRX            13
# 3                   DRX vs LOUD     Split          DRX            13
# 4                   DRX vs LOUD    Ascent          DRX            13
#
#    Team A Attacker Score  Team A Defender Score  Team A Overtime Score  \
# 0                      6                      5                    NaN
# 1                      7                      5                    3.0
# 2                      7                      5                    1.0
# 3                      8                      5                    NaN
# 4                      8                      5                    NaN
#
#           Team B  Team B Score  Team B Attacker Score  Team B Defender Score  \
# 0  Natus Vincere            13                      7                      6
# 1  Natus Vincere            17                      7                      5
# 2           LOUD            15                      7                      5
# 3           LOUD             6                      2                      4
# 4           LOUD             8                      4                      4
#
#    Team B Overtime Score Duration  Team_A_win  Team_B_win
# 0                    NaN  1:18:55       False        True
# 1                    5.0  1:22:57       False        True
# 2                    3.0  1:17:19       False        True
# 3                    NaN    47:47        True       False
# 4                    NaN      NaN        True       False

# %%
maps_scores = maps_scores[["Tournament", "Stage", "Match Type", "Match Name", "Map", "Team A", "Team A Score", "Team_A_win", "Team B", "Team B Score", "Team_B_win"]]

# %%
rating_df_by_roles_temp.keys()
# Out:
# Index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Team',
#        'Rating', 'duelist_r', 'controller_r', 'initiator_r', 'sentinel_r'],
#       dtype='object')

# %%
rating_df_by_roles_2023 =\
maps_scores.set_index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Team A'])\
                  .join(rating_df_by_roles_temp\
                        .rename(columns={\
                              "Team":"Team A",
                              "Rating":"Team_A_rating",
                              "duelist_r":"A_duel_r",
                              "controller_r":"A_cont_r",
                              "initiator_r":"A_init_r",
                              "sentinel_r":"A_sent_r"
                              })\
                        .set_index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Team A'])\
                  )\
                  .reset_index()\
                  .set_index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Team B'])\
                  .join(rating_df_by_roles_temp\
                        .rename(columns={\
                              "Team":"Team B",
                              "Rating":"Team_B_rating",
                              "duelist_r":"B_duel_r",
                              "controller_r":"B_cont_r",
                              "initiator_r":"B_init_r",
                              "sentinel_r":"B_sent_r"
                            })\
                        .set_index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Team B'])\
                  )\
                  .reset_index()\

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %%
features = ["A_duel_r", "A_cont_r", "A_init_r", "A_sent_r",
            "B_duel_r", "B_cont_r", "B_init_r", "B_sent_r"]
X = rating_df_by_roles_2023[features]
y = rating_df_by_roles_2023["Team_A_win"].to_numpy().reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, stratify=y, random_state=1)

# %%
# sanity check
assert len(X_train) == len(y_train), "X and y sizes are different"
assert len(X_test) == len(y_test), "X and y sizes are different"

# %%
lr = LogisticRegression()

# %%
lr.fit(X_train, y_train)
pred = lr.predict(X_test)
acc = accuracy_score(y_test, pred)
print("mean of true value:", np.mean(y_test))
print("mean of prediction:", np.mean(pred))
print("Accuracy:", acc)
# Out:
# mean of true value: 0.5096153846153846
# mean of prediction: 0.5528846153846154
# Accuracy: 0.8798076923076923
# /Users/ahram/miniforge3/envs/vct/lib/python3.10/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
lr.coef_
# Out:
# array([[ 1.69396458,  1.54651472,  1.33528804,  1.90713237, -1.67593836,
#         -1.90207293, -1.65382624, -2.07438117]])

# %%
print(np.mean(lr.coef_[0][:4]))
print(np.mean(lr.coef_[0][4:]))
# Out:
# 1.6207249253093339
# -1.8265546761587297

# %%
# Let's test by map

features = ["A_duel_r", "A_cont_r", "A_init_r", "A_sent_r",
            "B_duel_r", "B_cont_r", "B_init_r", "B_sent_r"]

maps = rating_df_by_roles_2023["Map"].unique()
analysis_df = pd.DataFrame()
analysis_df["map"] = maps
analysis_dictionary = {\
    "played_time":[],
    "mean_y_train":[],
    "mean_y_test":[],
    "mean_train_pred":[],
    "mean_test_pred":[],
    "train_acc":[],
    "test_acc" :[],
    "coefficients":[]
    }\

for map in maps:
    X = rating_df_by_roles_2023[rating_df_by_roles_2023["Map"] == map][features]
    y = rating_df_by_roles_2023[rating_df_by_roles_2023["Map"] == map]["Team_A_win"]
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, stratify=y, random_state=1)

    logr = LogisticRegression()
    logr.fit(X_train, y_train)
    train_pred = logr.predict(X_train)
    pred = logr.predict(X_test)
    
    
    analysis_dictionary["played_time"].append(len(rating_df_by_roles_2023[rating_df_by_roles_2023["Map"] == map]))
    analysis_dictionary["mean_y_train"].append(np.mean(y_train))
    analysis_dictionary["mean_y_test"].append(np.mean(y_test))
    analysis_dictionary["mean_train_pred"].append(np.mean(train_pred))
    analysis_dictionary["mean_test_pred"].append(np.mean(pred))
    analysis_dictionary["train_acc"].append(accuracy_score(y_train, train_pred))
    analysis_dictionary["test_acc"].append(accuracy_score(y_test, pred))
    analysis_dictionary["coefficients"].append(np.round(logr.coef_[0],2))

for feature_name, lst in analysis_dictionary.items():
    analysis_df[feature_name] = lst

analysis_df
# Out:
#         map  played_time  mean_y_train  mean_y_test  mean_train_pred  \
# 0  Fracture           93      0.536232     0.541667         0.579710
# 1      Bind           81      0.433333     0.428571         0.416667
# 2     Lotus          134      0.530000     0.529412         0.490000
# 3     Split          129      0.531250     0.545455         0.572917
# 4    Ascent          131      0.540816     0.545455         0.561224
# 5     Pearl          108      0.555556     0.555556         0.580247
# 6     Haven          119      0.449438     0.433333         0.415730
# 7    Icebox           35      0.423077     0.444444         0.423077
#
#    mean_test_pred  train_acc  test_acc  \
# 0        0.625000   0.898551  0.833333
# 1        0.333333   0.916667  0.619048
# 2        0.441176   0.860000  0.794118
# 3        0.545455   0.895833  0.939394
# 4        0.545455   0.816327  0.818182
# 5        0.666667   0.827160  0.740741
# 6        0.433333   0.853933  0.800000
# 7        0.444444   1.000000  1.000000
#
#                                         coefficients
# 0  [1.37, 1.52, 0.77, 0.99, -0.83, -1.3, -0.85, -...
# 1  [0.77, 0.96, 0.84, 1.5, -0.34, -2.1, -0.5, -0.26]
# 2  [1.17, 0.56, 0.69, 1.57, -0.69, -1.9, -0.63, -...
# 3  [1.16, 0.49, 0.93, 0.64, -1.67, -1.75, -1.58, ...
# 4  [0.46, 1.75, 1.97, 0.73, -0.91, -0.51, -0.75, ...
# 5  [1.04, 1.24, 1.06, 1.42, -0.95, -1.14, -1.01, ...
# 6  [0.6, 1.31, 1.9, 0.39, -1.65, -0.73, -1.26, -1...
# 7  [0.42, 1.26, -0.04, 0.61, -1.42, -0.21, -0.83,...

# %%
coef_list = ["A_duel_coef", "A_cont_coef", "A_init_coef", "A_sent_coef",
            "B_duel_coef", "B_cont_coef", "B_init_coef", "B_sent_coef"]

# %%
for i in range(len(coef_list)):
    analysis_df[coef_list[i]] = analysis_df.coefficients.apply(lambda l: l[i])

analysis_df[["map"]+coef_list]
# Out:
#         map  A_duel_coef  A_cont_coef  A_init_coef  A_sent_coef  B_duel_coef  \
# 0  Fracture         1.37         1.52         0.77         0.99        -0.83
# 1      Bind         0.77         0.96         0.84         1.50        -0.34
# 2     Lotus         1.17         0.56         0.69         1.57        -0.69
# 3     Split         1.16         0.49         0.93         0.64        -1.67
# 4    Ascent         0.46         1.75         1.97         0.73        -0.91
# 5     Pearl         1.04         1.24         1.06         1.42        -0.95
# 6     Haven         0.60         1.31         1.90         0.39        -1.65
# 7    Icebox         0.42         1.26        -0.04         0.61        -1.42
#
#    B_cont_coef  B_init_coef  B_sent_coef
# 0        -1.30        -0.85        -1.53
# 1        -2.10        -0.50        -0.26
# 2        -1.90        -0.63        -1.43
# 3        -1.75        -1.58        -1.64
# 4        -0.51        -0.75        -1.30
# 5        -1.14        -1.01        -1.04
# 6        -0.73        -1.26        -1.08
# 7        -0.21        -0.83        -0.90

# %% [markdown]
# `We can see here that coefficients varies depending on map.`  features_2 will be role ratings plus map information.

# %%
features_2 = ["Map"] + features

# %%
W = rating_df_by_roles_2023[features_2]
z = rating_df_by_roles_2023["Team_A_win"]

# %%
W = pd.get_dummies(W, columns=["Map"], dtype=int)

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline

# %%
W.keys()
# Out:
# Index(['A_duel_r', 'A_cont_r', 'A_init_r', 'A_sent_r', 'B_duel_r', 'B_cont_r',
#        'B_init_r', 'B_sent_r', 'Map_Ascent', 'Map_Bind', 'Map_Fracture',
#        'Map_Haven', 'Map_Icebox', 'Map_Lotus', 'Map_Pearl', 'Map_Split'],
#       dtype='object')

# %%
rating_features = ['A_duel_r', 'A_cont_r', 'A_init_r', 'A_sent_r', 'B_duel_r', 'B_cont_r',
       'B_init_r', 'B_sent_r']
map_features = ['Map_Ascent', 'Map_Bind', 'Map_Fracture',
       'Map_Haven', 'Map_Icebox', 'Map_Lotus', 'Map_Pearl', 'Map_Split']

# %%
interaction_features = []  # Use this list to select interaction terms and drop "Map_Ascent", "Map_Bind", ...
for map in map_features:
    for rating in rating_features:
        W[f"{map}_{rating}"] = W[map]*W[rating]
        interaction_features.append(f"{map}_{rating}")

# %%
W_interaction = W[rating_features + interaction_features]

# %%
W_train, W_test, z_train, z_test = train_test_split(W_interaction, z, shuffle=True, stratify=z, random_state=1)

# %%
poly_logr = LogisticRegression()
poly_logr.fit(W_train, z_train)
poly_train_pred = poly_logr.predict(W_train)
poly_test_pred = poly_logr.predict(W_test)
poly_train_acc = accuracy_score(z_train, poly_train_pred)
poly_test_acc = accuracy_score(z_test, poly_test_pred)

print("Train set true mean:", np.mean(z_train))
print("Train prediction mean:", np.mean(poly_train_pred))
print("Test set true mean:", np.mean(z_test))
print("Test prediction mean:", np.mean(poly_test_pred))
print("Train accuracy:", poly_train_acc)
print("Test accuracy:", poly_test_acc)
# Out:
# Train set true mean: 0.5112540192926045
# Train prediction mean: 0.5209003215434084
# Test set true mean: 0.5096153846153846
# Test prediction mean: 0.5336538461538461
# Train accuracy: 0.842443729903537
# Test accuracy: 0.8605769230769231

# %%
poly_logr_coef = pd.DataFrame()
poly_logr_coef["feature_name"] = W_interaction.keys()
poly_logr_coef["coef"] = poly_logr.coef_[0]

# %%
side_by_side(poly_logr_coef[:8], poly_logr_coef[8:24], poly_logr_coef[24:40],  poly_logr_coef[40:56], poly_logr_coef[56:])
# Out:
# <div style="display:flex"><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>feature_name</th>
#       <th>coef</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>A_duel_r</td>
#       <td>1.387638</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>A_cont_r</td>
#       <td>1.571408</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>A_init_r</td>
#       <td>1.236617</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>A_sent_r</td>
#       <td>1.871970</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>B_duel_r</td>
#       <td>-1.602893</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>B_cont_r</td>
#       <td>-1.660232</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>B_init_r</td>
#       <td>-1.611142</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>B_sent_r</td>
#       <td>-1.987616</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>feature_name</th>
#       <th>coef</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>8</th>
#       <td>Map_Ascent_A_duel_r</td>
#       <td>-0.091224</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Map_Ascent_A_cont_r</td>
#       <td>0.306250</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Map_Ascent_A_init_r</td>
#       <td>0.365488</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Map_Ascent_A_sent_r</td>
#       <td>-0.497668</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Map_Ascent_B_duel_r</td>
#       <td>0.385476</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Map_Ascent_B_cont_r</td>
#       <td>-0.360618</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Map_Ascent_B_init_r</td>
#       <td>0.041009</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Map_Ascent_B_sent_r</td>
#       <td>-0.462264</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Map_Bind_A_duel_r</td>
#       <td>-0.043347</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Map_Bind_A_cont_r</td>
#       <td>-0.181862</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Map_Bind_A_init_r</td>
#       <td>0.445397</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Map_Bind_A_sent_r</td>
#       <td>0.664066</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Map_Bind_B_duel_r</td>
#       <td>0.344979</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Map_Bind_B_cont_r</td>
#       <td>-0.348911</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Map_Bind_B_init_r</td>
#       <td>-0.669154</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>Map_Bind_B_sent_r</td>
#       <td>0.459650</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>feature_name</th>
#       <th>coef</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>24</th>
#       <td>Map_Fracture_A_duel_r</td>
#       <td>0.652210</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>Map_Fracture_A_cont_r</td>
#       <td>0.658954</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>Map_Fracture_A_init_r</td>
#       <td>0.070718</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>Map_Fracture_A_sent_r</td>
#       <td>0.392985</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>Map_Fracture_B_duel_r</td>
#       <td>0.223034</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>Map_Fracture_B_cont_r</td>
#       <td>-0.744814</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>Map_Fracture_B_init_r</td>
#       <td>-0.539053</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>Map_Fracture_B_sent_r</td>
#       <td>-0.783882</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>Map_Haven_A_duel_r</td>
#       <td>-0.090979</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>Map_Haven_A_cont_r</td>
#       <td>0.647001</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>Map_Haven_A_init_r</td>
#       <td>0.526595</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>Map_Haven_A_sent_r</td>
#       <td>0.472032</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>Map_Haven_B_duel_r</td>
#       <td>-0.762333</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>Map_Haven_B_cont_r</td>
#       <td>0.353367</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>Map_Haven_B_init_r</td>
#       <td>-0.618490</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>Map_Haven_B_sent_r</td>
#       <td>-0.705105</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>feature_name</th>
#       <th>coef</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>40</th>
#       <td>Map_Icebox_A_duel_r</td>
#       <td>-0.303627</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>Map_Icebox_A_cont_r</td>
#       <td>0.595120</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>Map_Icebox_A_init_r</td>
#       <td>-0.238494</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>Map_Icebox_A_sent_r</td>
#       <td>0.034512</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>Map_Icebox_B_duel_r</td>
#       <td>-0.976057</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>Map_Icebox_B_cont_r</td>
#       <td>0.161332</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>Map_Icebox_B_init_r</td>
#       <td>-0.234251</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>Map_Icebox_B_sent_r</td>
#       <td>-0.223026</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>Map_Lotus_A_duel_r</td>
#       <td>0.554312</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>Map_Lotus_A_cont_r</td>
#       <td>-0.539022</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>Map_Lotus_A_init_r</td>
#       <td>0.072228</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>Map_Lotus_A_sent_r</td>
#       <td>0.404270</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>Map_Lotus_B_duel_r</td>
#       <td>-0.140191</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>Map_Lotus_B_cont_r</td>
#       <td>-0.447685</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>Map_Lotus_B_init_r</td>
#       <td>0.260924</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>Map_Lotus_B_sent_r</td>
#       <td>0.022826</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>feature_name</th>
#       <th>coef</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>56</th>
#       <td>Map_Pearl_A_duel_r</td>
#       <td>-0.155322</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>Map_Pearl_A_cont_r</td>
#       <td>0.000579</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>Map_Pearl_A_init_r</td>
#       <td>-0.396824</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>Map_Pearl_A_sent_r</td>
#       <td>0.161977</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>Map_Pearl_B_duel_r</td>
#       <td>0.090459</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>Map_Pearl_B_cont_r</td>
#       <td>-0.092376</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>Map_Pearl_B_init_r</td>
#       <td>0.327680</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>Map_Pearl_B_sent_r</td>
#       <td>0.195696</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>Map_Split_A_duel_r</td>
#       <td>0.865616</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>Map_Split_A_cont_r</td>
#       <td>0.084390</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>Map_Split_A_init_r</td>
#       <td>0.391508</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>Map_Split_A_sent_r</td>
#       <td>0.239796</td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>Map_Split_B_duel_r</td>
#       <td>-0.768260</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>Map_Split_B_cont_r</td>
#       <td>-0.180528</td>
#     </tr>
#     <tr>
#       <th>70</th>
#       <td>Map_Split_B_init_r</td>
#       <td>-0.179806</td>
#     </tr>
#     <tr>
#       <th>71</th>
#       <td>Map_Split_B_sent_r</td>
#       <td>-0.491511</td>
#     </tr>
#   </tbody>
# </
