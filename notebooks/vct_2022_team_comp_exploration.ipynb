# %%
import pandas as pd
from IPython.display import HTML

# %%
# The function below is useful when I disply dataframes.
# We can display multiple dataframes side by side.
def side_by_side(*dfs):
    html = '<div style="display:flex">'
    for df in dfs:
        html += '<div style="margin-right: 2em">'
        html += df.to_html()
        html += '</div>'
    html += '</div>'
    display(HTML(html))

# %% [markdown]
# In this notebook, I would like to see if team compositions have an influence on match results.
#
# We can get team composition and match results data from "overview" and "maps_scores".
#
# Also, the cell below has the list of top tier tournaments in 2022.

# %%
### List of tournaments I want to include in my data set.
# Stage 1
stage1 = ["Champions Tour Stage 1: EMEA Challengers",
"Champions Tour North America Stage 1: Challengers",
"Champions Tour Latin America Stage 1: Playoffs",
"Champions Tour LATAM/BR Stage 1: Last Chance Qualifier",
"Champions Tour Asia-Pacific Stage 1: Challengers Playoffs",
"Champions Tour Korea Stage 1: Challengers",
"Champions Tour Japan Stage 1: Challengers Playoffs",
"Valorant Champions Tour Stage 1: Masters Reykjavík"]

# Stage 2
stage2 = ["Champions Tour EMEA Stage 2: Challengers",
"Champions Tour North America Stage 2: Challengers",
"Champions Tour LATAM/BR Stage 2: Last Chance Qualifier",
"Champions Tour Brazil Stage 2: Challengers",
"Champions Tour Asia-Pacific Stage 2: Challengers Playoffs",
"Champions Tour Korea Stage 2: Challengers",
"Champions Tour Japan Stage 2: Challengers Playoffs",
"Valorant Champions Tour Stage 2: Masters Copenhagen"]

# Champions
champions = ["Champions Tour EMEA: Last Chance Qualifier",
"Champions Tour North America: Last Chance Qualifier",
"Champions Tour South America: Last Chance Qualifier",
"Champions Tour Asia-Pacific: Last Chance Qualifier",
"Champions Tour East Asia: Last Chance Qualifier",
"Valorant Champions 2022"]

vct_2022_stages = {"stage 1": stage1, "stage 2": stage2, "champions": champions}

# %%
maps_scores = pd.read_csv("../data/vct_2022/matches/maps_scores.csv")

maps_scores.head(10)
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2022  Group Stage  Opening (A)
# 1  Valorant Champions 2022  Group Stage  Opening (A)
# 2  Valorant Champions 2022  Group Stage  Opening (A)
# 3  Valorant Champions 2022  Group Stage  Opening (A)
# 4  Valorant Champions 2022  Group Stage  Opening (A)
# 5  Valorant Champions 2022  Group Stage  Opening (B)
# 6  Valorant Champions 2022  Group Stage  Opening (B)
# 7  Valorant Champions 2022  Group Stage  Opening (B)
# 8  Valorant Champions 2022  Group Stage  Opening (B)
# 9  Valorant Champions 2022  Group Stage  Opening (B)
#
#                      Match Name       Map         Team A  Team A Score  \
# 0    Paper Rex vs EDward Gaming     Pearl      Paper Rex            13
# 1    Paper Rex vs EDward Gaming    Icebox      Paper Rex             5
# 2    Paper Rex vs EDward Gaming     Haven      Paper Rex            13
# 3       Leviatán vs Team Liquid     Haven       Leviatán            13
# 4       Leviatán vs Team Liquid    Ascent       Leviatán            13
# 5         ZETA DIVISION vs LOUD    Ascent  ZETA DIVISION             8
# 6         ZETA DIVISION vs LOUD  Fracture  ZETA DIVISION             9
# 7  OpTic Gaming vs BOOM Esports    Breeze   OpTic Gaming            16
# 8  OpTic Gaming vs BOOM Esports      Bind   OpTic Gaming            13
# 9  OpTic Gaming vs BOOM Esports  Fracture   OpTic Gaming            13
#
#    Team A Attacker Score  Team A Defender Score  Team A Overtime Score  \
# 0                      6                      7                    NaN
# 1                      2                      3                    NaN
# 2                      7                      6                    NaN
# 3                      8                      5                    NaN
# 4                      6                      7                    NaN
# 5                      7                      1                    NaN
# 6                      7                      2                    NaN
# 7                      4                      8                    4.0
# 8                     10                      3                    NaN
# 9                      9                      4                    NaN
#
#           Team B  Team B Score  Team B Attacker Score  Team B Defender Score  \
# 0  EDward Gaming            11                      5                      6
# 1  EDward Gaming            13                      3                     10
# 2  EDward Gaming             8                      3                      5
# 3    Team Liquid            10                      6                      4
# 4    Team Liquid            10                      4                      6
# 5           LOUD            13                      8                      5
# 6           LOUD            13                      8                      5
# 7   BOOM Esports            18                      4                      8
# 8   BOOM Esports             5                      3                      2
# 9   BOOM Esports             3                      0                      3
#
#    Team B Overtime Score Duration
# 0                    NaN  1:16:34
# 1                    NaN    40:51
# 2                    NaN      NaN
# 3                    NaN  1:04:37
# 4                    NaN  1:05:07
# 5                    NaN  1:05:35
# 6                    NaN    51:21
# 7                    6.0  1:46:49
# 8                    NaN    38:28
# 9                    NaN      NaN

# %%
overview = pd.read_csv("../data/vct_2022/matches/overview.csv")
overview["Agents"] = overview["Agents"].apply(lambda x: str(x).replace(" ",""))

# %%
# We don't need all rows from "overview" and the following are index.
ind1 = (overview.Map != "All Maps")    
ind2 = (overview.Side == "both")
ind = (ind1 & ind2)

# %%
keystolook = ["Tournament", "Stage", "Match Type", "Match Name", "Map", "Team", "Agents"]
#  I found that some matches do have "Agents" value null.  We need to get rid of this.
print(overview[ind][keystolook].isna().sum())
# Out:
# Tournament    0
# Stage         0
# Match Type    0
# Match Name    0
# Map           0
# Team          0
# Agents        0
# dtype: int64

# %%
#  It's not right that the number of missing Agents is 143 which is not divisible by 5.
#  I will fill null value with "000" for later.
#  Let's first convert our dataframe and see that new "Agents" has wrong values.  (Correct ones are lists of five character names.)
def join_strings(lst):
    return ','.join(str(x) for x in lst)

vct_2022_team_comp = overview[ind][keystolook].fillna("000")
agent_list = vct_2022_team_comp["Agents"].unique()  # before aggregating "Agents" to get a team composition, I want to save individual agents played in 2022.
print(agent_list)

vct_2022_team_comp = overview[ind][keystolook].groupby(["Tournament", "Stage", "Match Type", "Match Name", "Map", "Team"], as_index=False).agg(lambda x: join_strings(sorted(list((x)))))
# Out:
# ['fade' 'sage' 'astra' 'chamber' 'raze' 'viper' 'kayo' 'jett' 'sova'
#  'reyna' 'cypher' 'skye' 'omen' 'breach' 'phoenix' 'killjoy' 'neon'
#  'brimstone' 'yoru' 'omen,jett' 'kayo,jett' 'nan' 'raze,astra'
#  'jett,viper' 'astra,chamber' 'omen,chamber' 'chamber,astra' 'reyna,omen'
#  'jett,astra']
#                                               Tournament               Stage  \
# 0      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 1      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 2      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 3      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 4      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# ...                                                  ...                 ...
# 17712                   Valorant Conquerors Championship  Wildcard Qualifier
# 17713                   Valorant Conquerors Championship  Wildcard Qualifier
# 17714                   Valorant Conquerors Championship  Wildcard Qualifier
# 17715                   Valorant Conquerors Championship  Wildcard Qualifier
# 17716                   Valorant Conquerors Championship  Wildcard Qualifier
#
#                      Match Type                            Match Name     Map  \
# 0                   Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 1                   Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 2                   Decider (A)  Made in Thailand vs CERBERUS Esports    Bind
# 3                   Decider (A)  Made in Thailand vs CERBERUS Esports    Bind
# 4                   Decider (B)            Persija Esports vs Bonkers    Bind
# ...                         ...                                   ...     ...
# 17712  Upper Bracket Semifinals   Global Esports vs M1syl and friends  Breeze
# 17713  Upper Bracket Semifinals          Maruti Peek vs God Particles  Ascent
# 17714  Upper Bracket Semifinals          Maruti Peek vs God Particles  Ascent
# 17715  Upper Bracket Semifinals          Maruti Peek vs God Particles  Breeze
# 17716  Upper Bracket Semifinals          Maruti Peek vs God Particles  Breeze
#
#                     Team                            Agents
# 0       CERBERUS Esports     breach,chamber,jett,omen,sova
# 1       Made in Thailand      astra,jett,kayo,killjoy,sova
# 2       CERBERUS Esports    astra,breach,chamber,jett,sova
# 3       Made in Thailand    brimstone,raze,sage,skye,viper
# 4                Bonkers  brimstone,chamber,neon,skye,sova
# ...                  ...                               ...
# 17712  M1syl and friends      chamber,jett,skye,sova,viper
# 17713      God Particles      astra,jett,killjoy,raze,sova
# 17714        Maruti Peek      astra,jett,kayo,killjoy,sova
# 17715      God Particles       cypher,jett,skye,sova,viper
# 17716        Maruti Peek     chamber,jett,reyna,sova,viper
#
# [17717 rows x 7 columns]

# %%
overview[(overview["Agents"] == 'kayo,jett') & (overview["Map"] != "All Maps")]  # This line shows wrong input.  Agents column can't have mulitple agents when Map != "All Maps"

# So, getting agent_list in this stage doens't sound good.  I wanted to get agent_list in order to do linear regression later.
# I may preprocess the data later without making agent_list.
# Out:
#                                               Tournament              Stage  \
# 17517  Champions Tour North America Stage 2: Challengers  Open Qualifier #1
# 17518  Champions Tour North America Stage 2: Challengers  Open Qualifier #1
# 17519  Champions Tour North America Stage 2: Challengers  Open Qualifier #1
#
#          Match Type                Match Name     Map  Player        Team  \
# 17517  Round of 128  Lenny Time vs Go 4 Broke  Breeze  Camdog  Go 4 Broke
# 17518  Round of 128  Lenny Time vs Go 4 Broke  Breeze  Camdog  Go 4 Broke
# 17519  Round of 128  Lenny Time vs Go 4 Broke  Breeze  Camdog  Go 4 Broke
#
#           Agents  Rating  Average Combat Score  ...  Deaths  Assists  \
# 17517  kayo,jett    0.84                 171.0  ...    15.0      1.0
# 17518  kayo,jett    0.73                 154.0  ...     9.0      1.0
# 17519  kayo,jett    1.02                 203.0  ...     6.0      0.0
#
#        Kills - Deaths (KD)  Kill, Assist, Trade, Survive %  \
# 17517                 -4.0                             58%
# 17518                 -3.0                             50%
# 17519                 -1.0                             71%
#
#       Average Damage per Round  Headshot % First Kills  First Deaths  \
# 17517                    117.0         29%         1.0           4.0
# 17518                    109.0         25%         0.0           3.0
# 17519                    131.0         38%         1.0           1.0
#
#        Kills - Deaths (FKD)    Side
# 17517                  -3.0    both
# 17518                  -3.0  attack
# 17519                   0.0  defend
#
# [3 rows x 21 columns]

# %%
len(vct_2022_team_comp.Agents.unique())
# Out:
# 1109

# %% [markdown]
# "vct_2022_team_comp" doesn't have match result data.  I want to add it.

# %%
vct_2022_scores = maps_scores[["Tournament", "Stage", "Match Type", "Match Name", "Map",
                                "Team A", "Team A Score", "Team B", "Team B Score"]]
vct_2022_scores
# Out:
#                                      Tournament             Stage  \
# 0                       Valorant Champions 2022       Group Stage
# 1                       Valorant Champions 2022       Group Stage
# 2                       Valorant Champions 2022       Group Stage
# 3                       Valorant Champions 2022       Group Stage
# 4                       Valorant Champions 2022       Group Stage
# ...                                         ...               ...
# 8879  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 8880  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 8881  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 8882  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 8883  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
#
#        Match Type                        Match Name     Map         Team A  \
# 0     Opening (A)        Paper Rex vs EDward Gaming   Pearl      Paper Rex
# 1     Opening (A)        Paper Rex vs EDward Gaming  Icebox      Paper Rex
# 2     Opening (A)        Paper Rex vs EDward Gaming   Haven      Paper Rex
# 3     Opening (A)           Leviatán vs Team Liquid   Haven       Leviatán
# 4     Opening (A)           Leviatán vs Team Liquid  Ascent       Leviatán
# ...           ...                               ...     ...            ...
# 8879  Grand Final  Natus Vincere vs FunPlus Phoenix    Bind  Natus Vincere
# 8880  Grand Final  Natus Vincere vs FunPlus Phoenix  Icebox  Natus Vincere
# 8881  Grand Final  Natus Vincere vs FunPlus Phoenix  Breeze  Natus Vincere
# 8882  Grand Final  Natus Vincere vs FunPlus Phoenix   Haven  Natus Vincere
# 8883  Grand Final  Natus Vincere vs FunPlus Phoenix   Split  Natus Vincere
#
#       Team A Score           Team B  Team B Score
# 0               13    EDward Gaming            11
# 1                5    EDward Gaming            13
# 2               13    EDward Gaming             8
# 3               13      Team Liquid            10
# 4               13      Team Liquid            10
# ...            ...              ...           ...
# 8879            13  FunPlus Phoenix            10
# 8880            14  FunPlus Phoenix            12
# 8881             5  FunPlus Phoenix            13
# 8882             7  FunPlus Phoenix            13
# 8883             3  FunPlus Phoenix            13
#
# [8884 rows x 9 columns]

# %%
print("length of vct_2022_team_comp:", len(vct_2022_team_comp))
print("2(length of vct_2022_scores):", len(vct_2022_scores)*2)
# Out:
# length of vct_2022_team_comp: 17717
# 2(length of vct_2022_scores): 17768

# %% [markdown]
# vct_2022_scores has more match information than the other, so I will outer join them.  Before doing this, let's check if they have any null value.

# %%
display(vct_2022_team_comp.isna().sum())
display(vct_2022_scores.isna().sum())
# Out:
# Tournament    0
# Stage         0
# Match Type    0
# Match Name    0
# Map           0
# Team          0
# Agents        0
# dtype: int64
# Tournament      0
# Stage           0
# Match Type      0
# Match Name      0
# Map             0
# Team A          0
# Team A Score    0
# Team B          0
# Team B Score    0
# dtype: int64

# %% [markdown]
# Okay!  They look good.

# %%
left = vct_2022_team_comp
right = vct_2022_scores
keys = ["Tournament", "Stage", "Match Type", "Match Name", "Map"]
result = pd.merge(left, right, how="outer", on=keys)
print(len(result))
result.isna().sum()
# Out:
# 17800
# Tournament        0
# Stage             0
# Match Type        0
# Match Name        0
# Map               0
# Team             75
# Agents           75
# Team A          110
# Team A Score    110
# Team B          110
# Team B Score    110
# dtype: int64

# %% [markdown]
# Quite a lot of missing values here.  Compare to the total number of games, the number of missing value does not seem terrible. (The ratio is 110/17800 = 0.006.)
#
# I think it's okay to drop null values in this case.

# %%
vct_2022_comp_data = result.dropna()
vct_2022_comp_data.head()
# Out:
#                                           Tournament        Stage  \
# 0  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 1  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 2  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 3  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 4  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
#
#     Match Type                            Match Name     Map  \
# 0  Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 1  Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 2  Decider (A)  Made in Thailand vs CERBERUS Esports    Bind
# 3  Decider (A)  Made in Thailand vs CERBERUS Esports    Bind
# 4  Decider (B)            Persija Esports vs Bonkers    Bind
#
#                Team                            Agents            Team A  \
# 0  CERBERUS Esports     breach,chamber,jett,omen,sova  Made in Thailand
# 1  Made in Thailand      astra,jett,kayo,killjoy,sova  Made in Thailand
# 2  CERBERUS Esports    astra,breach,chamber,jett,sova  Made in Thailand
# 3  Made in Thailand    brimstone,raze,sage,skye,viper  Made in Thailand
# 4           Bonkers  brimstone,chamber,neon,skye,sova   Persija Esports
#
#    Team A Score            Team B  Team B Score
# 0          13.0  CERBERUS Esports           8.0
# 1          13.0  CERBERUS Esports           8.0
# 2          13.0  CERBERUS Esports           3.0
# 3          13.0  CERBERUS Esports           3.0
# 4          15.0           Bonkers          17.0

# %% [markdown]
# I want to add match result into this.
#
# Let's call our dataframe df and follow the steps below.
#
# - make "A win" column by setting "Team A Score" > "Team B Score"
# - set "win" column to be False
# - if "Team" == "Team A", then set "win" to be "A win" and if "Team" == "Team B", then set "win" to be ~"A win"

# %%
vct_2022_comp_data.loc[:,"A win"] = (vct_2022_comp_data.loc[:,"Team A Score"] > vct_2022_comp_data.loc[:,"Team B Score"])

vct_2022_comp_data
# Out:
#                                               Tournament               Stage  \
# 0      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 1      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 2      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 3      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 4      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# ...                                                  ...                 ...
# 17795                   Valorant Conquerors Championship  Wildcard Qualifier
# 17796                   Valorant Conquerors Championship  Wildcard Qualifier
# 17797                   Valorant Conquerors Championship  Wildcard Qualifier
# 17798                   Valorant Conquerors Championship  Wildcard Qualifier
# 17799                   Valorant Conquerors Championship  Wildcard Qualifier
#
#                      Match Type                            Match Name     Map  \
# 0                   Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 1                   Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 2                   Decider (A)  Made in Thailand vs CERBERUS Esports    Bind
# 3                   Decider (A)  Made in Thailand vs CERBERUS Esports    Bind
# 4                   Decider (B)            Persija Esports vs Bonkers    Bind
# ...                         ...                                   ...     ...
# 17795  Upper Bracket Semifinals   Global Esports vs M1syl and friends  Breeze
# 17796  Upper Bracket Semifinals          Maruti Peek vs God Particles  Ascent
# 17797  Upper Bracket Semifinals          Maruti Peek vs God Particles  Ascent
# 17798  Upper Bracket Semifinals          Maruti Peek vs God Particles  Breeze
# 17799  Upper Bracket Semifinals          Maruti Peek vs God Particles  Breeze
#
#                     Team                            Agents            Team A  \
# 0       CERBERUS Esports     breach,chamber,jett,omen,sova  Made in Thailand
# 1       Made in Thailand      astra,jett,kayo,killjoy,sova  Made in Thailand
# 2       CERBERUS Esports    astra,breach,chamber,jett,sova  Made in Thailand
# 3       Made in Thailand    brimstone,raze,sage,skye,viper  Made in Thailand
# 4                Bonkers  brimstone,chamber,neon,skye,sova   Persija Esports
# ...                  ...                               ...               ...
# 17795  M1syl and friends      chamber,jett,skye,sova,viper    Global Esports
# 17796      God Particles      astra,jett,killjoy,raze,sova       Maruti Peek
# 17797        Maruti Peek      astra,jett,kayo,killjoy,sova       Maruti Peek
# 17798      God Particles       cypher,jett,skye,sova,viper       Maruti Peek
# 17799        Maruti Peek     chamber,jett,reyna,sova,viper       Maruti Peek
#
#        Team A Score             Team B  Team B Score  A win
# 0              13.0   CERBERUS Esports           8.0   True
# 1              13.0   CERBERUS Esports           8.0   True
# 2              13.0   CERBERUS Esports           3.0   True
# 3              13.0   CERBERUS Esports           3.0   True
# 4              15.0            Bonkers          17.0  False
# ...             ...                ...           ...    ...
# 17795          13.0  M1syl and friends           8.0   True
# 17796           3.0      God Particles          13.0  False
# 17797           3.0      God Particles          13.0  False
# 17798           3.0      God Particles          13.0  False
# 17799           3.0      God Particles          13.0  False
#
# [17615 rows x 12 columns]

# %%
win = []
for index, row in vct_2022_comp_data.iterrows():
    if row["Team"] == row["Team A"]:
        win.append(row["A win"])
    elif row["Team"] == row["Team B"]:
        win.append(not row["A win"])
    else:
        print("Team is neither of Team A nor Team B.  This is wrong.")

# %%
vct_2022_comp_data.loc[:,"win"] = win
vct_2022_comp_data.loc[:,"loss"] = vct_2022_comp_data.loc[:,"win"].apply(lambda x: not x)
vct_2022_comp_data.head()
# Out:
#                                           Tournament        Stage  \
# 0  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 1  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 2  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 3  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 4  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
#
#     Match Type                            Match Name     Map  \
# 0  Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 1  Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 2  Decider (A)  Made in Thailand vs CERBERUS Esports    Bind
# 3  Decider (A)  Made in Thailand vs CERBERUS Esports    Bind
# 4  Decider (B)            Persija Esports vs Bonkers    Bind
#
#                Team                            Agents            Team A  \
# 0  CERBERUS Esports     breach,chamber,jett,omen,sova  Made in Thailand
# 1  Made in Thailand      astra,jett,kayo,killjoy,sova  Made in Thailand
# 2  CERBERUS Esports    astra,breach,chamber,jett,sova  Made in Thailand
# 3  Made in Thailand    brimstone,raze,sage,skye,viper  Made in Thailand
# 4           Bonkers  brimstone,chamber,neon,skye,sova   Persija Esports
#
#    Team A Score            Team B  Team B Score  A win    win   loss
# 0          13.0  CERBERUS Esports           8.0   True  False   True
# 1          13.0  CERBERUS Esports           8.0   True   True  False
# 2          13.0  CERBERUS Esports           3.0   True  False   True
# 3          13.0  CERBERUS Esports           3.0   True   True  False
# 4          15.0           Bonkers          17.0  False   True  False

# %% [markdown]
# It would be good to keep track of score differences. Let's do this.

# %%
vct_2022_comp_data.loc[:,"score diff"] = abs(vct_2022_comp_data.loc[:,"Team A Score"] - vct_2022_comp_data.loc[:,"Team B Score"])
vct_2022_comp_data
# Out:
#                                               Tournament               Stage  \
# 0      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 1      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 2      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 3      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 4      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# ...                                                  ...                 ...
# 17795                   Valorant Conquerors Championship  Wildcard Qualifier
# 17796                   Valorant Conquerors Championship  Wildcard Qualifier
# 17797                   Valorant Conquerors Championship  Wildcard Qualifier
# 17798                   Valorant Conquerors Championship  Wildcard Qualifier
# 17799                   Valorant Conquerors Championship  Wildcard Qualifier
#
#                      Match Type                            Match Name     Map  \
# 0                   Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 1                   Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 2                   Decider (A)  Made in Thailand vs CERBERUS Esports    Bind
# 3                   Decider (A)  Made in Thailand vs CERBERUS Esports    Bind
# 4                   Decider (B)            Persija Esports vs Bonkers    Bind
# ...                         ...                                   ...     ...
# 17795  Upper Bracket Semifinals   Global Esports vs M1syl and friends  Breeze
# 17796  Upper Bracket Semifinals          Maruti Peek vs God Particles  Ascent
# 17797  Upper Bracket Semifinals          Maruti Peek vs God Particles  Ascent
# 17798  Upper Bracket Semifinals          Maruti Peek vs God Particles  Breeze
# 17799  Upper Bracket Semifinals          Maruti Peek vs God Particles  Breeze
#
#                     Team                            Agents            Team A  \
# 0       CERBERUS Esports     breach,chamber,jett,omen,sova  Made in Thailand
# 1       Made in Thailand      astra,jett,kayo,killjoy,sova  Made in Thailand
# 2       CERBERUS Esports    astra,breach,chamber,jett,sova  Made in Thailand
# 3       Made in Thailand    brimstone,raze,sage,skye,viper  Made in Thailand
# 4                Bonkers  brimstone,chamber,neon,skye,sova   Persija Esports
# ...                  ...                               ...               ...
# 17795  M1syl and friends      chamber,jett,skye,sova,viper    Global Esports
# 17796      God Particles      astra,jett,killjoy,raze,sova       Maruti Peek
# 17797        Maruti Peek      astra,jett,kayo,killjoy,sova       Maruti Peek
# 17798      God Particles       cypher,jett,skye,sova,viper       Maruti Peek
# 17799        Maruti Peek     chamber,jett,reyna,sova,viper       Maruti Peek
#
#        Team A Score             Team B  Team B Score  A win    win   loss  \
# 0              13.0   CERBERUS Esports           8.0   True  False   True
# 1              13.0   CERBERUS Esports           8.0   True   True  False
# 2              13.0   CERBERUS Esports           3.0   True  False   True
# 3              13.0   CERBERUS Esports           3.0   True   True  False
# 4              15.0            Bonkers          17.0  False   True  False
# ...             ...                ...           ...    ...    ...    ...
# 17795          13.0  M1syl and friends           8.0   True  False   True
# 17796           3.0      God Particles          13.0  False   True  False
# 17797           3.0      God Particles          13.0  False  False   True
# 17798           3.0      God Particles          13.0  False   True  False
# 17799           3.0      God Particles          13.0  False  False   True
#
#        score diff
# 0             5.0
# 1             5.0
# 2            10.0
# 3            10.0
# 4             2.0
# ...           ...
# 17795         5.0
# 17796        10.0
# 17797        10.0
# 17798        10.0
# 17799        10.0
#
# [17615 rows x 15 columns]

# %% [markdown]
# There are too many different team compositions if we use individual agents.
#
# I think it's better to have adopt the way of general team composition.  For example, if we have "jett,kayo,killjoy,omen,sova", then this comp is 1 duelist, 2 initiators, 1 controller, 1 sentinel.

# %%
def get_comp(agents: str) -> (str, int):
    """ 
    input: string of five agents that order of agents are sorted aphabetically and seperated by ","
    return: ("dics", int) "dics" where d: the # of duelist(s)
                                i: the # of initiator(s)
                                c: the # of controller(s)
                                s: the # of sentinel(s)
            int means the number of invalid agents in input list
    """
    roles = {"duelist": {"jett", "phoenix", "reyna", "raze", "yoru", "neon", "iso"},
             "initiator": {"sova", "breach", "skye", "kayo", "fade", "gekko"},
             "controller": {"brimstone", "omen", "viper", "astra", "harbor"},
             "sentinel": {"cypher", "sage", "killjoy", "chamber", "deadlock"}}
    
    agentlist = agents.split(",")
    dul = 0
    ini = 0
    con = 0
    sen = 0
    non = 0
    composition = ""
    for agent in agentlist:
        if agent in roles["duelist"]:
            dul += 1
        elif agent in roles["initiator"]:
            ini += 1
        elif agent in roles["controller"]:
            con += 1
        elif agent in roles["sentinel"]:
            sen += 1
        else:
            non +=1

    # assert (dul + ini + con + sen) == 5, f"{dul + ini + con + sen}"   I checked with this line, there are not valid composition in our data.

    composition = str(dul) + str(ini) + str(con) + str(sen)

    return composition, non

# %%
vct_2022_comp_data.loc[:,"comp code"] = vct_2022_comp_data["Agents"].apply(lambda x: get_comp(x)[0])
vct_2022_comp_data.loc[:,"invalid comp"] = vct_2022_comp_data["Agents"].apply(lambda x: get_comp(x)[1])

vct_2022_comp_data
# Out:
#                                               Tournament               Stage  \
# 0      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 1      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 2      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 3      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 4      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# ...                                                  ...                 ...
# 17795                   Valorant Conquerors Championship  Wildcard Qualifier
# 17796                   Valorant Conquerors Championship  Wildcard Qualifier
# 17797                   Valorant Conquerors Championship  Wildcard Qualifier
# 17798                   Valorant Conquerors Championship  Wildcard Qualifier
# 17799                   Valorant Conquerors Championship  Wildcard Qualifier
#
#                      Match Type                            Match Name     Map  \
# 0                   Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 1                   Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 2                   Decider (A)  Made in Thailand vs CERBERUS Esports    Bind
# 3                   Decider (A)  Made in Thailand vs CERBERUS Esports    Bind
# 4                   Decider (B)            Persija Esports vs Bonkers    Bind
# ...                         ...                                   ...     ...
# 17795  Upper Bracket Semifinals   Global Esports vs M1syl and friends  Breeze
# 17796  Upper Bracket Semifinals          Maruti Peek vs God Particles  Ascent
# 17797  Upper Bracket Semifinals          Maruti Peek vs God Particles  Ascent
# 17798  Upper Bracket Semifinals          Maruti Peek vs God Particles  Breeze
# 17799  Upper Bracket Semifinals          Maruti Peek vs God Particles  Breeze
#
#                     Team                            Agents            Team A  \
# 0       CERBERUS Esports     breach,chamber,jett,omen,sova  Made in Thailand
# 1       Made in Thailand      astra,jett,kayo,killjoy,sova  Made in Thailand
# 2       CERBERUS Esports    astra,breach,chamber,jett,sova  Made in Thailand
# 3       Made in Thailand    brimstone,raze,sage,skye,viper  Made in Thailand
# 4                Bonkers  brimstone,chamber,neon,skye,sova   Persija Esports
# ...                  ...                               ...               ...
# 17795  M1syl and friends      chamber,jett,skye,sova,viper    Global Esports
# 17796      God Particles      astra,jett,killjoy,raze,sova       Maruti Peek
# 17797        Maruti Peek      astra,jett,kayo,killjoy,sova       Maruti Peek
# 17798      God Particles       cypher,jett,skye,sova,viper       Maruti Peek
# 17799        Maruti Peek     chamber,jett,reyna,sova,viper       Maruti Peek
#
#        Team A Score             Team B  Team B Score  A win    win   loss  \
# 0              13.0   CERBERUS Esports           8.0   True  False   True
# 1              13.0   CERBERUS Esports           8.0   True   True  False
# 2              13.0   CERBERUS Esports           3.0   True  False   True
# 3              13.0   CERBERUS Esports           3.0   True   True  False
# 4              15.0            Bonkers          17.0  False   True  False
# ...             ...                ...           ...    ...    ...    ...
# 17795          13.0  M1syl and friends           8.0   True  False   True
# 17796           3.0      God Particles          13.0  False   True  False
# 17797           3.0      God Particles          13.0  False  False   True
# 17798           3.0      God Particles          13.0  False   True  False
# 17799           3.0      God Particles          13.0  False  False   True
#
#        score diff comp code  invalid comp
# 0             5.0      1211             0
# 1             5.0      1211             0
# 2            10.0      1211             0
# 3            10.0      1121             0
# 4             2.0      1211             0
# ...           ...       ...           ...
# 17795         5.0      1211             0
# 17796        10.0      2111             0
# 17797        10.0      1211             0
# 17798        10.0      1211             0
# 17799        10.0      2111             0
#
# [17615 rows x 17 columns]

# %%
vct_2022_comp_data[vct_2022_comp_data["invalid comp"] != 0]
# Out:
#                                               Tournament               Stage  \
# 4778        Champions Tour Europe Stage 1: Challengers 2      Open Qualifier
# 6260       Champions Tour Indonesia Stage 2: Challengers         Group Stage
# 6261       Champions Tour Indonesia Stage 2: Challengers         Group Stage
# 9419   Champions Tour Malaysia & Singapore Stage 1: C...            Playoffs
# 9420   Champions Tour Malaysia & Singapore Stage 1: C...            Playoffs
# 10245  Champions Tour North America Stage 1: Challengers   Open Qualifier #1
# 10246  Champions Tour North America Stage 1: Challengers   Open Qualifier #1
# 11586  Champions Tour North America Stage 1: Challengers   Open Qualifier #2
# 11587  Champions Tour North America Stage 1: Challengers   Open Qualifier #2
# 13075    Champions Tour Philippines Stage 1: Challengers         Group Stage
# 13076    Champions Tour Philippines Stage 1: Challengers         Group Stage
# 13099    Champions Tour Philippines Stage 1: Challengers         Group Stage
# 13100    Champions Tour Philippines Stage 1: Challengers         Group Stage
# 13127    Champions Tour Philippines Stage 1: Challengers         Group Stage
# 13128    Champions Tour Philippines Stage 1: Challengers         Group Stage
# 13337    Champions Tour Philippines Stage 2: Challengers         Group Stage
# 13338    Champions Tour Philippines Stage 2: Challengers         Group Stage
# 15465        Champions Tour Vietnam Stage 1: Challengers              Finals
# 15466        Champions Tour Vietnam Stage 1: Challengers              Finals
# 15559        Champions Tour Vietnam Stage 1: Challengers         Group Stage
# 15560        Champions Tour Vietnam Stage 1: Challengers         Group Stage
# 15677        Champions Tour Vietnam Stage 2: Challengers      First Division
# 15678        Champions Tour Vietnam Stage 2: Challengers      First Division
# 15921                              Oceania Tour: Stage 1         Group Stage
# 15922                              Oceania Tour: Stage 1         Group Stage
# 16159                              Oceania Tour: Stage 2         Group Stage
# 16160                              Oceania Tour: Stage 2         Group Stage
# 17768                   Valorant Conquerors Championship  Wildcard Qualifier
# 17769                   Valorant Conquerors Championship  Wildcard Qualifier
#
#                         Match Type                                Match Name  \
# 4778                  Round of 256                     Giants Gaming vs ENTS
# 6260                       Round 1        Bigetron Arctic vs Persija Esports
# 6261                       Round 1        Bigetron Arctic vs Persija Esports
# 9419           Upper Quarterfinals                         BLEED vs Fastelle
# 9420           Upper Quarterfinals                         BLEED vs Fastelle
# 10245                Lower Round 1                     IlluZion vs Renegades
# 10246                Lower Round 1                     IlluZion vs Renegades
# 11586            Upper Round of 32                          Rise vs Reformed
# 11587            Upper Round of 32                          Rise vs Reformed
# 13075                      Group A                 Bren Esports vs Action PH
# 13076                      Group A                 Bren Esports vs Action PH
# 13099                      Group A               Oasis Gaming vs Team Secret
# 13100                      Group A               Oasis Gaming vs Team Secret
# 13127                      Group B    Looking for Org vs South Built Esports
# 13128                      Group B    Looking for Org vs South Built Esports
# 13337                       Week 1     Rex Regum Qeon vs South Built Esports
# 13338                       Week 1     Rex Regum Qeon vs South Built Esports
# 15465  Upper Bracket Quarterfinals                            OK vs Team Joy
# 15466  Upper Bracket Quarterfinals                            OK vs Team Joy
# 15559                  Opening (D)                       Fear of God vs chiu
# 15560                  Opening (D)                       Fear of God vs chiu
# 15677            Lower Round 1 (C)            Nghiện Thêm Lần Nữ vs Cat Gang
# 15678            Lower Round 1 (C)            Nghiện Thêm Lần Nữ vs Cat Gang
# 15921                       Week 1                       Iconic vs Mindfreak
# 15922                       Week 1                       Iconic vs Mindfreak
# 16159                       Week 2                          Bonkers vs ORDER
# 16160                       Week 2                          Bonkers vs ORDER
# 17768        Lower Bracket Round 1  M1syl and friends vs Crash Landin on You
# 17769        Lower Bracket Round 1  M1syl and friends vs Crash Landin on You
#
#             Map                 Team               Agents              Team A  \
# 4778     Ascent        Giants Gaming  nan,nan,nan,nan,nan       Giants Gaming
# 6260   Fracture      Bigetron Arctic  nan,nan,nan,nan,nan     Bigetron Arctic
# 6261   Fracture      Persija Esports  nan,nan,nan,nan,nan     Bigetron Arctic
# 9419     Ascent                BLEED  nan,nan,nan,nan,nan               BLEED
# 9420     Ascent             Fastelle  nan,nan,nan,nan,nan               BLEED
# 10245     Haven             IlluZion  nan,nan,nan,nan,nan            IlluZion
# 10246     Haven            Renegades  nan,nan,nan,nan,nan            IlluZion
# 11586    Breeze             Reformed  nan,nan,nan,nan,nan                Rise
# 11587    Breeze                 Rise  nan,nan,nan,nan,nan                Rise
# 13075     Haven            Action PH  nan,nan,nan,nan,nan        Bren Esports
# 13076     Haven         Bren Esports  nan,nan,nan,nan,nan        Bren Esports
# 13099  Fracture         Oasis Gaming  nan,nan,nan,nan,nan        Oasis Gaming
# 13100  Fracture          Team Secret  nan,nan,nan,nan,nan        Oasis Gaming
# 13127     Haven      Looking for Org  nan,nan,nan,nan,nan     Looking for Org
# 13128     Haven  South Built Esports  nan,nan,nan,nan,nan     Looking for Org
# 13337    Ascent       Rex Regum Qeon  nan,nan,nan,nan,nan      Rex Regum Qeon
# 13338    Ascent  South Built Esports  nan,nan,nan,nan,nan      Rex Regum Qeon
# 15465    Icebox                   OK  nan,nan,nan,nan,nan                  OK
# 15466    Icebox             Team Joy  nan,nan,nan,nan,nan                  OK
# 15559      Bind          Fear of God  nan,nan,nan,nan,nan         Fear of God
# 15560      Bind                 chiu      nan,nan,nan,nan         Fear of God
# 15677    Ascent             Cat Gang  nan,nan,nan,nan,nan  Nghiện Thêm Lần Nữ
# 15678    Ascent   Nghiện Thêm Lần Nữ  nan,nan,nan,nan,nan  Nghiện Thêm Lần Nữ
# 15921     Haven               Iconic  nan,nan,nan,nan,nan              Iconic
# 15922     Haven            Mindfreak      nan,nan,nan,nan              Iconic
# 16159     Split              Bonkers  nan,nan,nan,nan,nan             Bonkers
# 16160     Split                ORDER  nan,nan,nan,nan,nan             Bonkers
# 17768      Bind  Crash Landin on You  nan,nan,nan,nan,nan   M1syl and friends
# 17769      Bind    M1syl and friends  nan,nan,nan,nan,nan   M1syl and friends
#
#        Team A Score               Team B  Team B Score  A win    win   loss  \
# 4778           13.0                 ENTS           0.0   True   True  False
# 6260            0.0      Persija Esports           0.0  False  False   True
# 6261            0.0      Persija Esports           0.0  False   True  False
# 9419            0.0             Fastelle           0.0  False  False   True
# 9420            0.0             Fastelle           0.0  False   True  False
# 10245           2.0            Renegades          13.0  False  False   True
# 10246           2.0            Renegades          13.0  False   True  False
# 11586          13.0             Reformed           7.0   True  False   True
# 11587          13.0             Reformed           7.0   True   True  False
# 13075          13.0            Action PH           0.0   True  False   True
# 13076          13.0            Action PH           0.0   True   True  False
# 13099           0.0          Team Secret          13.0  False  False   True
# 13100           0.0          Team Secret          13.0  False   True  False
# 13127           0.0  South Built Esports          13.0  False  False   True
# 13128           0.0  South Built Esports          13.0  False   True  False
# 13337          13.0  South Built Esports           0.0   True   True  False
# 13338          13.0  South Built Esports           0.0   True  False   True
# 15465           0.0             Team Joy           0.0  False  False   True
# 15466           0.0             Team Joy           0.0  False   True  False
# 15559          10.0                 chiu          13.0  False  False   True
# 15560          10.0                 chiu          13.0  False   True  False
# 15677           0.0             Cat Gang           0.0  False   True  False
# 15678           0.0             Cat Gang           0.0  False  False   True
# 15921           0.0            Mindfreak           0.0  False  False   True
# 15922           0.0            Mindfreak           0.0  False   True  False
# 16159           0.0                ORDER           0.0  False  False   True
# 16160           0.0                ORDER           0.0  False   True  False
# 17768           0.0  Crash Landin on You           0.0  False   True  False
# 17769           0.0  Crash Landin on You           0.0  False  False   True
#
#        score diff comp code  invalid comp
# 4778         13.0      0000             5
# 6260          0.0      0000             5
# 6261          0.0      0000             5
# 9419          0.0      0000             5
# 9420          0.0      0000             5
# 10245        11.0      0000             5
# 10246        11.0      0000             5
# 11586         6.0      0000             5
# 11587         6.0      0000             5
# 13075        13.0      0000             5
# 13076        13.0      0000             5
# 13099        13.0      0000             5
# 13100        13.0      0000             5
# 13127        13.0      0000             5
# 13128        13.0      0000             5
# 13337        13.0      0000             5
# 13338        13.0      0000             5
# 15465         0.0      0000             5
# 15466         0.0      0000             5
# 15559         3.0      0000             5
# 15560         3.0      0000             4
# 15677         0.0      0000             5
# 15678         0.0      0000             5
# 15921         0.0      0000             5
# 15922         0.0      0000             4
# 16159         0.0      0000             5
# 16160         0.0      0000             5
# 17768         0.0      0000             5
# 17769         0.0      0000             5

# %% [markdown]
# It looks like rows with invalid compositions are corrupted.  We want to drop this as well.

# %%
vct_2022_comp_data = vct_2022_comp_data[vct_2022_comp_data["invalid comp"] == 0]
display(vct_2022_comp_data[vct_2022_comp_data["invalid comp"] != 0])  #### <- I just want to check it works as expected.
# Out:
# Empty DataFrame
# Columns: [Tournament, Stage, Match Type, Match Name, Map, Team, Agents, Team A, Team A Score, Team B, Team B Score, A win, win, loss, score diff, comp code, invalid comp]
# Index: []

# %%
keyfeatures = ["Tournament", "Stage", "Match Type", "Match Name", "Map", "Team", "Agents", "comp code", "win", "loss", "score diff"]
vct_2022_comp_data_cleaned = vct_2022_comp_data[keyfeatures]
vct_2022_comp_data_cleaned
# Out:
#                                               Tournament               Stage  \
# 0      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 1      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 2      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 3      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 4      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# ...                                                  ...                 ...
# 17795                   Valorant Conquerors Championship  Wildcard Qualifier
# 17796                   Valorant Conquerors Championship  Wildcard Qualifier
# 17797                   Valorant Conquerors Championship  Wildcard Qualifier
# 17798                   Valorant Conquerors Championship  Wildcard Qualifier
# 17799                   Valorant Conquerors Championship  Wildcard Qualifier
#
#                      Match Type                            Match Name     Map  \
# 0                   Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 1                   Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 2                   Decider (A)  Made in Thailand vs CERBERUS Esports    Bind
# 3                   Decider (A)  Made in Thailand vs CERBERUS Esports    Bind
# 4                   Decider (B)            Persija Esports vs Bonkers    Bind
# ...                         ...                                   ...     ...
# 17795  Upper Bracket Semifinals   Global Esports vs M1syl and friends  Breeze
# 17796  Upper Bracket Semifinals          Maruti Peek vs God Particles  Ascent
# 17797  Upper Bracket Semifinals          Maruti Peek vs God Particles  Ascent
# 17798  Upper Bracket Semifinals          Maruti Peek vs God Particles  Breeze
# 17799  Upper Bracket Semifinals          Maruti Peek vs God Particles  Breeze
#
#                     Team                            Agents comp code    win  \
# 0       CERBERUS Esports     breach,chamber,jett,omen,sova      1211  False
# 1       Made in Thailand      astra,jett,kayo,killjoy,sova      1211   True
# 2       CERBERUS Esports    astra,breach,chamber,jett,sova      1211  False
# 3       Made in Thailand    brimstone,raze,sage,skye,viper      1121   True
# 4                Bonkers  brimstone,chamber,neon,skye,sova      1211   True
# ...                  ...                               ...       ...    ...
# 17795  M1syl and friends      chamber,jett,skye,sova,viper      1211  False
# 17796      God Particles      astra,jett,killjoy,raze,sova      2111   True
# 17797        Maruti Peek      astra,jett,kayo,killjoy,sova      1211  False
# 17798      God Particles       cypher,jett,skye,sova,viper      1211   True
# 17799        Maruti Peek     chamber,jett,reyna,sova,viper      2111  False
#
#         loss  score diff
# 0       True         5.0
# 1      False         5.0
# 2       True        10.0
# 3      False        10.0
# 4      False         2.0
# ...      ...         ...
# 17795   True         5.0
# 17796  False        10.0
# 17797   True        10.0
# 17798  False        10.0
# 17799   True        10.0
#
# [17586 rows x 11 columns]

# %%
print("The number of unique comp codes:", len(vct_2022_comp_data_cleaned["comp code"].unique()))
print("The number of unique compositions:", len(vct_2022_comp_data_cleaned["Agents"].unique()))
# Out:
# The number of unique comp codes: 40
# The number of unique compositions: 1107

# %%
wincount_by_comp_code = vct_2022_comp_data_cleaned[["Map", "comp code", "win"]].groupby(["Map", "comp code"], as_index=False).agg("sum")
wincount_by_comp_code = wincount_by_comp_code\
                                .set_index(["Map", "comp code"])\
                                .rename(columns={"win": "win count"})

losscount_by_comp_code = vct_2022_comp_data_cleaned[["Map", "comp code", "loss"]].groupby(["Map", "comp code"], as_index=False).agg("sum")
losscount_by_comp_code = losscount_by_comp_code\
                                .set_index(["Map", "comp code"])\
                                .rename(columns={"loss": "loss count"})
# side_by_side(wincount_by_comp_code.sort_values(["Map", "win count"], ascending=False),
#                 losscount_by_comp_code.sort_values(["Map", "loss count"], ascending=False))

wincount_by_comp_code_sorted = wincount_by_comp_code.sort_values(["Map", "win count"], ascending=False)
losscount_by_comp_code_sorted = losscount_by_comp_code.sort_values(["Map", "loss count"], ascending=False)

# %%
maplist = vct_2022_comp_data_cleaned["Map"].unique()
mapdict = {}

for map in maplist:
    windf = wincount_by_comp_code_sorted.loc[map].head()
    lossdf = losscount_by_comp_code_sorted.loc[map].head()
    mapdict[map] = (windf, lossdf)

for map, df_tuple in mapdict.items():
    print("==============================")
    print(map)
    side_by_side(*df_tuple)
# Out:
# ==============================
# Ascent
# <div style="display:flex"><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>win count</th>
#     </tr>
#     <tr>
#       <th>comp code</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1211</th>
#       <td>1337</td>
#     </tr>
#     <tr>
#       <th>2111</th>
#       <td>191</td>
#     </tr>
#     <tr>
#       <th>1112</th>
#       <td>158</td>
#     </tr>
#     <tr>
#       <th>0212</th>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>0311</th>
#       <td>22</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>loss count</th>
#     </tr>
#     <tr>
#       <th>comp code</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1211</th>
#       <td>1369</td>
#     </tr>
#     <tr>
#       <th>2111</th>
#       <td>206</td>
#     </tr>
#     <tr>
#       <th>1112</th>
#       <td>108</td>
#     </tr>
#     <tr>
#       <th>0212</th>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>0311</th>
#       <td>17</td>
#     </tr>
#   </tbody>
# </table></div></div>
# ==============================
# Bind
# <div style="display:flex"><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>win count</th>
#     </tr>
#     <tr>
#       <th>comp code</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1121</th>
#       <td>349</td>
#     </tr>
#     <tr>
#       <th>1220</th>
#       <td>298</td>
#     </tr>
#     <tr>
#       <th>1211</th>
#       <td>274</td>
#     </tr>
#     <tr>
#       <th>2111</th>
#       <td>110</td>
#     </tr>
#     <tr>
#       <th>1112</th>
#       <td>64</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>loss count</th>
#     </tr>
#     <tr>
#       <th>comp code</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1211</th>
#       <td>325</td>
#     </tr>
#     <tr>
#       <th>1220</th>
#       <td>303</td>
#     </tr>
#     <tr>
#       <th>1121</th>
#       <td>278</td>
#     </tr>
#     <tr>
#       <th>2111</th>
#       <td>116</td>
#     </tr>
#     <tr>
#       <th>1112</th>
#       <td>74</td>
#     </tr>
#   </tbody>
# </table></div></div>
# ==============================
# Fracture
# <div style="display:flex"><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>win count</th>
#     </tr>
#     <tr>
#       <th>comp code</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1112</th>
#       <td>186</td>
#     </tr>
#     <tr>
#       <th>1121</th>
#       <td>164</td>
#     </tr>
#     <tr>
#       <th>1211</th>
#       <td>148</td>
#     </tr>
#     <tr>
#       <th>2111</th>
#       <td>86</td>
#     </tr>
#     <tr>
#       <th>2120</th>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>loss count</th>
#     </tr>
#     <tr>
#       <th>comp code</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1112</th>
#       <td>179</td>
#     </tr>
#     <tr>
#       <th>1211</th>
#       <td>167</td>
#     </tr>
#     <tr>
#       <th>1121</th>
#       <td>151</td>
#     </tr>
#     <tr>
#       <th>2111</th>
#       <td>79</td>
#     </tr>
#     <tr>
#       <th>1220</th>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table></div></div>
# ==============================
# Haven
# <div style="display:flex"><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>win count</th>
#     </tr>
#     <tr>
#       <th>comp code</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1211</th>
#       <td>1410</td>
#     </tr>
#     <tr>
#       <th>2111</th>
#       <td>157</td>
#     </tr>
#     <tr>
#       <th>1112</th>
#       <td>52</td>
#     </tr>
#     <tr>
#       <th>2210</th>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>0221</th>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>loss count</th>
#     </tr>
#     <tr>
#       <th>comp code</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1211</th>
#       <td>1365</td>
#     </tr>
#     <tr>
#       <th>2111</th>
#       <td>176</td>
#     </tr>
#     <tr>
#       <th>1112</th>
#       <td>48</td>
#     </tr>
#     <tr>
#       <th>2210</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>1121</th>
#       <td>10</td>
#     </tr>
#   </tbody>
# </table></div></div>
# ==============================
# Icebox
# <div style="display:flex"><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>win count</th>
#     </tr>
#     <tr>
#       <th>comp code</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1112</th>
#       <td>619</td>
#     </tr>
#     <tr>
#       <th>2111</th>
#       <td>490</td>
#     </tr>
#     <tr>
#       <th>1211</th>
#       <td>152</td>
#     </tr>
#     <tr>
#       <th>0212</th>
#       <td>102</td>
#     </tr>
#     <tr>
#       <th>1121</th>
#       <td>52</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>loss count</th>
#     </tr>
#     <tr>
#       <th>comp code</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1112</th>
#       <td>566</td>
#     </tr>
#     <tr>
#       <th>2111</th>
#       <td>522</td>
#     </tr>
#     <tr>
#       <th>1211</th>
#       <td>175</td>
#     </tr>
#     <tr>
#       <th>0212</th>
#       <td>102</td>
#     </tr>
#     <tr>
#       <th>1121</th>
#       <td>43</td>
#     </tr>
#   </tbody>
# </table></div></div>
# ==============================
# Split
# <div style="display:flex"><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>win count</th>
#     </tr>
#     <tr>
#       <th>comp code</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1112</th>
#       <td>330</td>
#     </tr>
#     <tr>
#       <th>1121</th>
#       <td>275</td>
#     </tr>
#     <tr>
#       <th>2012</th>
#       <td>131</td>
#     </tr>
#     <tr>
#       <th>1211</th>
#       <td>127</td>
#     </tr>
#     <tr>
#       <th>2111</th>
#       <td>72</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>loss count</th>
#     </tr>
#     <tr>
#       <th>comp code</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1112</th>
#       <td>335</td>
#     </tr>
#     <tr>
#       <th>1121</th>
#       <td>240</td>
#     </tr>
#     <tr>
#       <th>1211</th>
#       <td>144</td>
#     </tr>
#     <tr>
#       <th>2012</th>
#       <td>127</td>
#     </tr>
#     <tr>
#       <th>2111</th>
#       <td>88</td>
#     </tr>
#   </tbody>
# </table></div></div>
# ==============================
# Breeze
# <div style="display:flex"><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>win count</th>
#     </tr>
#     <tr>
#       <th>comp code</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1211</th>
#       <td>843</td>
#     </tr>
#     <tr>
#       <th>2111</th>
#       <td>104</td>
#     </tr>
#     <tr>
#       <th>0221</th>
#       <td>29</td>
#     </tr>
#     <tr>
#       <th>1112</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>1220</th>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>loss count</th>
#     </tr>
#     <tr>
#       <th>comp code</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1211</th>
#       <td>809</td>
#     </tr>
#     <tr>
#       <th>2111</th>
#       <td>108</td>
#     </tr>
#     <tr>
#       <th>0221</th>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>1112</th>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>0311</th>
#       <td>14</td>
#     </tr>
#   </tbody>
# </table></div></div>
# ==============================
# Pearl
# <div style="display:flex"><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>win count</th>
#     </tr>
#     <tr>
#       <th>comp code</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1211</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>0221</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1112</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1121</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>0212</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>loss count</th>
#     </tr>
#     <tr>
#       <th>comp code</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1121</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1211</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>0221</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>0212</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1112</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table></div></div>

# %%
mapdf = pd.get_dummies(vct_2022_comp_data_cleaned["Map"])  #dataframe with map played info that will be appended to the cleaned dataframe.

for map in maplist:
    vct_2022_comp_data_cleaned.loc[:,map] = mapdf[map]

# %%
vct_2022_comp_data_cleaned.keys()
# Out:
# Index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Team',
#        'Agents', 'comp code', 'win', 'loss', 'score diff', 'Ascent', 'Bind',
#        'Fracture', 'Haven', 'Icebox', 'Split', 'Breeze', 'Pearl'],
#       dtype='object')

# %%
# I want to define a funtion to get columns of individual characters to do linear regression on maps and characters.
# The following dictionary has all available characters in 2022 tournaments.  Characters played in other years are contained in this dictionary.
roles = {"duelist": {"jett", "phoenix", "reyna", "raze", "yoru", "neon"},
             "initiator": {"sova", "breach", "skye", "kayo", "fade"},
             "controller": {"brimstone", "omen", "viper", "astra"},
             "sentinel": {"cypher", "sage", "killjoy", "chamber"}}  
allcharacters = []
for role, chars in roles.items():
    allcharacters.extend(list(roles[role]))

allcharacters
# Out:
# ['yoru',
#  'neon',
#  'phoenix',
#  'jett',
#  'reyna',
#  'raze',
#  'sova',
#  'skye',
#  'fade',
#  'breach',
#  'kayo',
#  'omen',
#  'astra',
#  'brimstone',
#  'viper',
#  'killjoy',
#  'sage',
#  'cypher',
#  'chamber']

# %%
def is_in_comp(a: str, b: str) -> bool:
    """ 
    input: a charcter, and a team composition
    output: True if given character is in the composition, False otherwise
    """
    agentcomp = b.split(",")
    return a in agentcomp

# %%
for character in allcharacters:
    for index, row in vct_2022_comp_data_cleaned.iterrows():
        vct_2022_comp_data_cleaned.loc[:,character] = vct_2022_comp_data_cleaned["Agents"].apply(lambda x: is_in_comp(character, x))

vct_2022_comp_data_cleaned
# Out:
#                                               Tournament               Stage  \
# 0      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 1      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 2      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 3      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 4      Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# ...                                                  ...                 ...
# 17795                   Valorant Conquerors Championship  Wildcard Qualifier
# 17796                   Valorant Conquerors Championship  Wildcard Qualifier
# 17797                   Valorant Conquerors Championship  Wildcard Qualifier
# 17798                   Valorant Conquerors Championship  Wildcard Qualifier
# 17799                   Valorant Conquerors Championship  Wildcard Qualifier
#
#                      Match Type                            Match Name     Map  \
# 0                   Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 1                   Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 2                   Decider (A)  Made in Thailand vs CERBERUS Esports    Bind
# 3                   Decider (A)  Made in Thailand vs CERBERUS Esports    Bind
# 4                   Decider (B)            Persija Esports vs Bonkers    Bind
# ...                         ...                                   ...     ...
# 17795  Upper Bracket Semifinals   Global Esports vs M1syl and friends  Breeze
# 17796  Upper Bracket Semifinals          Maruti Peek vs God Particles  Ascent
# 17797  Upper Bracket Semifinals          Maruti Peek vs God Particles  Ascent
# 17798  Upper Bracket Semifinals          Maruti Peek vs God Particles  Breeze
# 17799  Upper Bracket Semifinals          Maruti Peek vs God Particles  Breeze
#
#                     Team                            Agents comp code    win  \
# 0       CERBERUS Esports     breach,chamber,jett,omen,sova      1211  False
# 1       Made in Thailand      astra,jett,kayo,killjoy,sova      1211   True
# 2       CERBERUS Esports    astra,breach,chamber,jett,sova      1211  False
# 3       Made in Thailand    brimstone,raze,sage,skye,viper      1121   True
# 4                Bonkers  brimstone,chamber,neon,skye,sova      1211   True
# ...                  ...                               ...       ...    ...
# 17795  M1syl and friends      chamber,jett,skye,sova,viper      1211  False
# 17796      God Particles      astra,jett,killjoy,raze,sova      2111   True
# 17797        Maruti Peek      astra,jett,kayo,killjoy,sova      1211  False
# 17798      God Particles       cypher,jett,skye,sova,viper      1211   True
# 17799        Maruti Peek     chamber,jett,reyna,sova,viper      2111  False
#
#         loss  ...   fade  breach   kayo   omen  astra  brimstone  viper  \
# 0       True  ...  False    True  False   True  False      False  False
# 1      False  ...  False   False   True  False   True      False  False
# 2       True  ...  False    True  False  False   True      False  False
# 3      False  ...  False   False  False  False  False       True   True
# 4      False  ...  False   False  False  False  False       True  False
# ...      ...  ...    ...     ...    ...    ...    ...        ...    ...
# 17795   True  ...  False   False  False  False  False      False   True
# 17796  False  ...  False   False  False  False   True      False  False
# 17797   True  ...  False   False   True  False   True      False  False
# 17798  False  ...  False   False  False  False  False      False   True
# 17799   True  ...  False   False  False  False  False      False   True
#
#         sage  cypher  chamber
# 0      False   False     True
# 1      False   False    False
# 2      False   False     True
# 3       True   False    False
# 4      False   False     True
# ...      ...     ...      ...
# 17795  False   False     True
# 17796  False   False    False
# 17797  False   False    False
# 17798  False    True    False
# 17799  False   False     True
#
# [17586 rows x 38 columns]

# %% [markdown]
# I want to do linear regression on individual agents and maps and that's why I wrote the cell right above.\
# However, the running time is 1 min 30 seconds for each character, so the above cell takes about 30 minutes to run.\
# I will make a new dataframe whose columns are:
# - Tournament
# - Stage
# - Match Type
# - Match Name
# - Map
# - List of maps
# - List of agents
# - Score
# - Score diff
# - Win.
#
# The first five features (Tournament, Stage, Match Type, Match Name, Map) can be used as the match id.
