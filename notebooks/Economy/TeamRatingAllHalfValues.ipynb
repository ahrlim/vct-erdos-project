# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
plt_kwargs = {'figsize': (10, 4)}

# %%
eco_rounds = pd.read_csv("../../data/vct_2022/matches/eco_rounds.csv")
#Map_Title = "Fracture"
#maps_scores = pd.read_csv("../../data/vct_2022/matches/maps_scores.csv")
#eco_stats = pd.read_csv("../../data/vct_2022/matches/eco_stats.csv")

# %%
#eco_rounds = eco_rounds.loc[ (eco_rounds["Map"]==Map_Title)]

eco_rounds["Outcome"] = eco_rounds["Outcome"].apply(lambda x: 1 if x == "Win" else 0)
eco_rounds["Loadout Value"] = eco_rounds["Loadout Value"].apply(lambda x: int(x.replace(".","").replace("k","00")))
eco_rounds["Remaining Credits"] = eco_rounds["Remaining Credits"].apply(lambda x: int(x.replace(".","").replace("k","00")))

eco_rounds
# Out:
#                                        Tournament             Stage  \
# 0                         Valorant Champions 2022       Group Stage
# 1                         Valorant Champions 2022       Group Stage
# 2                         Valorant Champions 2022       Group Stage
# 3                         Valorant Champions 2022       Group Stage
# 4                         Valorant Champions 2022       Group Stage
# ...                                           ...               ...
# 358793  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 358794  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 358795  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 358796  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 358797  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
#
#          Match Type                        Match Name    Map  Round Number  \
# 0       Opening (A)        Paper Rex vs EDward Gaming  Pearl             1
# 1       Opening (A)        Paper Rex vs EDward Gaming  Pearl             1
# 2       Opening (A)        Paper Rex vs EDward Gaming  Pearl             2
# 3       Opening (A)        Paper Rex vs EDward Gaming  Pearl             2
# 4       Opening (A)        Paper Rex vs EDward Gaming  Pearl             3
# ...             ...                               ...    ...           ...
# 358793  Grand Final  Natus Vincere vs FunPlus Phoenix  Split            14
# 358794  Grand Final  Natus Vincere vs FunPlus Phoenix  Split            15
# 358795  Grand Final  Natus Vincere vs FunPlus Phoenix  Split            15
# 358796  Grand Final  Natus Vincere vs FunPlus Phoenix  Split            16
# 358797  Grand Final  Natus Vincere vs FunPlus Phoenix  Split            16
#
#                    Team  Loadout Value  Remaining Credits              Type  \
# 0             Paper Rex           3700                100         Eco: 0-5k
# 1         EDward Gaming           4000                200         Eco: 0-5k
# 2             Paper Rex           1200               9600         Eco: 0-5k
# 3         EDward Gaming          15600               2400  Semi-buy: 10-20k
# 4             Paper Rex          21300                700    Full buy: 20k+
# ...                 ...            ...                ...               ...
# 358793  FunPlus Phoenix          15100                400  Semi-buy: 10-20k
# 358794    Natus Vincere          15700                500  Semi-buy: 10-20k
# 358795  FunPlus Phoenix          16900               5700  Semi-buy: 10-20k
# 358796    Natus Vincere          20000               4700  Semi-buy: 10-20k
# 358797  FunPlus Phoenix           6200               9300   Semi-eco: 5-10k
#
#         Outcome
# 0             0
# 1             1
# 2             0
# 3             1
# 4             0
# ...         ...
# 358793        1
# 358794        1
# 358795        0
# 358796        0
# 358797        1
#
# [358798 rows x 11 columns]

# %%
half_eco_rounds = eco_rounds.loc[ (eco_rounds["Round Number"]<13)]


half_eco_rounds
# Out:
#                                        Tournament             Stage  \
# 0                         Valorant Champions 2022       Group Stage
# 1                         Valorant Champions 2022       Group Stage
# 2                         Valorant Champions 2022       Group Stage
# 3                         Valorant Champions 2022       Group Stage
# 4                         Valorant Champions 2022       Group Stage
# ...                                           ...               ...
# 358785  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 358786  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 358787  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 358788  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 358789  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
#
#          Match Type                        Match Name    Map  Round Number  \
# 0       Opening (A)        Paper Rex vs EDward Gaming  Pearl             1
# 1       Opening (A)        Paper Rex vs EDward Gaming  Pearl             1
# 2       Opening (A)        Paper Rex vs EDward Gaming  Pearl             2
# 3       Opening (A)        Paper Rex vs EDward Gaming  Pearl             2
# 4       Opening (A)        Paper Rex vs EDward Gaming  Pearl             3
# ...             ...                               ...    ...           ...
# 358785  Grand Final  Natus Vincere vs FunPlus Phoenix  Split            10
# 358786  Grand Final  Natus Vincere vs FunPlus Phoenix  Split            11
# 358787  Grand Final  Natus Vincere vs FunPlus Phoenix  Split            11
# 358788  Grand Final  Natus Vincere vs FunPlus Phoenix  Split            12
# 358789  Grand Final  Natus Vincere vs FunPlus Phoenix  Split            12
#
#                    Team  Loadout Value  Remaining Credits              Type  \
# 0             Paper Rex           3700                100         Eco: 0-5k
# 1         EDward Gaming           4000                200         Eco: 0-5k
# 2             Paper Rex           1200               9600         Eco: 0-5k
# 3         EDward Gaming          15600               2400  Semi-buy: 10-20k
# 4             Paper Rex          21300                700    Full buy: 20k+
# ...                 ...            ...                ...               ...
# 358785  FunPlus Phoenix          23200              28000    Full buy: 20k+
# 358786    Natus Vincere          18700               1600  Semi-buy: 10-20k
# 358787  FunPlus Phoenix          23200              27100    Full buy: 20k+
# 358788    Natus Vincere          24200               7300    Full buy: 20k+
# 358789  FunPlus Phoenix          24200              10500    Full buy: 20k+
#
#         Outcome
# 0             0
# 1             1
# 2             0
# 3             1
# 4             0
# ...         ...
# 358785        1
# 358786        1
# 358787        0
# 358788        0
# 358789        1
#
# [211824 rows x 11 columns]

# %%
maps_scores = pd.read_csv("../../data/vct_2022/matches/maps_scores.csv")
maps_scores.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2022  Group Stage  Opening (A)
# 1  Valorant Champions 2022  Group Stage  Opening (A)
# 2  Valorant Champions 2022  Group Stage  Opening (A)
# 3  Valorant Champions 2022  Group Stage  Opening (A)
# 4  Valorant Champions 2022  Group Stage  Opening (A)
#
#                    Match Name     Map     Team A  Team A Score  \
# 0  Paper Rex vs EDward Gaming   Pearl  Paper Rex            13
# 1  Paper Rex vs EDward Gaming  Icebox  Paper Rex             5
# 2  Paper Rex vs EDward Gaming   Haven  Paper Rex            13
# 3     Leviatán vs Team Liquid   Haven   Leviatán            13
# 4     Leviatán vs Team Liquid  Ascent   Leviatán            13
#
#    Team A Attacker Score  Team A Defender Score  Team A Overtime Score  \
# 0                      6                      7                    NaN
# 1                      2                      3                    NaN
# 2                      7                      6                    NaN
# 3                      8                      5                    NaN
# 4                      6                      7                    NaN
#
#           Team B  Team B Score  Team B Attacker Score  Team B Defender Score  \
# 0  EDward Gaming            11                      5                      6
# 1  EDward Gaming            13                      3                     10
# 2  EDward Gaming             8                      3                      5
# 3    Team Liquid            10                      6                      4
# 4    Team Liquid            10                      4                      6
#
#    Team B Overtime Score Duration
# 0                    NaN  1:16:34
# 1                    NaN    40:51
# 2                    NaN      NaN
# 3                    NaN  1:04:37
# 4                    NaN  1:05:07

# %%
team_ab_2022 = maps_scores[["Tournament", "Stage", "Match Type", "Match Name", "Map", "Team A", "Team B"]]

team_ab_2022
# Out:
#                                      Tournament             Stage  \
# 0                       Valorant Champions 2022       Group Stage
# 1                       Valorant Champions 2022       Group Stage
# 2                       Valorant Champions 2022       Group Stage
# 3                       Valorant Champions 2022       Group Stage
# 4                       Valorant Champions 2022       Group Stage
# ...                                         ...               ...
# 8879  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 8880  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 8881  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 8882  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
# 8883  Champions Tour CIS Stage 1: Challengers 1  Closed Qualifier
#
#        Match Type                        Match Name     Map         Team A  \
# 0     Opening (A)        Paper Rex vs EDward Gaming   Pearl      Paper Rex
# 1     Opening (A)        Paper Rex vs EDward Gaming  Icebox      Paper Rex
# 2     Opening (A)        Paper Rex vs EDward Gaming   Haven      Paper Rex
# 3     Opening (A)           Leviatán vs Team Liquid   Haven       Leviatán
# 4     Opening (A)           Leviatán vs Team Liquid  Ascent       Leviatán
# ...           ...                               ...     ...            ...
# 8879  Grand Final  Natus Vincere vs FunPlus Phoenix    Bind  Natus Vincere
# 8880  Grand Final  Natus Vincere vs FunPlus Phoenix  Icebox  Natus Vincere
# 8881  Grand Final  Natus Vincere vs FunPlus Phoenix  Breeze  Natus Vincere
# 8882  Grand Final  Natus Vincere vs FunPlus Phoenix   Haven  Natus Vincere
# 8883  Grand Final  Natus Vincere vs FunPlus Phoenix   Split  Natus Vincere
#
#                Team B
# 0       EDward Gaming
# 1       EDward Gaming
# 2       EDward Gaming
# 3         Team Liquid
# 4         Team Liquid
# ...               ...
# 8879  FunPlus Phoenix
# 8880  FunPlus Phoenix
# 8881  FunPlus Phoenix
# 8882  FunPlus Phoenix
# 8883  FunPlus Phoenix
#
# [8884 rows x 7 columns]

# %%
keys = ['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map','Team']

Eco_rounds_ab_2022=\
pd.merge(
    team_ab_2022.rename(columns={"Team A":"Team"})\
    ,eco_rounds\
    ,on=keys
)\
.rename(columns={"Loadout Value":"Loadout_A", "Remaining Credits":"Remaining_credit_A", "Type":"Eco_type_A", "Outcome":"Outcome_A"})\
.rename(columns={"Team":"Team A", "Team B":"Team"})\
.set_index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map','Team', 'Round Number'])\
.join(eco_rounds\
      .set_index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map','Team', 'Round Number'])\
)\
.reset_index()\
.rename(columns={"Loadout Value":"Loadout_B", "Remaining Credits":"Remaining_credit_B", "Type":"Eco_type_B", "Outcome":"Outcome_B"})\
.rename(columns={"Team":"Team B"})

Eco_rounds_ab_2022.head()
# Out:
#                                           Tournament        Stage  \
# 0  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 1  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 2  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 3  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 4  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
#
#     Match Type                            Match Name     Map  \
# 0  Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 1  Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 2  Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 3  Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 4  Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
#
#              Team B  Round Number            Team A  Loadout_A  \
# 0  CERBERUS Esports             1  Made in Thailand       2900
# 1  CERBERUS Esports             2  Made in Thailand      16400
# 2  CERBERUS Esports             3  Made in Thailand      18800
# 3  CERBERUS Esports             4  Made in Thailand      22400
# 4  CERBERUS Esports             5  Made in Thailand       9100
#
#    Remaining_credit_A        Eco_type_A  Outcome_A  Loadout_B  \
# 0                 600         Eco: 0-5k          1       3800
# 1                 500  Semi-buy: 10-20k          1       3300
# 2               13100  Semi-buy: 10-20k          0      21700
# 3                1700    Full buy: 20k+          0      22800
# 4                8500   Semi-eco: 5-10k          0      21900
#
#    Remaining_credit_B      Eco_type_B  Outcome_B
# 0                 200       Eco: 0-5k          0
# 1                9000       Eco: 0-5k          0
# 2                 400  Full buy: 20k+          1
# 3                7200  Full buy: 20k+          1
# 4                3200  Full buy: 20k+          1

# %%
Eco_rounds_ab_2022[[ "Eco_type_A", "Eco_type_B", "Outcome_A", "Round Number"]].groupby([ "Eco_type_A", "Eco_type_B", "Outcome_A"]).count()
# Out:
#                                              Round Number
# Eco_type_A       Eco_type_B       Outcome_A
# Eco: 0-5k        Eco: 0-5k        0                  8321
#                                   1                  9497
#                  Full buy: 20k+   0                   649
#                                   1                    91
#                  Semi-buy: 10-20k 0                  6643
#                                   1                   701
#                  Semi-eco: 5-10k  0                     3
#                                   1                     2
# Full buy: 20k+   Eco: 0-5k        0                    77
#                                   1                   741
#                  Full buy: 20k+   0                 31204
#                                   1                 35179
#                  Semi-buy: 10-20k 0                  8490
#                                   1                 16129
#                  Semi-eco: 5-10k  0                  2084
#                                   1                 10186
# Semi-buy: 10-20k Eco: 0-5k        0                   605
#                                   1                  7574
#                  Full buy: 20k+   0                 13432
#                                   1                  8581
#                  Semi-buy: 10-20k 0                  2572
#                                   1                  3003
#                  Semi-eco: 5-10k  0                   269
#                                   1                  1217
# Semi-eco: 5-10k  Eco: 0-5k        0                     1
#                                   1                     3
#                  Full buy: 20k+   0                  8083
#                                   1                  2079
#                  Semi-buy: 10-20k 0                   975
#                                   1                   280
#                  Semi-eco: 5-10k  0                     1
#                                   1                     3

# %%
def RoundRating(LoadOutA, LoadoutB,  OutcomeA):
    LoadoutB = max(LoadoutB, 100)
    LoadOutA = max(LoadOutA, 100)
    if OutcomeA == 1:
        return LoadoutB/LoadOutA
    if OutcomeA == 0:
        return -LoadOutA/LoadoutB
    
def RoundRating2(x, y):
    return 5

# %%
RoundRating(2000, 2000, 1)
# Out:
# 1.0

# %%
Eco_rounds_ab_2022["Rating_A"]=Eco_rounds_ab_2022[["Loadout_A", "Loadout_B", "Outcome_A"]]\
    .apply(lambda row: RoundRating(row["Loadout_A"], row["Loadout_B"], row["Outcome_A"]), axis=1)

Eco_rounds_ab_2022["Rating_B"]=Eco_rounds_ab_2022[["Loadout_A", "Loadout_B", "Outcome_B"]]\
    .apply(lambda row: RoundRating(row["Loadout_B"], row["Loadout_A"], row["Outcome_B"]), axis=1)


Eco_rounds_ab_2022.head(10)
# Out:
#                                           Tournament        Stage  \
# 0  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 1  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 2  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 3  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 4  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 5  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 6  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 7  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 8  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 9  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
#
#     Match Type                            Match Name     Map  \
# 0  Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 1  Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 2  Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 3  Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 4  Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 5  Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 6  Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 7  Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 8  Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 9  Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
#
#              Team B  Round Number            Team A  Loadout_A  \
# 0  CERBERUS Esports             1  Made in Thailand       2900
# 1  CERBERUS Esports             2  Made in Thailand      16400
# 2  CERBERUS Esports             3  Made in Thailand      18800
# 3  CERBERUS Esports             4  Made in Thailand      22400
# 4  CERBERUS Esports             5  Made in Thailand       9100
# 5  CERBERUS Esports             6  Made in Thailand      21900
# 6  CERBERUS Esports             7  Made in Thailand      21700
# 7  CERBERUS Esports             8  Made in Thailand      24100
# 8  CERBERUS Esports             9  Made in Thailand      23300
# 9  CERBERUS Esports            10  Made in Thailand      21400
#
#    Remaining_credit_A        Eco_type_A  Outcome_A  Loadout_B  \
# 0                 600         Eco: 0-5k          1       3800
# 1                 500  Semi-buy: 10-20k          1       3300
# 2               13100  Semi-buy: 10-20k          0      21700
# 3                1700    Full buy: 20k+          0      22800
# 4                8500   Semi-eco: 5-10k          0      21900
# 5                2500    Full buy: 20k+          1      22600
# 6                3400    Full buy: 20k+          1      11400
# 7                7200    Full buy: 20k+          0      24400
# 8                3200    Full buy: 20k+          1      24300
# 9                3000    Full buy: 20k+          1      22500
#
#    Remaining_credit_B        Eco_type_B  Outcome_B  Rating_A  Rating_B
# 0                 200         Eco: 0-5k          0  1.310345 -1.310345
# 1                9000         Eco: 0-5k          0  0.201220 -0.201220
# 2                 400    Full buy: 20k+          1 -0.866359  0.866359
# 3                7200    Full buy: 20k+          1 -0.982456  0.982456
# 4                3200    Full buy: 20k+          1 -0.415525  0.415525
# 5                6800    Full buy: 20k+          0  1.031963 -1.031963
# 6               11200  Semi-buy: 10-20k          0  0.525346 -0.525346
# 7                9300    Full buy: 20k+          1 -0.987705  0.987705
# 8               19000    Full buy: 20k+          0  1.042918 -1.042918
# 9                9200    Full buy: 20k+          0  1.051402 -1.051402

# %%
keys = ['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map','Team A', 'Team B']
grouped5 = Eco_rounds_ab_2022.groupby(keys)
Eco_rounds_ab_2022["Match Rating A"]=grouped5["Rating_A"].transform(lambda x: x.mean())
Eco_rounds_ab_2022["Match Rating B"]=grouped5["Rating_B"].transform(lambda x: x.mean())

Eco_rounds_ab_2022.head(5)
# Out:
#                                           Tournament        Stage  \
# 0  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 1  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 2  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 3  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 4  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
#
#     Match Type                            Match Name     Map  \
# 0  Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 1  Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 2  Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 3  Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
# 4  Decider (A)  Made in Thailand vs CERBERUS Esports  Ascent
#
#              Team B  Round Number            Team A  Loadout_A  \
# 0  CERBERUS Esports             1  Made in Thailand       2900
# 1  CERBERUS Esports             2  Made in Thailand      16400
# 2  CERBERUS Esports             3  Made in Thailand      18800
# 3  CERBERUS Esports             4  Made in Thailand      22400
# 4  CERBERUS Esports             5  Made in Thailand       9100
#
#    Remaining_credit_A        Eco_type_A  Outcome_A  Loadout_B  \
# 0                 600         Eco: 0-5k          1       3800
# 1                 500  Semi-buy: 10-20k          1       3300
# 2               13100  Semi-buy: 10-20k          0      21700
# 3                1700    Full buy: 20k+          0      22800
# 4                8500   Semi-eco: 5-10k          0      21900
#
#    Remaining_credit_B      Eco_type_B  Outcome_B  Rating_A  Rating_B  \
# 0                 200       Eco: 0-5k          0  1.310345 -1.310345
# 1                9000       Eco: 0-5k          0  0.201220 -0.201220
# 2                 400  Full buy: 20k+          1 -0.866359  0.866359
# 3                7200  Full buy: 20k+          1 -0.982456  0.982456
# 4                3200  Full buy: 20k+          1 -0.415525  0.415525
#
#    Match Rating A  Match Rating B
# 0          0.1148         -0.1148
# 1          0.1148         -0.1148
# 2          0.1148         -0.1148
# 3          0.1148         -0.1148
# 4          0.1148         -0.1148

# %%
#keys = ['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map','Team A', 'Team B']
grouped6 = Eco_rounds_ab_2022.groupby(["Team A"])
Eco_rounds_ab_2022["Team Rating A"]=grouped6["Rating_A"].transform(lambda x: x.mean())
grouped6 = Eco_rounds_ab_2022.groupby(["Team B"])
Eco_rounds_ab_2022["Team Rating B"]=grouped6["Rating_B"].transform(lambda x: x.mean())

Eco_rounds_ab_2022
# Out:
#                                                Tournament               Stage  \
# 0       Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 1       Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 2       Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 3       Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 4       Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# ...                                                   ...                 ...
# 178670                   Valorant Conquerors Championship  Wildcard Qualifier
# 178671                   Valorant Conquerors Championship  Wildcard Qualifier
# 178672                   Valorant Conquerors Championship  Wildcard Qualifier
# 178673                   Valorant Conquerors Championship  Wildcard Qualifier
# 178674                   Valorant Conquerors Championship  Wildcard Qualifier
#
#                       Match Type                            Match Name  \
# 0                    Decider (A)  Made in Thailand vs CERBERUS Esports
# 1                    Decider (A)  Made in Thailand vs CERBERUS Esports
# 2                    Decider (A)  Made in Thailand vs CERBERUS Esports
# 3                    Decider (A)  Made in Thailand vs CERBERUS Esports
# 4                    Decider (A)  Made in Thailand vs CERBERUS Esports
# ...                          ...                                   ...
# 178670  Upper Bracket Semifinals          Maruti Peek vs God Particles
# 178671  Upper Bracket Semifinals          Maruti Peek vs God Particles
# 178672  Upper Bracket Semifinals          Maruti Peek vs God Particles
# 178673  Upper Bracket Semifinals          Maruti Peek vs God Particles
# 178674  Upper Bracket Semifinals          Maruti Peek vs God Particles
#
#            Map            Team B  Round Number            Team A  Loadout_A  \
# 0       Ascent  CERBERUS Esports             1  Made in Thailand       2900
# 1       Ascent  CERBERUS Esports             2  Made in Thailand      16400
# 2       Ascent  CERBERUS Esports             3  Made in Thailand      18800
# 3       Ascent  CERBERUS Esports             4  Made in Thailand      22400
# 4       Ascent  CERBERUS Esports             5  Made in Thailand       9100
# ...        ...               ...           ...               ...        ...
# 178670  Breeze     God Particles            12       Maruti Peek      22300
# 178671  Breeze     God Particles            13       Maruti Peek       3800
# 178672  Breeze     God Particles            14       Maruti Peek      15400
# 178673  Breeze     God Particles            15       Maruti Peek      21200
# 178674  Breeze     God Particles            16       Maruti Peek      20500
#
#         Remaining_credit_A  ... Loadout_B  Remaining_credit_B  \
# 0                      600  ...      3800                 200
# 1                      500  ...      3300                9000
# 2                    13100  ...     21700                 400
# 3                     1700  ...     22800                7200
# 4                     8500  ...     21900                3200
# ...                    ...  ...       ...                 ...
# 178670                1700  ...     26900               16100
# 178671                 300  ...      4000                 200
# 178672                3000  ...      1600                9300
# 178673                8500  ...     20600                1000
# 178674                1100  ...     19500                4200
#
#               Eco_type_B  Outcome_B  Rating_A  Rating_B  Match Rating A  \
# 0              Eco: 0-5k          0  1.310345 -1.310345        0.114800
# 1              Eco: 0-5k          0  0.201220 -0.201220        0.114800
# 2         Full buy: 20k+          1 -0.866359  0.866359        0.114800
# 3         Full buy: 20k+          1 -0.982456  0.982456        0.114800
# 4         Full buy: 20k+          1 -0.415525  0.415525        0.114800
# ...                  ...        ...       ...       ...             ...
# 178670    Full buy: 20k+          1 -0.828996  0.828996       -0.492629
# 178671         Eco: 0-5k          0  1.052632 -1.052632       -0.492629
# 178672         Eco: 0-5k          0  0.103896 -0.103896       -0.492629
# 178673    Full buy: 20k+          1 -1.029126  1.029126       -0.492629
# 178674  Semi-buy: 10-20k          1 -1.051282  1.051282       -0.492629
#
#         Match Rating B  Team Rating A  Team Rating B
# 0            -0.114800      -0.005523       0.012610
# 1            -0.114800      -0.005523       0.012610
# 2            -0.114800      -0.005523       0.012610
# 3            -0.114800      -0.005523       0.012610
# 4            -0.114800      -0.005523       0.012610
# ...                ...            ...            ...
# 178670        0.492629      -0.040756       0.056728
# 178671        0.492629      -0.040756       0.056728
# 178672        0.492629      -0.040756       0.056728
# 178673        0.492629      -0.040756       0.056728
# 178674        0.492629      -0.040756       0.056728
#
# [178675 rows x 22 columns]

# %%
Eco_rounds_ab_2022[['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map','Team A', 'Team B', 'Team Rating A', 'Team Rating B']]
# Out:
#                                                Tournament               Stage  \
# 0       Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 1       Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 2       Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 3       Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 4       Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# ...                                                   ...                 ...
# 178670                   Valorant Conquerors Championship  Wildcard Qualifier
# 178671                   Valorant Conquerors Championship  Wildcard Qualifier
# 178672                   Valorant Conquerors Championship  Wildcard Qualifier
# 178673                   Valorant Conquerors Championship  Wildcard Qualifier
# 178674                   Valorant Conquerors Championship  Wildcard Qualifier
#
#                       Match Type                            Match Name  \
# 0                    Decider (A)  Made in Thailand vs CERBERUS Esports
# 1                    Decider (A)  Made in Thailand vs CERBERUS Esports
# 2                    Decider (A)  Made in Thailand vs CERBERUS Esports
# 3                    Decider (A)  Made in Thailand vs CERBERUS Esports
# 4                    Decider (A)  Made in Thailand vs CERBERUS Esports
# ...                          ...                                   ...
# 178670  Upper Bracket Semifinals          Maruti Peek vs God Particles
# 178671  Upper Bracket Semifinals          Maruti Peek vs God Particles
# 178672  Upper Bracket Semifinals          Maruti Peek vs God Particles
# 178673  Upper Bracket Semifinals          Maruti Peek vs God Particles
# 178674  Upper Bracket Semifinals          Maruti Peek vs God Particles
#
#            Map            Team A            Team B  Team Rating A  \
# 0       Ascent  Made in Thailand  CERBERUS Esports      -0.005523
# 1       Ascent  Made in Thailand  CERBERUS Esports      -0.005523
# 2       Ascent  Made in Thailand  CERBERUS Esports      -0.005523
# 3       Ascent  Made in Thailand  CERBERUS Esports      -0.005523
# 4       Ascent  Made in Thailand  CERBERUS Esports      -0.005523
# ...        ...               ...               ...            ...
# 178670  Breeze       Maruti Peek     God Particles      -0.040756
# 178671  Breeze       Maruti Peek     God Particles      -0.040756
# 178672  Breeze       Maruti Peek     God Particles      -0.040756
# 178673  Breeze       Maruti Peek     God Particles      -0.040756
# 178674  Breeze       Maruti Peek     God Particles      -0.040756
#
#         Team Rating B
# 0            0.012610
# 1            0.012610
# 2            0.012610
# 3            0.012610
# 4            0.012610
# ...               ...
# 178670       0.056728
# 178671       0.056728
# 178672       0.056728
# 178673       0.056728
# 178674       0.056728
#
# [178675 rows x 9 columns]

# %%
Eco_rounds_ab_2022.sort_values(by=["Team Rating A"], ascending=False).head()
# Out:
#                                                Tournament              Stage  \
# 120896  Champions Tour North America Stage 2: Challengers  Open Qualifier #1
# 120893  Champions Tour North America Stage 2: Challengers  Open Qualifier #1
# 120892  Champions Tour North America Stage 2: Challengers  Open Qualifier #1
# 120912  Champions Tour North America Stage 2: Challengers  Open Qualifier #1
# 120913  Champions Tour North America Stage 2: Challengers  Open Qualifier #1
#
#           Match Type           Match Name     Map     Team B  Round Number  \
# 120896  Round of 128  Gifted vs Immortals  Breeze  Immortals            16
# 120893  Round of 128  Gifted vs Immortals  Breeze  Immortals            13
# 120892  Round of 128  Gifted vs Immortals  Breeze  Immortals            12
# 120912  Round of 128  Gifted vs Immortals   Haven  Immortals             9
# 120913  Round of 128  Gifted vs Immortals   Haven  Immortals            10
#
#         Team A  Loadout_A  Remaining_credit_A  ... Loadout_B  \
# 120896  Gifted      24000               16200  ...      8800
# 120893  Gifted       3900                 200  ...      3500
# 120892  Gifted      25500               14400  ...     22900
# 120912  Gifted      23200               26600  ...     20700
# 120913  Gifted      23200               36300  ...     10500
#
#         Remaining_credit_B        Eco_type_B  Outcome_B  Rating_A  Rating_B  \
# 120896                8500   Semi-eco: 5-10k          0  0.366667 -0.366667
# 120893                 100         Eco: 0-5k          0  0.897436 -0.897436
# 120892                7200    Full buy: 20k+          1 -1.113537  1.113537
# 120912                 900    Full buy: 20k+          0  0.892241 -0.892241
# 120913                7600  Semi-buy: 10-20k          0  0.452586 -0.452586
#
#         Match Rating A  Match Rating B  Team Rating A  Team Rating B
# 120896        0.150365       -0.150365       0.593484      -0.593484
# 120893        0.150365       -0.150365       0.593484      -0.593484
# 120892        0.150365       -0.150365       0.593484      -0.593484
# 120912        1.272932       -1.272932       0.593484      -0.593484
# 120913        1.272932       -1.272932       0.593484      -0.593484
#
# [5 rows x 22 columns]

# %%
Half_Eco_rounds_ab_2022 = Eco_rounds_ab_2022.loc[Eco_rounds_ab_2022["Round Number"]<13]
Half_Eco_rounds_ab_2022
# Out:
#                                                Tournament               Stage  \
# 0       Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 1       Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 2       Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 3       Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 4       Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# ...                                                   ...                 ...
# 178666                   Valorant Conquerors Championship  Wildcard Qualifier
# 178667                   Valorant Conquerors Championship  Wildcard Qualifier
# 178668                   Valorant Conquerors Championship  Wildcard Qualifier
# 178669                   Valorant Conquerors Championship  Wildcard Qualifier
# 178670                   Valorant Conquerors Championship  Wildcard Qualifier
#
#                       Match Type                            Match Name  \
# 0                    Decider (A)  Made in Thailand vs CERBERUS Esports
# 1                    Decider (A)  Made in Thailand vs CERBERUS Esports
# 2                    Decider (A)  Made in Thailand vs CERBERUS Esports
# 3                    Decider (A)  Made in Thailand vs CERBERUS Esports
# 4                    Decider (A)  Made in Thailand vs CERBERUS Esports
# ...                          ...                                   ...
# 178666  Upper Bracket Semifinals          Maruti Peek vs God Particles
# 178667  Upper Bracket Semifinals          Maruti Peek vs God Particles
# 178668  Upper Bracket Semifinals          Maruti Peek vs God Particles
# 178669  Upper Bracket Semifinals          Maruti Peek vs God Particles
# 178670  Upper Bracket Semifinals          Maruti Peek vs God Particles
#
#            Map            Team B  Round Number            Team A  Loadout_A  \
# 0       Ascent  CERBERUS Esports             1  Made in Thailand       2900
# 1       Ascent  CERBERUS Esports             2  Made in Thailand      16400
# 2       Ascent  CERBERUS Esports             3  Made in Thailand      18800
# 3       Ascent  CERBERUS Esports             4  Made in Thailand      22400
# 4       Ascent  CERBERUS Esports             5  Made in Thailand       9100
# ...        ...               ...           ...               ...        ...
# 178666  Breeze     God Particles             8       Maruti Peek      13400
# 178667  Breeze     God Particles             9       Maruti Peek      19500
# 178668  Breeze     God Particles            10       Maruti Peek       9900
# 178669  Breeze     God Particles            11       Maruti Peek      24300
# 178670  Breeze     God Particles            12       Maruti Peek      22300
#
#         Remaining_credit_A  ... Loadout_B  Remaining_credit_B      Eco_type_B  \
# 0                      600  ...      3800                 200       Eco: 0-5k
# 1                      500  ...      3300                9000       Eco: 0-5k
# 2                    13100  ...     21700                 400  Full buy: 20k+
# 3                     1700  ...     22800                7200  Full buy: 20k+
# 4                     8500  ...     21900                3200  Full buy: 20k+
# ...                    ...  ...       ...                 ...             ...
# 178666                4300  ...     22700               31000  Full buy: 20k+
# 178667                1800  ...     22900               25100  Full buy: 20k+
# 178668                9100  ...     23500               33400  Full buy: 20k+
# 178669                1600  ...     25900               39400  Full buy: 20k+
# 178670                1700  ...     26900               16100  Full buy: 20k+
#
#         Outcome_B  Rating_A  Rating_B  Match Rating A  Match Rating B  \
# 0               0  1.310345 -1.310345        0.114800       -0.114800
# 1               0  0.201220 -0.201220        0.114800       -0.114800
# 2               1 -0.866359  0.866359        0.114800       -0.114800
# 3               1 -0.982456  0.982456        0.114800       -0.114800
# 4               1 -0.415525  0.415525        0.114800       -0.114800
# ...           ...       ...       ...             ...             ...
# 178666          1 -0.590308  0.590308       -0.492629        0.492629
# 178667          1 -0.851528  0.851528       -0.492629        0.492629
# 178668          1 -0.421277  0.421277       -0.492629        0.492629
# 178669          0  1.065844 -1.065844       -0.492629        0.492629
# 178670          1 -0.828996  0.828996       -0.492629        0.492629
#
#         Team Rating A  Team Rating B
# 0           -0.005523       0.012610
# 1           -0.005523       0.012610
# 2           -0.005523       0.012610
# 3           -0.005523       0.012610
# 4           -0.005523       0.012610
# ...               ...            ...
# 178666      -0.040756       0.056728
# 178667      -0.040756       0.056728
# 178668      -0.040756       0.056728
# 178669      -0.040756       0.056728
# 178670      -0.040756       0.056728
#
# [105540 rows x 22 columns]

# %%
grouped_rating_df_A = Eco_rounds_ab_2022.groupby(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Team A'])["Rating_A"].agg("mean").reset_index()
grouped_rating_df_B = Eco_rounds_ab_2022.groupby(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Team B'])["Rating_B"].agg("mean").reset_index()
#print(grouped_rating_df_A.head())
grouped_rating_df_B.head()
# Out:
#                                           Tournament        Stage  \
# 0  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 1  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 2  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 3  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 4  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
#
#     Match Type                            Match Name       Map  \
# 0  Decider (A)  Made in Thailand vs CERBERUS Esports    Ascent
# 1  Decider (A)  Made in Thailand vs CERBERUS Esports      Bind
# 2  Decider (B)            Persija Esports vs Bonkers      Bind
# 3  Decider (B)            Persija Esports vs Bonkers  Fracture
# 4  Decider (B)            Persija Esports vs Bonkers     Haven
#
#              Team B  Rating_B
# 0  CERBERUS Esports -0.114800
# 1  CERBERUS Esports -0.440027
# 2           Bonkers  0.049020
# 3           Bonkers -0.037580
# 4           Bonkers -0.132635

# %%
half_grouped_rating_df_A = Half_Eco_rounds_ab_2022.groupby(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Team A'])["Rating_A"].agg("mean").reset_index()
half_grouped_rating_df_B = Half_Eco_rounds_ab_2022.groupby(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Team B'])["Rating_B"].agg("mean").reset_index()
#print(grouped_rating_df_A.head())
half_grouped_rating_df_B.head()
# Out:
#                                           Tournament        Stage  \
# 0  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 1  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 2  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 3  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
# 4  Champions Tour Asia-Pacific Stage 1: Challenge...  Group Stage
#
#     Match Type                            Match Name       Map  \
# 0  Decider (A)  Made in Thailand vs CERBERUS Esports    Ascent
# 1  Decider (A)  Made in Thailand vs CERBERUS Esports      Bind
# 2  Decider (B)            Persija Esports vs Bonkers      Bind
# 3  Decider (B)            Persija Esports vs Bonkers  Fracture
# 4  Decider (B)            Persija Esports vs Bonkers     Haven
#
#              Team B  Rating_B
# 0  CERBERUS Esports -0.140378
# 1  CERBERUS Esports -0.528703
# 2           Bonkers -0.008694
# 3           Bonkers  0.247368
# 4           Bonkers -0.272200

# %%
maps_scores["Team_A_win"] = maps_scores["Team A Score"] > maps_scores["Team B Score"]
maps_scores["Team_B_win"] = maps_scores["Team B Score"] > maps_scores["Team A Score"]

maps_scores.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2022  Group Stage  Opening (A)
# 1  Valorant Champions 2022  Group Stage  Opening (A)
# 2  Valorant Champions 2022  Group Stage  Opening (A)
# 3  Valorant Champions 2022  Group Stage  Opening (A)
# 4  Valorant Champions 2022  Group Stage  Opening (A)
#
#                    Match Name     Map     Team A  Team A Score  \
# 0  Paper Rex vs EDward Gaming   Pearl  Paper Rex            13
# 1  Paper Rex vs EDward Gaming  Icebox  Paper Rex             5
# 2  Paper Rex vs EDward Gaming   Haven  Paper Rex            13
# 3     Leviatán vs Team Liquid   Haven   Leviatán            13
# 4     Leviatán vs Team Liquid  Ascent   Leviatán            13
#
#    Team A Attacker Score  Team A Defender Score  Team A Overtime Score  \
# 0                      6                      7                    NaN
# 1                      2                      3                    NaN
# 2                      7                      6                    NaN
# 3                      8                      5                    NaN
# 4                      6                      7                    NaN
#
#           Team B  Team B Score  Team B Attacker Score  Team B Defender Score  \
# 0  EDward Gaming            11                      5                      6
# 1  EDward Gaming            13                      3                     10
# 2  EDward Gaming             8                      3                      5
# 3    Team Liquid            10                      6                      4
# 4    Team Liquid            10                      4                      6
#
#    Team B Overtime Score Duration  Team_A_win  Team_B_win
# 0                    NaN  1:16:34        True       False
# 1                    NaN    40:51       False        True
# 2                    NaN      NaN        True       False
# 3                    NaN  1:04:37        True       False
# 4                    NaN  1:05:07        True       False

# %%
maps_scores = maps_scores[["Tournament", "Stage", "Match Type", "Match Name", "Map", "Team A", "Team A Score", "Team_A_win", "Team B", "Team B Score", "Team_B_win"]]

# %%
#maps_scores = maps_scores.loc[ (maps_scores["Map"]==Map_Title)]
maps_scores.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2022  Group Stage  Opening (A)
# 1  Valorant Champions 2022  Group Stage  Opening (A)
# 2  Valorant Champions 2022  Group Stage  Opening (A)
# 3  Valorant Champions 2022  Group Stage  Opening (A)
# 4  Valorant Champions 2022  Group Stage  Opening (A)
#
#                    Match Name     Map     Team A  Team A Score  Team_A_win  \
# 0  Paper Rex vs EDward Gaming   Pearl  Paper Rex            13        True
# 1  Paper Rex vs EDward Gaming  Icebox  Paper Rex             5       False
# 2  Paper Rex vs EDward Gaming   Haven  Paper Rex            13        True
# 3     Leviatán vs Team Liquid   Haven   Leviatán            13        True
# 4     Leviatán vs Team Liquid  Ascent   Leviatán            13        True
#
#           Team B  Team B Score  Team_B_win
# 0  EDward Gaming            11       False
# 1  EDward Gaming            13        True
# 2  EDward Gaming             8       False
# 3    Team Liquid            10       False
# 4    Team Liquid            10       False

# %%
maps_scores.keys()
# Out:
# Index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Team A',
#        'Team A Score', 'Team_A_win', 'Team B', 'Team B Score', 'Team_B_win'],
#       dtype='object')

# %%
final_rating_df =\
      maps_scores.set_index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Team A'])\
                  .join(grouped_rating_df_A\
                        .rename(columns={"Rating_A":"Team_A_rating"})\
                        .set_index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Team A'])\
                  )\
                  .reset_index()\
                  .set_index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Team B'])\
                  .join(grouped_rating_df_B\
                        .rename(columns={"Rating_B":"Team_B_rating"})\
                        .set_index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Team B'])\
                  )\
                  .reset_index()

# %%
final_rating_df
# Out:
#                                              Tournament               Stage  \
# 0     Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 1     Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 2     Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 3     Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 4     Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# ...                                                 ...                 ...
# 8879                   Valorant Conquerors Championship  Wildcard Qualifier
# 8880                   Valorant Conquerors Championship  Wildcard Qualifier
# 8881                   Valorant Conquerors Championship  Wildcard Qualifier
# 8882                   Valorant Conquerors Championship  Wildcard Qualifier
# 8883                   Valorant Conquerors Championship  Wildcard Qualifier
#
#                     Match Type                            Match Name  \
# 0                  Decider (A)  Made in Thailand vs CERBERUS Esports
# 1                  Decider (A)  Made in Thailand vs CERBERUS Esports
# 2                  Decider (B)            Persija Esports vs Bonkers
# 3                  Decider (B)            Persija Esports vs Bonkers
# 4                  Decider (B)            Persija Esports vs Bonkers
# ...                        ...                                   ...
# 8879     Upper Bracket Round 1     M1syl and friends vs Salt Esports
# 8880  Upper Bracket Semifinals   Global Esports vs M1syl and friends
# 8881  Upper Bracket Semifinals   Global Esports vs M1syl and friends
# 8882  Upper Bracket Semifinals          Maruti Peek vs God Particles
# 8883  Upper Bracket Semifinals          Maruti Peek vs God Particles
#
#            Map             Team B             Team A  Team A Score  \
# 0       Ascent   CERBERUS Esports   Made in Thailand            13
# 1         Bind   CERBERUS Esports   Made in Thailand            13
# 2         Bind            Bonkers    Persija Esports            15
# 3     Fracture            Bonkers    Persija Esports            15
# 4        Haven            Bonkers    Persija Esports            15
# ...        ...                ...                ...           ...
# 8879     Haven       Salt Esports  M1syl and friends            13
# 8880      Bind  M1syl and friends     Global Esports            13
# 8881    Breeze  M1syl and friends     Global Esports            13
# 8882    Ascent      God Particles        Maruti Peek             3
# 8883    Breeze      God Particles        Maruti Peek             3
#
#       Team_A_win  Team B Score  Team_B_win  Team_A_rating  Team_B_rating
# 0           True             8       False       0.114800      -0.114800
# 1           True             3       False       0.440027      -0.440027
# 2          False            17        True      -0.049020       0.049020
# 3           True            13       False       0.037580      -0.037580
# 4           True            13       False       0.132635      -0.132635
# ...          ...           ...         ...            ...            ...
# 8879        True            11       False       0.058145      -0.058145
# 8880        True             4       False       0.316246      -0.316246
# 8881        True             8       False       0.207972      -0.207972
# 8882       False            13        True      -0.338892       0.338892
# 8883       False            13        True      -0.492629       0.492629
#
# [8884 rows x 13 columns]

# %%
half_final_rating_df =\
      maps_scores.set_index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Team A'])\
                  .join(half_grouped_rating_df_A\
                        .rename(columns={"Rating_A":"Team_A_rating"})\
                        .set_index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Team A'])\
                  )\
                  .reset_index()\
                  .set_index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Team B'])\
                  .join(half_grouped_rating_df_B\
                        .rename(columns={"Rating_B":"Team_B_rating"})\
                        .set_index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Team B'])\
                  )\
                  .reset_index()

# %%
half_final_rating_df
# Out:
#                                              Tournament               Stage  \
# 0     Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 1     Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 2     Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 3     Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# 4     Champions Tour Asia-Pacific Stage 1: Challenge...         Group Stage
# ...                                                 ...                 ...
# 8879                   Valorant Conquerors Championship  Wildcard Qualifier
# 8880                   Valorant Conquerors Championship  Wildcard Qualifier
# 8881                   Valorant Conquerors Championship  Wildcard Qualifier
# 8882                   Valorant Conquerors Championship  Wildcard Qualifier
# 8883                   Valorant Conquerors Championship  Wildcard Qualifier
#
#                     Match Type                            Match Name  \
# 0                  Decider (A)  Made in Thailand vs CERBERUS Esports
# 1                  Decider (A)  Made in Thailand vs CERBERUS Esports
# 2                  Decider (B)            Persija Esports vs Bonkers
# 3                  Decider (B)            Persija Esports vs Bonkers
# 4                  Decider (B)            Persija Esports vs Bonkers
# ...                        ...                                   ...
# 8879     Upper Bracket Round 1     M1syl and friends vs Salt Esports
# 8880  Upper Bracket Semifinals   Global Esports vs M1syl and friends
# 8881  Upper Bracket Semifinals   Global Esports vs M1syl and friends
# 8882  Upper Bracket Semifinals          Maruti Peek vs God Particles
# 8883  Upper Bracket Semifinals          Maruti Peek vs God Particles
#
#            Map             Team B             Team A  Team A Score  \
# 0       Ascent   CERBERUS Esports   Made in Thailand            13
# 1         Bind   CERBERUS Esports   Made in Thailand            13
# 2         Bind            Bonkers    Persija Esports            15
# 3     Fracture            Bonkers    Persija Esports            15
# 4        Haven            Bonkers    Persija Esports            15
# ...        ...                ...                ...           ...
# 8879     Haven       Salt Esports  M1syl and friends            13
# 8880      Bind  M1syl and friends     Global Esports            13
# 8881    Breeze  M1syl and friends     Global Esports            13
# 8882    Ascent      God Particles        Maruti Peek             3
# 8883    Breeze      God Particles        Maruti Peek             3
#
#       Team_A_win  Team B Score  Team_B_win  Team_A_rating  Team_B_rating
# 0           True             8       False       0.140378      -0.140378
# 1           True             3       False       0.528703      -0.528703
# 2          False            17        True       0.008694      -0.008694
# 3           True            13       False      -0.247368       0.247368
# 4           True            13       False       0.272200      -0.272200
# ...          ...           ...         ...            ...            ...
# 8879        True            11       False       0.244047      -0.244047
# 8880        True             4       False       0.339463      -0.339463
# 8881        True             8       False       0.405931      -0.405931
# 8882       False            13        True      -0.163437       0.163437
# 8883       False            13        True      -0.579849       0.579849
#
# [8884 rows x 13 columns]

# %%
len(final_rating_df)
# Out:
# 8884

# %%
final_rating_df.Team_A_rating.isna().sum()
# Out:
# 113

# %%
final_rating_df=final_rating_df.dropna()

# %%
final_rating_df.Team_A_rating.isna().sum()
# Out:
# 0

# %%
half_final_rating_df=half_final_rating_df.dropna()
half_final_rating_df.Team_A_rating.isna().sum()
# Out:
# 0

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %%
final_rating_df.keys()
# Out:
# Index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Map', 'Team B',
#        'Team A', 'Team A Score', 'Team_A_win', 'Team B Score', 'Team_B_win',
#        'Team_A_rating', 'Team_B_rating'],
#       dtype='object')

# %%
scaler = StandardScaler()
scaler_A = StandardScaler()
scaler_B = StandardScaler()

scaler.fit(pd.concat([final_rating_df.Team_A_rating, final_rating_df.Team_B_rating]).to_numpy().reshape(-1,1))
scaler_A.fit(final_rating_df.Team_A_rating.to_numpy().reshape(-1,1))
scaler_B.fit(final_rating_df.Team_B_rating.to_numpy().reshape(-1,1))
# Out:
# StandardScaler()

# %%
print("mean of ratings:", scaler.mean_)
print("variance of ratings:", scaler.var_)

print("mean of team A ratings:", scaler_A.mean_)
print("variance of team B ratings:", scaler_A.var_)

print("mean of team B ratings:", scaler_B.mean_)
print("variance of team B ratings:", scaler_B.var_)
# Out:
# mean of ratings: [-4.65810139e-18]
# variance of ratings: [0.11196504]
# mean of team A ratings: [0.05868178]
# variance of team B ratings: [0.10852149]
# mean of team B ratings: [-0.05868178]
# variance of team B ratings: [0.10852149]

# %%
alpha = 0.3  # Opacity of scatter plot

# %%
plt.figure(figsize=(14,6))
#plt.subplot(1, 2, 1)  # row 1, column 2, count 1

plt.scatter(
    final_rating_df[final_rating_df.Team_A_win == True].Team_A_rating,
    final_rating_df[final_rating_df.Team_A_win == True].Team_B_rating,
    c="blue",
    alpha=alpha,
    label = "A win"
)

plt.scatter(
    final_rating_df[final_rating_df.Team_A_win == False].Team_A_rating,
    final_rating_df[final_rating_df.Team_A_win == False].Team_B_rating,
    c="red",
    alpha=alpha,
    label= "B win"
)
plt.plot(range(-1,1), range(-1,1), linestyle="dotted", color="grey", label="A rating = B rating")
plt.xlabel("Team A rating")
plt.ylabel("Team B rating")

# using subplot function and creating plot two
# row 1, column 2, count 2
# plt.subplot(1, 2, 2)
 
# plt.scatter(
#     scaler.transform(final_rating_df[final_rating_df.Team_A_win == True].Team_A_rating.to_numpy().reshape(-1,1)),
#     scaler.transform(final_rating_df[final_rating_df.Team_A_win == True].Team_B_rating.to_numpy().reshape(-1,1)),
#     c="blue",
#     alpha=alpha,
#     label="A win"
# )

# plt.scatter(
#     scaler.transform(final_rating_df[final_rating_df.Team_A_win == False].Team_A_rating.to_numpy().reshape(-1,1)),
#     scaler.transform(final_rating_df[final_rating_df.Team_A_win == False].Team_B_rating.to_numpy().reshape(-1,1)),
#     c="red",
#     alpha=alpha,
#     label ="B win"
# )

# plt.plot(range(-4,5), range(-4,5), linestyle="dotted", color="grey", label="A rating = B rating")
# plt.legend(loc="upper center", bbox_to_anchor=(1.2, 1))

# plt.xlabel("Team A rating scaled")
# plt.ylabel("Team B rating scaled")
 
plt.show()

# %%
print("mean of team A win:", np.mean(final_rating_df.Team_A_win))
print("mean of team B win:", np.mean(final_rating_df.Team_B_win))
# Out:
# mean of team A win: 0.5878463117090411
# mean of team B win: 0.41215368829095883

# %%
lr = LogisticRegression()
X = final_rating_df[["Team_A_rating", "Team_B_rating"]]
y = final_rating_df.Team_A_win.to_numpy().reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, stratify=y)

# %%
lr.fit(X_train, y_train)
pred = lr.predict(X_test)
acc = accuracy_score(y_test, pred)
print("mean of true value:", np.mean(y_test))
print("mean of prediction:", np.mean(pred))
print("Accuracy:", acc)
# Out:
# mean of true value: 0.5877792977656179
# mean of prediction: 0.5950752393980848
# Accuracy: 0.9334245326037391
# c:\Users\parab\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
cm = confusion_matrix(y_test, pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()

# %% [markdown]
# Before chams 2022

# %%
chams_2022_team_rating = final_rating_df.loc[final_rating_df["Tournament"]=="Valorant Champions 2022"]

# %%
chams_2022_team_rating
# Out:
#                    Tournament        Stage        Match Type  \
# 8478  Valorant Champions 2022  Group Stage       Decider (A)
# 8479  Valorant Champions 2022  Group Stage       Decider (A)
# 8480  Valorant Champions 2022  Group Stage       Decider (A)
# 8481  Valorant Champions 2022  Group Stage       Decider (B)
# 8482  Valorant Champions 2022  Group Stage       Decider (B)
# ...                       ...          ...               ...
# 8559  Valorant Champions 2022     Playoffs  Upper Semifinals
# 8560  Valorant Champions 2022     Playoffs  Upper Semifinals
# 8561  Valorant Champions 2022     Playoffs  Upper Semifinals
# 8562  Valorant Champions 2022     Playoffs  Upper Semifinals
# 8563  Valorant Champions 2022     Playoffs  Upper Semifinals
#
#                     Match Name     Map         Team B        Team A  \
# 8478  Paper Rex vs Team Liquid  Ascent    Team Liquid     Paper Rex
# 8479  Paper Rex vs Team Liquid   Haven    Team Liquid     Paper Rex
# 8480  Paper Rex vs Team Liquid   Pearl    Team Liquid     Paper Rex
# 8481     LOUD vs ZETA DIVISION  Ascent  ZETA DIVISION          LOUD
# 8482     LOUD vs ZETA DIVISION    Bind  ZETA DIVISION          LOUD
# ...                        ...     ...            ...           ...
# 8559               DRX vs LOUD  Breeze           LOUD           DRX
# 8560               DRX vs LOUD   Haven           LOUD           DRX
# 8561      OpTic Gaming vs XSET  Ascent           XSET  OpTic Gaming
# 8562      OpTic Gaming vs XSET   Haven           XSET  OpTic Gaming
# 8563      OpTic Gaming vs XSET   Pearl           XSET  OpTic Gaming
#
#       Team A Score  Team_A_win  Team B Score  Team_B_win  Team_A_rating  \
# 8478             8       False            13        True      -0.148251
# 8479            13       False            15        True      -0.204104
# 8480            13        True             4       False       0.287442
# 8481            13        True             5       False       0.122540
# 8482            13        True            11       False       0.118260
# ...            ...         ...           ...         ...            ...
# 8559            11       False            13        True      -0.122199
# 8560             6       False            13        True      -0.160568
# 8561            11       False            13        True      -0.103463
# 8562            13        True             9       False       0.199880
# 8563            13        True             8       False       0.248255
#
#       Team_B_rating
# 8478       0.148251
# 8479       0.204104
# 8480      -0.287442
# 8481      -0.122540
# 8482      -0.118260
# ...             ...
# 8559       0.122199
# 8560       0.160568
# 8561       0.103463
# 8562      -0.199880
# 8563      -0.248255
#
# [85 rows x 13 columns]

# %%
lr2 = LogisticRegression()
W_train = final_rating_df[final_rating_df["Tournament"] != "Valorant Champions 2022"][["Team_A_rating", "Team_B_rating"]]
z_train = final_rating_df[final_rating_df["Tournament"] != "Valorant Champions 2022"].Team_A_win.to_numpy().reshape(-1,1)

W_test = chams_2022_team_rating[["Team_A_rating", "Team_B_rating"]]
z_test = chams_2022_team_rating.Team_A_win.to_numpy().reshape(-1,1)

# %%
print(len(W_train), len(W_test))
# Out:
# 8686 85

# %%
lr2.fit(W_train, z_train)
pred2 = lr2.predict(W_test)
acc2 = accuracy_score(z_test, pred2)
print("mean of true values:", np.mean(z_test))
print("mean of prediction:", np.mean(pred2))
print("Accuracy:", acc2)
# Out:
# mean of true values: 0.5647058823529412
# mean of prediction: 0.5882352941176471
# Accuracy: 0.9529411764705882
# c:\Users\parab\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
cm2 = confusion_matrix(z_test, pred2, labels=lr2.classes_)
disp2 = ConfusionMatrixDisplay(confusion_matrix=cm2,
                              display_labels=lr2.classes_)
disp2.plot()
plt.show()

# %% [markdown]
# This is suss. We would not know beforehand the ratings of the matches in the final. I will replace the ratings in the finals with average rating from previous tournaments.

# %%
grouped_overall_rating_df_A = Eco_rounds_ab_2022.groupby(['Team A'])["Rating_A"].agg("mean").reset_index()
grouped_overall_rating_df_B = Eco_rounds_ab_2022.groupby(['Team B'])["Rating_B"].agg("mean").reset_index()
#print(grouped_rating_df_A.head())
print(grouped_overall_rating_df_A.head(20))
# Out:
#                     Team A  Rating_A
# 0    Frederikssund Vikings -0.201840
# 1                    0Zero  0.179229
# 2              100 Thieves  0.058342
# 3                   100paz  0.206708
# 4                     1337  0.231309
# 5                  18again -0.444057
# 6                19esports  0.192222
# 7                 1Percent -0.139736
# 8         1gameandwegohome -0.080977
# 9              3 Gün Yeter  0.428768
# 10             303 Esports -0.021572
# 11                36NUMBER  0.261567
# 12              3P eSports -0.023969
# 13         4 ruim e 1 ruim  0.048019
# 14               47 Gaming  0.053347
# 15               5 SAHABAT -0.211035
# 16             5 of a Kind -0.350953
# 17                  5MOKES  0.018101
# 18                  5ORDIC  0.132341
# 19     717 Monster Esports -0.143249

# %%
chams_2022 =  maps_scores.loc[ (maps_scores["Tournament"]=="Valorant Champions 2022")]
len(chams_2022)
# Out:
# 86

# %%
champs_rating_overall_df = chams_2022.merge(grouped_overall_rating_df_A, on=["Team A"], how="left")
champs_rating_overall_df
# Out:
#                  Tournament        Stage   Match Type  \
# 0   Valorant Champions 2022  Group Stage  Opening (A)
# 1   Valorant Champions 2022  Group Stage  Opening (A)
# 2   Valorant Champions 2022  Group Stage  Opening (A)
# 3   Valorant Champions 2022  Group Stage  Opening (A)
# 4   Valorant Champions 2022  Group Stage  Opening (A)
# ..                      ...          ...          ...
# 81  Valorant Champions 2022     Playoffs  Lower Final
# 82  Valorant Champions 2022     Playoffs  Grand Final
# 83  Valorant Champions 2022     Playoffs  Grand Final
# 84  Valorant Champions 2022     Playoffs  Grand Final
# 85  Valorant Champions 2022     Playoffs  Grand Final
#
#                     Match Name     Map        Team A  Team A Score  \
# 0   Paper Rex vs EDward Gaming   Pearl     Paper Rex            13
# 1   Paper Rex vs EDward Gaming  Icebox     Paper Rex             5
# 2   Paper Rex vs EDward Gaming   Haven     Paper Rex            13
# 3      Leviatán vs Team Liquid   Haven      Leviatán            13
# 4      Leviatán vs Team Liquid  Ascent      Leviatán            13
# ..                         ...     ...           ...           ...
# 81         OpTic Gaming vs DRX   Haven  OpTic Gaming            13
# 82        LOUD vs OpTic Gaming  Ascent          LOUD            15
# 83        LOUD vs OpTic Gaming    Bind          LOUD             6
# 84        LOUD vs OpTic Gaming  Breeze          LOUD            16
# 85        LOUD vs OpTic Gaming   Haven          LOUD            13
#
#     Team_A_win         Team B  Team B Score  Team_B_win  Rating_A
# 0         True  EDward Gaming            11       False  0.160603
# 1        False  EDward Gaming            13        True  0.160603
# 2         True  EDward Gaming             8       False  0.160603
# 3         True    Team Liquid            10       False  0.093804
# 4         True    Team Liquid            10       False  0.093804
# ..         ...            ...           ...         ...       ...
# 81        True            DRX            10       False  0.030358
# 82        True   OpTic Gaming            13       False  0.113253
# 83       False   OpTic Gaming            13        True  0.113253
# 84        True   OpTic Gaming            14       False  0.113253
# 85        True   OpTic Gaming             5       False  0.113253
#
# [86 rows x 12 columns]

# %%
champs_rating_overall_df = champs_rating_overall_df.merge(grouped_overall_rating_df_B, on=["Team B"], how="left")
champs_rating_overall_df
# Out:
#                  Tournament        Stage   Match Type  \
# 0   Valorant Champions 2022  Group Stage  Opening (A)
# 1   Valorant Champions 2022  Group Stage  Opening (A)
# 2   Valorant Champions 2022  Group Stage  Opening (A)
# 3   Valorant Champions 2022  Group Stage  Opening (A)
# 4   Valorant Champions 2022  Group Stage  Opening (A)
# ..                      ...          ...          ...
# 81  Valorant Champions 2022     Playoffs  Lower Final
# 82  Valorant Champions 2022     Playoffs  Grand Final
# 83  Valorant Champions 2022     Playoffs  Grand Final
# 84  Valorant Champions 2022     Playoffs  Grand Final
# 85  Valorant Champions 2022     Playoffs  Grand Final
#
#                     Match Name     Map        Team A  Team A Score  \
# 0   Paper Rex vs EDward Gaming   Pearl     Paper Rex            13
# 1   Paper Rex vs EDward Gaming  Icebox     Paper Rex             5
# 2   Paper Rex vs EDward Gaming   Haven     Paper Rex            13
# 3      Leviatán vs Team Liquid   Haven      Leviatán            13
# 4      Leviatán vs Team Liquid  Ascent      Leviatán            13
# ..                         ...     ...           ...           ...
# 81         OpTic Gaming vs DRX   Haven  OpTic Gaming            13
# 82        LOUD vs OpTic Gaming  Ascent          LOUD            15
# 83        LOUD vs OpTic Gaming    Bind          LOUD             6
# 84        LOUD vs OpTic Gaming  Breeze          LOUD            16
# 85        LOUD vs OpTic Gaming   Haven          LOUD            13
#
#     Team_A_win         Team B  Team B Score  Team_B_win  Rating_A  Rating_B
# 0         True  EDward Gaming            11       False  0.160603  0.053276
# 1        False  EDward Gaming            13        True  0.160603  0.053276
# 2         True  EDward Gaming             8       False  0.160603  0.053276
# 3         True    Team Liquid            10       False  0.093804  0.054733
# 4         True    Team Liquid            10       False  0.093804  0.054733
# ..         ...            ...           ...         ...       ...       ...
# 81        True            DRX            10       False  0.030358  0.177392
# 82        True   OpTic Gaming            13       False  0.113253  0.024078
# 83       False   OpTic Gaming            13        True  0.113253  0.024078
# 84        True   OpTic Gaming            14       False  0.113253  0.024078
# 85        True   OpTic Gaming             5       False  0.113253  0.024078
#
# [86 rows x 13 columns]

# %%
champs_rating_overall_df=champs_rating_overall_df.rename(columns={"Rating_A":"Team_A_rating", "Rating_B":"Team_B_rating"})
champs_rating_overall_df
# Out:
#                  Tournament        Stage   Match Type  \
# 0   Valorant Champions 2022  Group Stage  Opening (A)
# 1   Valorant Champions 2022  Group Stage  Opening (A)
# 2   Valorant Champions 2022  Group Stage  Opening (A)
# 3   Valorant Champions 2022  Group Stage  Opening (A)
# 4   Valorant Champions 2022  Group Stage  Opening (A)
# ..                      ...          ...          ...
# 81  Valorant Champions 2022     Playoffs  Lower Final
# 82  Valorant Champions 2022     Playoffs  Grand Final
# 83  Valorant Champions 2022     Playoffs  Grand Final
# 84  Valorant Champions 2022     Playoffs  Grand Final
# 85  Valorant Champions 2022     Playoffs  Grand Final
#
#                     Match Name     Map        Team A  Team A Score  \
# 0   Paper Rex vs EDward Gaming   Pearl     Paper Rex            13
# 1   Paper Rex vs EDward Gaming  Icebox     Paper Rex             5
# 2   Paper Rex vs EDward Gaming   Haven     Paper Rex            13
# 3      Leviatán vs Team Liquid   Haven      Leviatán            13
# 4      Leviatán vs Team Liquid  Ascent      Leviatán            13
# ..                         ...     ...           ...           ...
# 81         OpTic Gaming vs DRX   Haven  OpTic Gaming            13
# 82        LOUD vs OpTic Gaming  Ascent          LOUD            15
# 83        LOUD vs OpTic Gaming    Bind          LOUD             6
# 84        LOUD vs OpTic Gaming  Breeze          LOUD            16
# 85        LOUD vs OpTic Gaming   Haven          LOUD            13
#
#     Team_A_win         Team B  Team B Score  Team_B_win  Team_A_rating  \
# 0         True  EDward Gaming            11       False       0.160603
# 1        False  EDward Gaming            13        True       0.160603
# 2         True  EDward Gaming             8       False       0.160603
# 3         True    Team Liquid            10       False       0.093804
# 4         True    Team Liquid            10       False       0.093804
# ..         ...            ...           ...         ...            ...
# 81        True            DRX            10       False       0.030358
# 82        True   OpTic Gaming            13       False       0.113253
# 83       False   OpTic Gaming            13        True       0.113253
# 84        True   OpTic Gaming            14       False       0.113253
# 85        True   OpTic Gaming             5       False       0.113253
#
#     Team_B_rating
# 0        0.053276
# 1        0.053276
# 2        0.053276
# 3        0.054733
# 4        0.054733
# ..            ...
# 81       0.177392
# 82       0.024078
# 83       0.024078
# 84       0.024078
# 85       0.024078
#
# [86 rows x 13 columns]

# %%
lr3 = LogisticRegression()
A_train = final_rating_df[final_rating_df["Tournament"] != "Valorant Champions 2022"][["Team_A_rating", "Team_B_rating"]]
b_train = final_rating_df[final_rating_df["Tournament"] != "Valorant Champions 2022"].Team_A_win.to_numpy().reshape(-1,1)

A_test = champs_rating_overall_df[["Team_A_rating", "Team_B_rating"]]
b_test = champs_rating_overall_df.Team_A_win.to_numpy().reshape(-1,1)

# %%
print(len(A_train), len(b_test))
# Out:
# 8686 86

# %%
lr3.fit(A_train, b_train)
pred3 = lr3.predict(A_test)
acc3 = accuracy_score(b_test, pred3)
print("mean of true values:", np.mean(b_test))
print("mean of prediction:", np.mean(pred3))
print("Accuracy:", acc3)
# Out:
# mean of true values: 0.5581395348837209
# mean of prediction: 0.686046511627907
# Accuracy: 0.6627906976744186
# c:\Users\parab\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
cm3 = confusion_matrix(b_test, pred3, labels=lr3.classes_)
disp3 = ConfusionMatrixDisplay(confusion_matrix=cm3,
                              display_labels=lr3.classes_)
disp3.plot()
plt.show()

# %% [markdown]
# This is sad. So, now I will calculate the ratings of the final matches with the first 12 rounds.

# %%
half_chams_2022_team_rating = half_final_rating_df.loc[final_rating_df["Tournament"]=="Valorant Champions 2022"]

# %%
half_chams_2022_team_rating
# Out:
#                    Tournament        Stage        Match Type  \
# 8478  Valorant Champions 2022  Group Stage       Decider (A)
# 8479  Valorant Champions 2022  Group Stage       Decider (A)
# 8480  Valorant Champions 2022  Group Stage       Decider (A)
# 8481  Valorant Champions 2022  Group Stage       Decider (B)
# 8482  Valorant Champions 2022  Group Stage       Decider (B)
# ...                       ...          ...               ...
# 8559  Valorant Champions 2022     Playoffs  Upper Semifinals
# 8560  Valorant Champions 2022     Playoffs  Upper Semifinals
# 8561  Valorant Champions 2022     Playoffs  Upper Semifinals
# 8562  Valorant Champions 2022     Playoffs  Upper Semifinals
# 8563  Valorant Champions 2022     Playoffs  Upper Semifinals
#
#                     Match Name     Map         Team B        Team A  \
# 8478  Paper Rex vs Team Liquid  Ascent    Team Liquid     Paper Rex
# 8479  Paper Rex vs Team Liquid   Haven    Team Liquid     Paper Rex
# 8480  Paper Rex vs Team Liquid   Pearl    Team Liquid     Paper Rex
# 8481     LOUD vs ZETA DIVISION  Ascent  ZETA DIVISION          LOUD
# 8482     LOUD vs ZETA DIVISION    Bind  ZETA DIVISION          LOUD
# ...                        ...     ...            ...           ...
# 8559               DRX vs LOUD  Breeze           LOUD           DRX
# 8560               DRX vs LOUD   Haven           LOUD           DRX
# 8561      OpTic Gaming vs XSET  Ascent           XSET  OpTic Gaming
# 8562      OpTic Gaming vs XSET   Haven           XSET  OpTic Gaming
# 8563      OpTic Gaming vs XSET   Pearl           XSET  OpTic Gaming
#
#       Team A Score  Team_A_win  Team B Score  Team_B_win  Team_A_rating  \
# 8478             8       False            13        True      -0.198276
# 8479            13       False            15        True      -0.319742
# 8480            13        True             4       False       0.116354
# 8481            13        True             5       False      -0.196658
# 8482            13        True            11       False       0.121970
# ...            ...         ...           ...         ...            ...
# 8559            11       False            13        True       0.130077
# 8560             6       False            13        True      -0.073864
# 8561            11       False            13        True      -0.298044
# 8562            13        True             9       False      -0.133493
# 8563            13        True             8       False       0.240656
#
#       Team_B_rating
# 8478       0.198276
# 8479       0.319742
# 8480      -0.116354
# 8481       0.196658
# 8482      -0.121970
# ...             ...
# 8559      -0.130077
# 8560       0.073864
# 8561       0.298044
# 8562       0.133493
# 8563      -0.240656
#
# [85 rows x 13 columns]

# %%
lr4 = LogisticRegression()
C_train = final_rating_df[final_rating_df["Tournament"] != "Valorant Champions 2022"][["Team_A_rating", "Team_B_rating"]]
d_train = final_rating_df[final_rating_df["Tournament"] != "Valorant Champions 2022"].Team_A_win.to_numpy().reshape(-1,1)

C_test = half_chams_2022_team_rating[["Team_A_rating", "Team_B_rating"]]
d_test = half_chams_2022_team_rating.Team_A_win.to_numpy().reshape(-1,1)

# %%
print(len(C_train), len(d_test))
# Out:
# 8686 85

# %%
lr4.fit(C_train, d_train)
pred4 = lr4.predict(C_test)
acc4 = accuracy_score(d_test, pred4)
print("mean of true values:", np.mean(d_test))
print("mean of prediction:", np.mean(pred4))
print("Accuracy:", acc4)
# Out:
# mean of true values: 0.5647058823529412
# mean of prediction: 0.5294117647058824
# Accuracy: 0.7058823529411765
# c:\Users\parab\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
cm4 = confusion_matrix(d_test, pred4, labels=lr4.classes_)
disp4 = ConfusionMatrixDisplay(confusion_matrix=cm4,
                              display_labels=lr4.classes_)
disp4.plot()
plt.show()
